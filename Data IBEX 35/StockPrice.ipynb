# %%
#españa
import pandas as pd
import yfinance as yf
from datetime import datetime

df = pd.read_csv('Ticketsvalidos.csv')
start_date = '2020-01-01'
end_date = '2024-12-31'


tickers_mc = df[df['ticker_market'].str.endswith('.MC')]['ticker_market'].tolist()

data = yf.download(tickers_mc, start=start_date, end=end_date)
df_long = data.stack(level=1).reset_index()
df_long.rename(columns={'level_1': 'ticker_market', 'Date': 'FECHA'}, inplace=True)

stockprice_mc = df_long[["Ticker", "Close", "High", "Low", "Open", "Volume", "FECHA"]]

ibex = yf.Ticker('^IBEX')
ibex_hist = ibex.history(start=start_date, end=end_date)

if ibex_hist.empty:
    ibex_hist = ibex.history(period='5d').tail(1)

ibex_open = ibex_hist['Open'].values[0]
ibex_close = ibex_hist['Close'].values[0]

stockprice_mc['StockIndexOpen'] = ibex_open
stockprice_mc['StockIndexClose'] = ibex_close

stockprice_mc.to_excel('stockprice_mc.xlsx', index=False)

stockprice_mc.head()
# Out:
# /tmp/ipython-input-2088104590.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers_mc, start=start_date, end=end_date)
# [*********************100%***********************]  96 of 96 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CMM.MC']: YFPricesMissingError('possibly delisted; no price data found  (1d 2020-01-01 -> 2024-12-31)')
# /tmp/ipython-input-2088104590.py:14: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_long = data.stack(level=1).reset_index()
# Price    Ticker      Close       High        Low       Open    Volume  \
# 0        A3M.MC   2.224365   2.275063   2.200284   2.200284  576886.0
# 1        ACS.MC  23.431675  23.897777  23.431675  23.857825  547978.0
# 2        ACX.MC   7.204575   7.297307   7.168909   7.168909  592405.0
# 3        ADZ.MC   7.020000   7.200000   6.920000   7.200000    7468.0
# 4      AEDAS.MC  11.050766  11.076525  10.921969  11.050766   18454.0
#
# Price      FECHA  StockIndexOpen  StockIndexClose
# 0     2020-01-02     9639.099609      9691.200195
# 1     2020-01-02     9639.099609      9691.200195
# 2     2020-01-02     9639.099609      9691.200195
# 3     2020-01-02     9639.099609      9691.200195
# 4     2020-01-02     9639.099609      9691.200195

# %%
#Francia
import pandas as pd
import yfinance as yf
from datetime import datetime

df = pd.read_csv('Ticketsvalidos.csv')
start_date = '2020-01-01'
end_date = '2024-12-31'


tickers_pa = df[df['ticker_market'].str.endswith('.PA')]['ticker_market'].tolist()

data = yf.download(tickers_pa, start=start_date, end=end_date)
df_long = data.stack(level=1).reset_index()
df_long.rename(columns={'level_1': 'ticker_market', 'Date': 'FECHA'}, inplace=True)

stockprice_pa = df_long[["Ticker", "Close", "High", "Low", "Open", "Volume", "FECHA"]]

ibex = yf.Ticker('^FCHI')
ibex_hist = ibex.history(start=start_date, end=end_date)

if ibex_hist.empty:
    ibex_hist = ibex.history(period='5d').tail(1)

ibex_open = ibex_hist['Open'].values[0]
ibex_close = ibex_hist['Close'].values[0]

stockprice_pa['StockIndexOpen'] = ibex_open
stockprice_pa['StockIndexClose'] = ibex_close

stockprice_pa.to_excel('stockprice_pa.xlsx', index=False)

stockprice_pa.head()
# Out:
# /tmp/ipython-input-3482370144.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers_pa, start=start_date, end=end_date)
# [*********************100%***********************]  210 of 210 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ALMII.PA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2020-01-01 -> 2024-12-31)')
# /tmp/ipython-input-3482370144.py:14: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_long = data.stack(level=1).reset_index()
# Price   Ticker       Close        High         Low        Open    Volume  \
# 0      ABEO.PA   15.651174   15.651174   15.287191   15.287191    1973.0
# 1      ABNX.PA    0.340500    0.347500    0.338000    0.338000   63468.0
# 2      ABVX.PA   23.700001   23.700001   21.650000   22.150000  103573.0
# 3      ADOC.PA   10.780000   10.780000    9.940000    9.980000   68082.0
# 4       ADP.PA  162.969421  164.820295  162.043985  163.617224   70483.0
#
# Price      FECHA  StockIndexOpen  StockIndexClose
# 0     2020-01-02     6016.609863           6041.5
# 1     2020-01-02     6016.609863           6041.5
# 2     2020-01-02     6016.609863           6041.5
# 3     2020-01-02     6016.609863           6041.5
# 4     2020-01-02     6016.609863           6041.5

# %%
#reino unido
import pandas as pd
import yfinance as yf
from datetime import datetime

df = pd.read_csv('Ticketsvalidos.csv')
start_date = '2020-01-01'
end_date = '2024-12-31'

tickers_l = df[df['ticker_market'].str.endswith('.L')]['ticker_market'].tolist()

data = yf.download(tickers_l, start=start_date, end=end_date)
df_long = data.stack(level=1, future_stack=True).reset_index()
df_long.rename(columns={'level_1': 'ticker_market', 'Date': 'FECHA'}, inplace=True)

# Renombrar para mantener las columnas esperadas (mayúsculas)
df_long.rename(columns={'ticker_market': 'Ticker'}, inplace=True)

stockprice_l = df_long[["Ticker", "Close", "High", "Low", "Open", "Volume", "FECHA"]]

ftse = yf.Ticker('^FTSE')
ftse_hist = ftse.history(start=start_date, end=end_date)

if ftse_hist.empty:
    ftse_hist = ftse.history(period='5d').tail(1)

ftse_open = ftse_hist['Open'].values[0]
ftse_close = ftse_hist['Close'].values[0]

stockprice_l['StockIndexOpen'] = ftse_open
stockprice_l['StockIndexClose'] = ftse_close

stockprice_l.to_excel('stockprice_l.xlsx', index=False)

stockprice_l.head()
# Out:
# /tmp/ipython-input-860543282.py:12: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers_l, start=start_date, end=end_date)
# [*********************100%***********************]  433 of 433 completed
# ERROR:yfinance:
# 2 Failed downloads:
# ERROR:yfinance:['0QYF.L', '0QYR.L']: YFPricesMissingError('possibly delisted; no price data found  (1d 2020-01-01 -> 2024-12-31)')
# Price  Ticker  Close  High  Low  Open  Volume      FECHA  StockIndexOpen  \
# 0      0QYF.L    NaN   NaN  NaN   NaN     NaN 2020-01-02     7542.399902
# 1      0QYR.L    NaN   NaN  NaN   NaN     NaN 2020-01-02     7542.399902
# 2      0JSJ.L    NaN   NaN  NaN   NaN     NaN 2020-01-02     7542.399902
# 3      0JYA.L    NaN   NaN  NaN   NaN     NaN 2020-01-02     7542.399902
# 4      0K34.L    NaN   NaN  NaN   NaN     NaN 2020-01-02     7542.399902
#
# Price  StockIndexClose
# 0          7604.299805
# 1          7604.299805
# 2          7604.299805
# 3          7604.299805
# 4          7604.299805

# %%
#alemania
import pandas as pd
import yfinance as yf
from datetime import datetime

df = pd.read_csv('Ticketsvalidos.csv')
start_date = '2020-01-01'
end_date = '2024-12-31'

tickers_de = df[df['ticker_market'].str.endswith('.DE')]['ticker_market'].tolist()

data = yf.download(tickers_de, start=start_date, end=end_date)
df_long = data.stack(level=1, future_stack=True).reset_index()
df_long.rename(columns={'level_1': 'ticker_market', 'Date': 'FECHA'}, inplace=True)

# Renombrar para mantener las columnas esperadas (mayúsculas)
df_long.rename(columns={'ticker_market': 'Ticker'}, inplace=True)

stockprice_de = df_long[["Ticker", "Close", "High", "Low", "Open", "Volume", "FECHA"]]

dax = yf.Ticker('^GDAXI')
dax_hist = dax.history(start=start_date, end=end_date)

if dax_hist.empty:
    dax_hist = dax.history(period='5d').tail(1)

dax_open = dax_hist['Open'].values[0]
dax_close = dax_hist['Close'].values[0]

stockprice_de['StockIndexOpen'] = dax_open
stockprice_de['StockIndexClose'] = dax_close

stockprice_de.to_excel('stockprice_de.xlsx', index=False)

stockprice_de.head()
# Out:
# /tmp/ipython-input-3804260440.py:12: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers_de, start=start_date, end=end_date)
# [*********************100%***********************]  53 of 53 completed
# ERROR:yfinance:
# 3 Failed downloads:
# ERROR:yfinance:['2U3.DE', 'A4Y.DE']: YFPricesMissingError('possibly delisted; no price data found  (1d 2020-01-01 -> 2024-12-31)')
# ERROR:yfinance:['2HR.DE']: YFPricesMissingError('possibly delisted; no price data found  (1d 2020-01-01 -> 2024-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1577833200, endDate = 1735599600")')
# Price   Ticker      Close       High        Low       Open     Volume  \
# 0       2HR.DE        NaN        NaN        NaN        NaN        NaN
# 1       2U3.DE        NaN        NaN        NaN        NaN        NaN
# 2       A4Y.DE        NaN        NaN        NaN        NaN        NaN
# 3      1COV.DE  36.833733  37.209231  36.239922  36.239922  1238476.0
# 4       1YD.DE  24.175264  24.790789  23.487575  24.196489      380.0
#
# Price      FECHA  StockIndexOpen  StockIndexClose
# 0     2020-01-02    13233.709961     13385.929688
# 1     2020-01-02    13233.709961     13385.929688
# 2     2020-01-02    13233.709961     13385.929688
# 3     2020-01-02    13233.709961     13385.929688
# 4     2020-01-02    13233.709961     13385.929688

# %%
#suiza
import pandas as pd
import yfinance as yf
from datetime import datetime

df = pd.read_csv('Ticketsvalidos.csv')
start_date = '2020-01-01'
end_date = '2024-12-31'

tickers_de = df[df['ticker_market'].str.endswith('.SW')]['ticker_market'].tolist()

data = yf.download(tickers_de, start=start_date, end=end_date)
df_long = data.stack(level=1, future_stack=True).reset_index()
df_long.rename(columns={'level_1': 'ticker_market', 'Date': 'FECHA'}, inplace=True)

df_long.rename(columns={'ticker_market': 'Ticker'}, inplace=True)

stockprice_sw = df_long[["Ticker", "Close", "High", "Low", "Open", "Volume", "FECHA"]]

dax = yf.Ticker('^SSMI')
dax_hist = dax.history(start=start_date, end=end_date)

if dax_hist.empty:
    dax_hist = dax.history(period='5d').tail(1)

dax_open = dax_hist['Open'].values[0]
dax_close = dax_hist['Close'].values[0]

stockprice_sw['StockIndexOpen'] = dax_open
stockprice_sw['StockIndexClose'] = dax_close

stockprice_sw.to_excel('stockprice_sw.xlsx', index=False)

stockprice_sw.head()
# Out:
# /tmp/ipython-input-2953037362.py:12: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers_de, start=start_date, end=end_date)
# [*********************100%***********************]  162 of 162 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['TEMN.SW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2020-01-01 -> 2024-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1577833200, endDate = 1735599600")')
# Price   Ticker       Close        High         Low        Open     Volume  \
# 0      TEMN.SW         NaN         NaN         NaN         NaN        NaN
# 1       2HQ.SW         NaN         NaN         NaN         NaN        NaN
# 2      ABBN.SW   19.010515   19.034723   18.800722   18.808790  8061086.0
# 3      ADEN.SW   42.153591   42.486273   42.070421   42.222899   830376.0
# 4      ADVN.SW  165.562805  165.562805  165.562805  165.562805        8.0
#
# Price      FECHA  StockIndexOpen  StockIndexClose
# 0     2020-01-03    10585.290039     10699.820312
# 1     2020-01-03    10585.290039     10699.820312
# 2     2020-01-03    10585.290039     10699.820312
# 3     2020-01-03    10585.290039     10699.820312
# 4     2020-01-03    10585.290039     10699.820312

# %%
#Suecia
import pandas as pd
import yfinance as yf
from datetime import datetime

df = pd.read_csv('Ticketsvalidos.csv')
start_date = '2020-01-01'
end_date = '2024-12-31'

tickers_de = df[df['ticker_market'].str.endswith('.MI')]['ticker_market'].tolist()

data = yf.download(tickers_de, start=start_date, end=end_date)
df_long = data.stack(level=1, future_stack=True).reset_index()
df_long.rename(columns={'level_1': 'ticker_market', 'Date': 'FECHA'}, inplace=True)

df_long.rename(columns={'ticker_market': 'Ticker'}, inplace=True)

stockprice_mi = df_long[["Ticker", "Close", "High", "Low", "Open", "Volume", "FECHA"]]

dax = yf.Ticker('FTSEMIB.MI')
dax_hist = dax.history(start=start_date, end=end_date)

if dax_hist.empty:
    dax_hist = dax.history(period='5d').tail(1)

dax_open = dax_hist['Open'].values[0]
dax_close = dax_hist['Close'].values[0]

stockprice_mi['StockIndexOpen'] = dax_open
stockprice_mi['StockIndexClose'] = dax_close

stockprice_mi.to_excel('stockprice_mi.xlsx', index=False)

stockprice_mi.head()
# Out:
# /tmp/ipython-input-2480330846.py:12: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers_de, start=start_date, end=end_date)
# [*********************100%***********************]  108 of 108 completed
# /tmp/ipython-input-2480330846.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stockprice_mi['StockIndexOpen'] = dax_open
# /tmp/ipython-input-2480330846.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stockprice_mi['StockIndexClose'] = dax_close
# Price   Ticker      Close       High        Low       Open    Volume  \
# 0      ABTG.MI   1.658281   1.658281   1.619716   1.619716    4200.0
# 1       ACE.MI  13.525730  13.732682  13.525730  13.629207   80459.0
# 2       ADB.MI  11.072960  11.146169  10.853330  10.981447    8628.0
# 3       AEF.MI   2.030000   2.050000   2.005000   2.010000  161368.0
# 4      ANIM.MI   3.261598   3.271305   3.195034   3.214449  664085.0
#
# Price      FECHA  StockIndexOpen  StockIndexClose
# 0     2020-01-02         23607.0          23836.0
# 1     2020-01-02         23607.0          23836.0
# 2     2020-01-02         23607.0          23836.0
# 3     2020-01-02         23607.0          23836.0
# 4     2020-01-02         23607.0          23836.0

# %%
#Suecia
import pandas as pd
import yfinance as yf
from datetime import datetime

df = pd.read_csv('Ticketsvalidos.csv')
start_date = '2020-01-01'
end_date = '2024-12-31'

tickers_st = df[df['ticker_market'].str.endswith('.ST')]['ticker_market'].tolist()

data = yf.download(tickers_de, start=start_date, end=end_date)
df_long = data.stack(level=1, future_stack=True).reset_index()
df_long.rename(columns={'level_1': 'ticker_market', 'Date': 'FECHA'}, inplace=True)

df_long.rename(columns={'ticker_market': 'Ticker'}, inplace=True)

stockprice_st = df_long[["Ticker", "Close", "High", "Low", "Open", "Volume", "FECHA"]]

dax = yf.Ticker('^OMXS30')
dax_hist = dax.history(start=start_date, end=end_date)

if dax_hist.empty:
    dax_hist = dax.history(period='5d').tail(1)

dax_open = dax_hist['Open'].values[0]
dax_close = dax_hist['Close'].values[0]

stockprice_st['StockIndexOpen'] = dax_open
stockprice_st['StockIndexClose'] = dax_close

stockprice_st.to_excel('stockprice_st.xlsx', index=False)

stockprice_st.head()
# Out:
# /tmp/ipython-input-2150736101.py:12: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers_de, start=start_date, end=end_date)
# [*********************100%***********************]  108 of 108 completed
# ERROR:yfinance:$^OMXS30: possibly delisted; no price data found  (1d 2020-01-01 -> 2024-12-31)
# /tmp/ipython-input-2150736101.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stockprice_st['StockIndexOpen'] = dax_open
# /tmp/ipython-input-2150736101.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stockprice_st['StockIndexClose'] = dax_close
# Price   Ticker      Close       High        Low       Open    Volume  \
# 0      ABTG.MI   1.658281   1.658281   1.619716   1.619716    4200.0
# 1       ACE.MI  13.525730  13.732682  13.525730  13.629207   80459.0
# 2       ADB.MI  11.072960  11.146169  10.853330  10.981447    8628.0
# 3       AEF.MI   2.030000   2.050000   2.005000   2.010000  161368.0
# 4      ANIM.MI   3.261598   3.271305   3.195035   3.214449  664085.0
#
# Price      FECHA  StockIndexOpen  StockIndexClose
# 0     2020-01-02      2555.47998      2533.593262
# 1     2020-01-02      2555.47998      2533.593262
# 2     2020-01-02      2555.47998      2533.593262
# 3     2020-01-02      2555.47998      2533.593262
# 4     2020-01-02      2555.47998      2533.593262

# %%
#Países Bajos
import pandas as pd
import yfinance as yf
from datetime import datetime

df = pd.read_csv('Ticketsvalidos.csv')
start_date = '2020-01-01'
end_date = '2024-12-31'

tickers_as = df[df['ticker_market'].str.endswith('.AS')]['ticker_market'].tolist()

data = yf.download(tickers_de, start=start_date, end=end_date)
df_long = data.stack(level=1, future_stack=True).reset_index()
df_long.rename(columns={'level_1': 'ticker_market', 'Date': 'FECHA'}, inplace=True)

df_long.rename(columns={'ticker_market': 'Ticker'}, inplace=True)

stockprice_as = df_long[["Ticker", "Close", "High", "Low", "Open", "Volume", "FECHA"]]

dax = yf.Ticker('^AEX')
dax_hist = dax.history(start=start_date, end=end_date)

if dax_hist.empty:
    dax_hist = dax.history(period='5d').tail(1)

dax_open = dax_hist['Open'].values[0]
dax_close = dax_hist['Close'].values[0]

stockprice_as['StockIndexOpen'] = dax_open
stockprice_as['StockIndexClose'] = dax_close

stockprice_as.to_excel('stockprice_as.xlsx', index=False)

stockprice_as.head()
# Out:
# /tmp/ipython-input-30965719.py:12: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers_de, start=start_date, end=end_date)
# [*********************100%***********************]  108 of 108 completed
# /tmp/ipython-input-30965719.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stockprice_as['StockIndexOpen'] = dax_open
# /tmp/ipython-input-30965719.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stockprice_as['StockIndexClose'] = dax_close
# Price   Ticker      Close       High        Low       Open    Volume  \
# 0      ABTG.MI   1.658281   1.658281   1.619716   1.619716    4200.0
# 1       ACE.MI  13.525729  13.732681  13.525729  13.629206   80459.0
# 2       ADB.MI  11.072960  11.146169  10.853330  10.981447    8628.0
# 3       AEF.MI   2.030000   2.050000   2.005000   2.010000  161368.0
# 4      ANIM.MI   3.261598   3.271305   3.195034   3.214449  664085.0
#
# Price      FECHA  StockIndexOpen  StockIndexClose
# 0     2020-01-02       608.01001       612.869995
# 1     2020-01-02       608.01001       612.869995
# 2     2020-01-02       608.01001       612.869995
# 3     2020-01-02       608.01001       612.869995
# 4     2020-01-02       608.01001       612.869995
