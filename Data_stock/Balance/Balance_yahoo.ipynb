# %% [markdown]
# ### Balance geneal

# %%
import re
import time
import pandas as pd
import yfinance as yf
from difflib import get_close_matches

def norm(s: str) -> str:
    return re.sub(r'[^a-z0-9]', '', str(s).lower())

def best_match(target_norm: str, candidates_norm: dict) -> str | None:
    if target_norm in candidates_norm:
        return target_norm
    m = get_close_matches(target_norm, list(candidates_norm.keys()), n=1, cutoff=0.84)
    if m:
        return m[0]
    for c in candidates_norm:
        if target_norm in c or c in target_norm:
            return c
    return None

def to_millions(x):
    try:
        val = float(x)
        return round(val / 1_000_000, 2)
    except (TypeError, ValueError):
        return None

df_tickers = pd.read_csv("/Users/marcomendieta/Documents/TFM/Data_stock/Tickets_componentes_indices.csv", sep=None, engine="python")
tickers = (
    df_tickers["ticker_market"]
    .dropna()
    .astype(str)
    .str.strip()
    .unique()
    .tolist()
)

balance_general_keys = [
#ACTIVO
#corto plazo
    "CashAndCashEquivalents",
    "CashFinancial",
    "CashCashEquivalentsAndShortTermInvestments",
    "TradingSecurities",
    "OtherShortTermInvestments",
    "AccountsReceivable",
    "OtherReceivables",
    "LoansHeldForSale",
    "OtherCurrentAssets",
#largo plazo
    "LongTermInvestments",
    "InvestmentsAndAdvances",
    "Properties",
    "MachineryFurnitureEquipment",
    "ConstructionInProgress",
    "OtherIntangibleAssets",
    "Goodwill",
    "GoodwillAndOtherIntangibleAssets",
    "OtherNonCurrentAssets",
    "DeferredTaxAssets",
    "NetTangibleAssets",
    "TotalAssets",

#PASIVO
#corto plazp
    "AccountsPayable",
    "CurrentNotesPayable",
    "CurrentDebt",
    "CurrentDebtAndCapitalLeaseObligation",
    "CurrentAccruedExpenses",
    "PayablesAndAccruedExpenses",
    "IncomeTaxPayable",
    "TaxesPayable",
    "SecuritiesSoldUnderRepurchaseAgreements",
    "FederalFundsPurchasedAndSecuritiesSoldUnderRepurchaseAgreements",
    "LiabilitiesOfDiscontinuedOperations",
#largo plazo
    "LongTermDebt",
    "LongTermDebtAndCapitalLeaseObligation",
    "NonCurrentDeferredLiabilities",
    "NonCurrentDeferredTaxesLiabilities",
#total de pasivos
    "TotalDebt",
    "NetDebt",
    "TotalLiabilitiesNetMinorityInterest",

    #CAPITAL
    "StockholdersEquity",
    "ShareIssued",
    "CommonStock",
    "CapitalStock",
    "CommonStockEquity",
    "OrdinarySharesNumber",
    "TreasuryStock",
    "AdditionalPaidInCapital",
    "InvestedCapital",
    "TotalCapitalization",
    "RetainedEarnings",
    "UnrealizedGainLoss",
    "GainsLossesNotAffectingRetainedEarnings",
    "ForeignCurrencyTranslationAdjustments",
    "OtherEquityAdjustments",
    "TotalEquityGrossMinorityInterest",
    "RevaluationReserve",
    "TangibleBookValue",
]

balance_general_dict = {}

for ti in tickers:
    retry = 3
    while retry > 0:
        try:
            t = yf.Ticker(ti)
            bs = t.balance_sheet
            if bs is None or bs.empty:
                bs = t.quarterly_balance_sheet

            if bs is None or bs.empty:
                print(f"{ti} no tiene balance general disponible (anual/quarterly).")
                break
            last_period = bs.columns[0]
            norm_index_map = {norm(idx): idx for idx in bs.index}

            data_balance = {}
            for key in balance_general_keys:
                nk = norm(key)
                match_norm = best_match(nk, norm_index_map)
                if match_norm is None:
                    data_balance[key] = None
                    continue
                yahoo_label = norm_index_map[match_norm]
                value = bs.loc[yahoo_label, last_period]
                data_balance[key] = to_millions(value)

            balance_general_dict[ti] = data_balance
            print(f"{ti} procesado correctamente.")
            break

        except Exception as e:
            msg = str(e).lower()
            if "too many requests" in msg or "rate limit" in msg:
                retry -= 1
                wait_time = 10
                print(f"Rate limit detectado para {ti}. Esperando {wait_time}s. Intentos restantes: {retry}")
                time.sleep(wait_time)
            else:
                print(f"Error al procesar {ti}: {e}")
                break

    time.sleep(1)

df_balance_general = pd.DataFrame.from_dict(balance_general_dict, orient='index')
df_balance_general.index.name = "Ticker"
outfile = "balances_generales12.csv"
df_balance_general.to_csv(outfile)
print(f"Archivo guardado como {outfile}")
# Out:
# AIR.PA procesado correctamente.
# VIV.PA procesado correctamente.
# STM.PA no tiene balance general disponible (anual/quarterly).
# VIE.PA procesado correctamente.
# SAF.PA procesado correctamente.
# BVI.PA procesado correctamente.
# EDEN.PA procesado correctamente.
# INGA.AS procesado correctamente.
# ASMI.AS no tiene balance general disponible (anual/quarterly).
# RAND.AS procesado correctamente.
# AD.AS procesado correctamente.
# MT.AS procesado correctamente.
# KPN.AS procesado correctamente.
# ASML.AS procesado correctamente.
# BESI.AS procesado correctamente.
# NN.AS procesado correctamente.
# IMCD.AS procesado correctamente.
# ASRNL.AS procesado correctamente.
# UNA.AS procesado correctamente.
# ADYEN.AS procesado correctamente.
# PRX.AS procesado correctamente.
# CFR.SW procesado correctamente.
# ABBN.SW procesado correctamente.
# LOGN.SW procesado correctamente.
# ZURN.SW procesado correctamente.
# SLHN.SW procesado correctamente.
# NOVN.SW procesado correctamente.
# NESN.SW procesado correctamente.
# ROG.SW procesado correctamente.
# LONN.SW procesado correctamente.
# SCMN.SW procesado correctamente.
# GEBN.SW procesado correctamente.
# SIKA.SW procesado correctamente.
# PGHN.SW procesado correctamente.
# KNIN.SW procesado correctamente.
# SOON.SW procesado correctamente.
# UBSG.SW procesado correctamente.
# GIVN.SW procesado correctamente.
# BOL.ST procesado correctamente.
# AZN.ST procesado correctamente.
# ALFA.ST procesado correctamente.
# ABB.ST procesado correctamente.
# SAND.ST procesado correctamente.
# TELIA.ST procesado correctamente.
# ACS.MC procesado correctamente.
# ACX.MC procesado correctamente.
# BBVA.MC procesado correctamente.
# BKT.MC procesado correctamente.
# ANA.MC procesado correctamente.
# CABK.MC procesado correctamente.
# NTGY.MC procesado correctamente.
# FER.MC procesado correctamente.
# ITX.MC procesado correctamente.
# REP.MC procesado correctamente.
# IBE.MC procesado correctamente.
# IDR.MC procesado correctamente.
# MAP.MC procesado correctamente.
# TEF.MC procesado correctamente.
# SCYR.MC procesado correctamente.
# SAN.MC procesado correctamente.
# COL.MC procesado correctamente.
# ELE.MC procesado correctamente.
# ROVI.MC procesado correctamente.
# MTS.MC procesado correctamente.
# MRL.MC procesado correctamente.
# LOG.MC procesado correctamente.
# AENA.MC procesado correctamente.
# CLNX.MC procesado correctamente.
# UNI.MC procesado correctamente.
# SRG.MI procesado correctamente.
# PIRC.MI procesado correctamente.
# PRY.MI procesado correctamente.
# ISP.MI procesado correctamente.
# BMED.MI procesado correctamente.
# ENI.MI procesado correctamente.
# BMPS.MI procesado correctamente.
# BZU.MI procesado correctamente.
# TRN.MI procesado correctamente.
# BAMI.MI procesado correctamente.
# LDO.MI procesado correctamente.
# MONC.MI procesado correctamente.
# FBK.MI procesado correctamente.
# PST.MI procesado correctamente.
# RACE.MI procesado correctamente.
# IG.MI procesado correctamente.
# Archivo guardado como balances_generales12.csv

# %%
import re
import time
import pandas as pd
import yfinance as yf
from difflib import get_close_matches

def norm(s: str) -> str:
    return re.sub(r'[^a-z0-9]', '', str(s).lower())

def best_match(target_norm: str, candidates_norm: dict) -> str | None:
    if target_norm in candidates_norm:
        return target_norm
    m = get_close_matches(target_norm, list(candidates_norm.keys()), n=1, cutoff=0.84)
    if m:
        return m[0]
    for c in candidates_norm:
        if target_norm in c or c in target_norm:
            return c
    return None

def to_millions(x):
    try:
        val = float(x)
        return round(val / 1_000_000, 2)
    except (TypeError, ValueError):
        return None

df_tickers = pd.read_csv("/Users/marcomendieta/Documents/TFM/Data_stock/Tickets.csv", sep=None, engine="python")
tickers = (
    df_tickers["ticker_market"]
    .dropna()
    .astype(str)
    .str.strip()
    .unique()
    .tolist()
)

balance_general_keys = [
#ACTIVO
#corto plazo
    "CashAndCashEquivalents",
    "CashFinancial",
    "CashCashEquivalentsAndShortTermInvestments",
    "TradingSecurities",
    "OtherShortTermInvestments",
    "AccountsReceivable",
    "OtherReceivables",
    "LoansHeldForSale",
    "OtherCurrentAssets",
#largo plazo
    "LongTermInvestments",
    "InvestmentsAndAdvances",
    "Properties",
    "MachineryFurnitureEquipment",
    "ConstructionInProgress",
    "OtherIntangibleAssets",
    "Goodwill",
    "GoodwillAndOtherIntangibleAssets",
    "OtherNonCurrentAssets",
    "DeferredTaxAssets",
    "NetTangibleAssets",
    "TotalAssets",

#PASIVO
#corto plazp
    "AccountsPayable",
    "CurrentNotesPayable",
    "CurrentDebt",
    "CurrentDebtAndCapitalLeaseObligation",
    "CurrentAccruedExpenses",
    "PayablesAndAccruedExpenses",
    "IncomeTaxPayable",
    "TaxesPayable",
    "SecuritiesSoldUnderRepurchaseAgreements",
    "FederalFundsPurchasedAndSecuritiesSoldUnderRepurchaseAgreements",
    "LiabilitiesOfDiscontinuedOperations",
#largo plazo
    "LongTermDebt",
    "LongTermDebtAndCapitalLeaseObligation",
    "NonCurrentDeferredLiabilities",
    "NonCurrentDeferredTaxesLiabilities",
#total de pasivos
    "TotalDebt",
    "NetDebt",
    "TotalLiabilitiesNetMinorityInterest",

    #CAPITAL
    "StockholdersEquity",
    "ShareIssued",
    "CommonStock",
    "CapitalStock",
    "CommonStockEquity",
    "OrdinarySharesNumber",
    "TreasuryStock",
    "AdditionalPaidInCapital",
    "InvestedCapital",
    "TotalCapitalization",
    "RetainedEarnings",
    "UnrealizedGainLoss",
    "GainsLossesNotAffectingRetainedEarnings",
    "ForeignCurrencyTranslationAdjustments",
    "OtherEquityAdjustments",
    "TotalEquityGrossMinorityInterest",
    "RevaluationReserve",
    "TangibleBookValue",
]


balance_general_dict = {}

for ti in tickers:
    retry = 3
    while retry > 0:
        try:
            t = yf.Ticker(ti)
            bs = t.balance_sheet
            if bs is None or bs.empty:
                bs = t.quarterly_balance_sheet

            if bs is None or bs.empty:
                print(f"{ti} no tiene balance general disponible (anual/quarterly).")
                break
            last_period = bs.columns[0]
            norm_index_map = {norm(idx): idx for idx in bs.index}

            data_balance = {}
            for key in balance_general_keys:
                nk = norm(key)
                match_norm = best_match(nk, norm_index_map)
                if match_norm is None:
                    data_balance[key] = None
                    continue
                yahoo_label = norm_index_map[match_norm]
                value = bs.loc[yahoo_label, last_period]
                data_balance[key] = to_millions(value)

            balance_general_dict[ti] = data_balance
            print(f"{ti} procesado correctamente.")
            break

        except Exception as e:
            msg = str(e).lower()
            if "too many requests" in msg or "rate limit" in msg:
                retry -= 1
                wait_time = 10
                print(f"Rate limit detectado para {ti}. Esperando {wait_time}s. Intentos restantes: {retry}")
                time.sleep(wait_time)
            else:
                print(f"Error al procesar {ti}: {e}")
                break

    time.sleep(1)

df_balance_general = pd.DataFrame.from_dict(balance_general_dict, orient='index')
df_balance_general.index.name = "Ticker"
outfile = "balances_generales.csv"
df_balance_general.to_csv(outfile)
print(f"Archivo guardado como {outfile}")
# Out:
# BASFN.DE no tiene balance general disponible (anual/quarterly).
# BAYGN.DE no tiene balance general disponible (anual/quarterly).
# ALVG.DE no tiene balance general disponible (anual/quarterly).
# ADSGN.DE no tiene balance general disponible (anual/quarterly).
# LHAG.DE no tiene balance general disponible (anual/quarterly).
# SIEGN.DE no tiene balance general disponible (anual/quarterly).
# VOWG.DE no tiene balance general disponible (anual/quarterly).
# DBKGN.DE no tiene balance general disponible (anual/quarterly).
# CONG.DE no tiene balance general disponible (anual/quarterly).
# DPWGN.DE no tiene balance general disponible (anual/quarterly).
# DAIGN.DE no tiene balance general disponible (anual/quarterly).
# PSHG_P.DE no tiene balance general disponible (anual/quarterly).
# HNKG_P.DE no tiene balance general disponible (anual/quarterly).
# CBKG.DE no tiene balance general disponible (anual/quarterly).
# DB1GN.DE no tiene balance general disponible (anual/quarterly).
# BMWG.DE no tiene balance general disponible (anual/quarterly).
# FMEG.DE no tiene balance general disponible (anual/quarterly).
# DTEGN.DE no tiene balance general disponible (anual/quarterly).
# MANG.DE no tiene balance general disponible (anual/quarterly).
# MRCG.DE no tiene balance general disponible (anual/quarterly).
# IFXGN.DE no tiene balance general disponible (anual/quarterly).
# CECG.DE no tiene balance general disponible (anual/quarterly).
# MUVGN.DE no tiene balance general disponible (anual/quarterly).
# SAPG.DE no tiene balance general disponible (anual/quarterly).
# TKAG.DE no tiene balance general disponible (anual/quarterly).
# RHMG.DE no tiene balance general disponible (anual/quarterly).
# TUIGN.DE no tiene balance general disponible (anual/quarterly).
# WDIG.DE no tiene balance general disponible (anual/quarterly).
# LXSG.DE no tiene balance general disponible (anual/quarterly).
# BEIG.DE no tiene balance general disponible (anual/quarterly).
# FREG.DE no tiene balance general disponible (anual/quarterly).
# FNTGN.DE no tiene balance general disponible (anual/quarterly).
# SZGG.DE no tiene balance general disponible (anual/quarterly).
# A3B.DE no tiene balance general disponible (anual/quarterly).
# FRAG.DE no tiene balance general disponible (anual/quarterly).
# WCHG.DE no tiene balance general disponible (anual/quarterly).
# QSCG.DE no tiene balance general disponible (anual/quarterly).
# ZILGN.DE no tiene balance general disponible (anual/quarterly).
# VOSG.DE no tiene balance general disponible (anual/quarterly).
# KRNG.DE no tiene balance general disponible (anual/quarterly).
# G1AG.DE no tiene balance general disponible (anual/quarterly).
# HNRGN.DE no tiene balance general disponible (anual/quarterly).
# GBFG.DE no tiene balance general disponible (anual/quarterly).
# DRWG_P.DE no tiene balance general disponible (anual/quarterly).
# SOWGN.DE no tiene balance general disponible (anual/quarterly).
# KCOGN.DE no tiene balance general disponible (anual/quarterly).
# HOTG.DE no tiene balance general disponible (anual/quarterly).
# RWEG.DE no tiene balance general disponible (anual/quarterly).
# DEQGN.DE no tiene balance general disponible (anual/quarterly).
# NDXG.DE no tiene balance general disponible (anual/quarterly).
# NAFG.DE no tiene balance general disponible (anual/quarterly).
# A6W.DE no tiene balance general disponible (anual/quarterly).
# AIXGN.DE no tiene balance general disponible (anual/quarterly).
# RHKG.DE no tiene balance general disponible (anual/quarterly).
# GILG.DE no tiene balance general disponible (anual/quarterly).
# ABM.DE no tiene balance general disponible (anual/quarterly).
# SGCG.DE no tiene balance general disponible (anual/quarterly).
# SDFGN.DE no tiene balance general disponible (anual/quarterly).
# MTXGN.DE no tiene balance general disponible (anual/quarterly).
# SZUG.DE no tiene balance general disponible (anual/quarterly).
# HDDG.DE no tiene balance general disponible (anual/quarterly).
# ARLG.DE no tiene balance general disponible (anual/quarterly).
# B5AG.DE no tiene balance general disponible (anual/quarterly).
# DEZG.DE no tiene balance general disponible (anual/quarterly).
# SY1G.DE no tiene balance general disponible (anual/quarterly).
# CTNGK.DE no tiene balance general disponible (anual/quarterly).
# PV.DE no tiene balance general disponible (anual/quarterly).
# SNGGK.DE no tiene balance general disponible (anual/quarterly).
# HEIG.DE no tiene balance general disponible (anual/quarterly).
# AD8.DE no tiene balance general disponible (anual/quarterly).
# QIA.DE procesado correctamente.
# ADC.DE no tiene balance general disponible (anual/quarterly).
# UTDI.DE procesado correctamente.
# LEOGN.DE no tiene balance general disponible (anual/quarterly).
# GGS.DE no tiene balance general disponible (anual/quarterly).
# AEL.DE no tiene balance general disponible (anual/quarterly).
# AF4.DE no tiene balance general disponible (anual/quarterly).
# MORG.DE no tiene balance general disponible (anual/quarterly).
# M5ZG.DE no tiene balance general disponible (anual/quarterly).
# MDNG.DE no tiene balance general disponible (anual/quarterly).
# AGM.DE no tiene balance general disponible (anual/quarterly).
# AFXG.DE no tiene balance general disponible (anual/quarterly).
# BOSSN.DE no tiene balance general disponible (anual/quarterly).
# LOGNN.DE no tiene balance general disponible (anual/quarterly).
# BC8G.DE no tiene balance general disponible (anual/quarterly).
# ERICB.DE no tiene balance general disponible (anual/quarterly).
# MLPG.DE no tiene balance general disponible (anual/quarterly).
# 55O1.DE no tiene balance general disponible (anual/quarterly).
# ADAG.DE no tiene balance general disponible (anual/quarterly).
# CBRO.DE no tiene balance general disponible (anual/quarterly).
# DGII.DE no tiene balance general disponible (anual/quarterly).
# MQFA.DE no tiene balance general disponible (anual/quarterly).
# STM.DE procesado correctamente.
# EURA.DE no tiene balance general disponible (anual/quarterly).
# KORI.DE no tiene balance general disponible (anual/quarterly).
# PC6AY.DE no tiene balance general disponible (anual/quarterly).
# TQK.DE no tiene balance general disponible (anual/quarterly).
# RIOAY.DE no tiene balance general disponible (anual/quarterly).
# GTTG.DE no tiene balance general disponible (anual/quarterly).
# GSKY.DE no tiene balance general disponible (anual/quarterly).
# CCLC.DE no tiene balance general disponible (anual/quarterly).
# ARRJY.DE no tiene balance general disponible (anual/quarterly).
# NJY.DE no tiene balance general disponible (anual/quarterly).
# BHPY.DE no tiene balance general disponible (anual/quarterly).
# DIO.DE procesado correctamente.
# NOKY.DE no tiene balance general disponible (anual/quarterly).
# MCA.DE no tiene balance general disponible (anual/quarterly).
# ACEL.DE no tiene balance general disponible (anual/quarterly).
# EPWA.DE no tiene balance general disponible (anual/quarterly).
# HITY.DE no tiene balance general disponible (anual/quarterly).
# STEL.DE no tiene balance general disponible (anual/quarterly).
# 31L.DE no tiene balance general disponible (anual/quarterly).
# INVP.DE no tiene balance general disponible (anual/quarterly).
# DRFNY.DE no tiene balance general disponible (anual/quarterly).
# NPNJ.DE no tiene balance general disponible (anual/quarterly).
# AODCQ.DE no tiene balance general disponible (anual/quarterly).
# SLMJ.DE no tiene balance general disponible (anual/quarterly).
# AVA.DE no tiene balance general disponible (anual/quarterly).
# 0941.DE no tiene balance general disponible (anual/quarterly).
# BUDY.DE no tiene balance general disponible (anual/quarterly).
# AIRG.DE no tiene balance general disponible (anual/quarterly).
# HDJA.DE no tiene balance general disponible (anual/quarterly).
# 6762.DE no tiene balance general disponible (anual/quarterly).
# TJH7.DE no tiene balance general disponible (anual/quarterly).
# NNN1Y.DE no tiene balance general disponible (anual/quarterly).
# DISCKC.DE no tiene balance general disponible (anual/quarterly).
# EONGN.DE no tiene balance general disponible (anual/quarterly).
# ELO1.DE no tiene balance general disponible (anual/quarterly).
# CRNT.DE no tiene balance general disponible (anual/quarterly).
# ITRN.DE no tiene balance general disponible (anual/quarterly).
# MLNX.DE no tiene balance general disponible (anual/quarterly).
# 2F5.DE no tiene balance general disponible (anual/quarterly).
# SILC.DE no tiene balance general disponible (anual/quarterly).
# CTCH.DE no tiene balance general disponible (anual/quarterly).
# CPTGY.DE no tiene balance general disponible (anual/quarterly).
# 4TXAY.DE no tiene balance general disponible (anual/quarterly).
# 2EBAY.DE no tiene balance general disponible (anual/quarterly).
# ODHN.DE no tiene balance general disponible (anual/quarterly).
# IMX.DE no tiene balance general disponible (anual/quarterly).
# SAPGY_P.DE no tiene balance general disponible (anual/quarterly).
# VODIY.DE no tiene balance general disponible (anual/quarterly).
# DLGS.DE no tiene balance general disponible (anual/quarterly).
# RR5.DE no tiene balance general disponible (anual/quarterly).
# JENGN.DE no tiene balance general disponible (anual/quarterly).
# GWIG.DE no tiene balance general disponible (anual/quarterly).
# AITN.DE no tiene balance general disponible (anual/quarterly).
# GMMG.DE no tiene balance general disponible (anual/quarterly).
# DRIG.DE no tiene balance general disponible (anual/quarterly).
# BIONN.DE no tiene balance general disponible (anual/quarterly).
# BKP6.DE no tiene balance general disponible (anual/quarterly).
# 1ZD.DE no tiene balance general disponible (anual/quarterly).
# LN3.DE no tiene balance general disponible (anual/quarterly).
# G1V.DE no tiene balance general disponible (anual/quarterly).
# PVR1.DE no tiene balance general disponible (anual/quarterly).
# PXSL.DE no tiene balance general disponible (anual/quarterly).
# ALGR.DE no tiene balance general disponible (anual/quarterly).
# BNRGN.DE no tiene balance general disponible (anual/quarterly).
# FIEG.DE no tiene balance general disponible (anual/quarterly).
# FPE4Y.DE no tiene balance general disponible (anual/quarterly).
# FPEG_P.DE no tiene balance general disponible (anual/quarterly).
# AVD.DE no tiene balance general disponible (anual/quarterly).
# ROSNQA.DE no tiene balance general disponible (anual/quarterly).
# S92G.DE no tiene balance general disponible (anual/quarterly).
# SMHNN.DE no tiene balance general disponible (anual/quarterly).
# VBKG.DE no tiene balance general disponible (anual/quarterly).
# CEPD.DE no tiene balance general disponible (anual/quarterly).
# WHS.DE no tiene balance general disponible (anual/quarterly).
# AQG.DE no tiene balance general disponible (anual/quarterly).
# AAP.DE no tiene balance general disponible (anual/quarterly).
# MYR.DE no tiene balance general disponible (anual/quarterly).
# YM1.DE no tiene balance general disponible (anual/quarterly).
# QRL.DE no tiene balance general disponible (anual/quarterly).
# S2Z.DE no tiene balance general disponible (anual/quarterly).
# T7W.DE no tiene balance general disponible (anual/quarterly).
# G2O.DE no tiene balance general disponible (anual/quarterly).
# RCL.DE no tiene balance general disponible (anual/quarterly).
# 6LA.DE no tiene balance general disponible (anual/quarterly).
# SAN.DE no tiene balance general disponible (anual/quarterly).
# SNC.DE no tiene balance general disponible (anual/quarterly).
# SVO.DE no tiene balance general disponible (anual/quarterly).
# RRTL.DE procesado correctamente.
# VOPA.DE no tiene balance general disponible (anual/quarterly).
# ACGL.DE no tiene balance general disponible (anual/quarterly).
# 9AC.DE no tiene balance general disponible (anual/quarterly).
# AMPP.DE no tiene balance general disponible (anual/quarterly).
# AMRNY.DE no tiene balance general disponible (anual/quarterly).
# 2UH.DE no tiene balance general disponible (anual/quarterly).
# DLBA.DE no tiene balance general disponible (anual/quarterly).
# ATSG.DE no tiene balance general disponible (anual/quarterly).
# DLX.DE procesado correctamente.
# AZPN.DE no tiene balance general disponible (anual/quarterly).
# DNYY.DE no tiene balance general disponible (anual/quarterly).
# BSFA.DE no tiene balance general disponible (anual/quarterly).
# PP4A.DE no tiene balance general disponible (anual/quarterly).
# BRKR.DE no tiene balance general disponible (anual/quarterly).
# CUCA.DE no tiene balance general disponible (anual/quarterly).
# CBOE.DE no tiene balance general disponible (anual/quarterly).
# CENX.DE no tiene balance general disponible (anual/quarterly).
# SIY.DE no tiene balance general disponible (anual/quarterly).
# FDV1.DE no tiene balance general disponible (anual/quarterly).
# CPRT.DE no tiene balance general disponible (anual/quarterly).
# CVLT.DE no tiene balance general disponible (anual/quarterly).
# DECK.DE no tiene balance general disponible (anual/quarterly).
# ENMD.DE no tiene balance general disponible (anual/quarterly).
# ESLT.DE no tiene balance general disponible (anual/quarterly).
# EXEL.DE no tiene balance general disponible (anual/quarterly).
# FOSL.DE no tiene balance general disponible (anual/quarterly).
# GGALYB.DE no tiene balance general disponible (anual/quarterly).
# GLGL.DE no tiene balance general disponible (anual/quarterly).
# G2U.DE no tiene balance general disponible (anual/quarterly).
# G5NA.DE no tiene balance general disponible (anual/quarterly).
# P8S.DE no tiene balance general disponible (anual/quarterly).
# IKIA.DE no tiene balance general disponible (anual/quarterly).
# DSX.DE no tiene balance general disponible (anual/quarterly).
# LECO.DE no tiene balance general disponible (anual/quarterly).
# 33L.DE procesado correctamente.
# M6X2.DE no tiene balance general disponible (anual/quarterly).
# MPEY.DE no tiene balance general disponible (anual/quarterly).
# MYRX.DE no tiene balance general disponible (anual/quarterly).
# NR1A.DE no tiene balance general disponible (anual/quarterly).
# ODFL.DE no tiene balance general disponible (anual/quarterly).
# PBCT.DE no tiene balance general disponible (anual/quarterly).
# PVDA.DE no tiene balance general disponible (anual/quarterly).
# PENN.DE no tiene balance general disponible (anual/quarterly).
# PIGG.DE no tiene balance general disponible (anual/quarterly).
# DUM.DE no tiene balance general disponible (anual/quarterly).
# QY1.DE no tiene balance general disponible (anual/quarterly).
# REED.DE no tiene balance general disponible (anual/quarterly).
# REGN.DE no tiene balance general disponible (anual/quarterly).
# 3T3.DE no tiene balance general disponible (anual/quarterly).
# 4SB.DE no tiene balance general disponible (anual/quarterly).
# SL2.DE no tiene balance general disponible (anual/quarterly).
# SNPS.DE no tiene balance general disponible (anual/quarterly).
# 8SO.DE no tiene balance general disponible (anual/quarterly).
# SWKS.DE no tiene balance general disponible (anual/quarterly).
# RVS1.DE no tiene balance general disponible (anual/quarterly).
# I9DN.DE no tiene balance general disponible (anual/quarterly).
# 37Z.DE no tiene balance general disponible (anual/quarterly).
# TB5.DE no tiene balance general disponible (anual/quarterly).
# T98.DE no tiene balance general disponible (anual/quarterly).
# TRCT.DE no tiene balance general disponible (anual/quarterly).
# TSEM.DE no tiene balance general disponible (anual/quarterly).
# TXM1.DE no tiene balance general disponible (anual/quarterly).
# ULTA.DE no tiene balance general disponible (anual/quarterly).
# UTHR.DE no tiene balance general disponible (anual/quarterly).
# CR3.DE no tiene balance general disponible (anual/quarterly).
# VCC2.DE no tiene balance general disponible (anual/quarterly).
# VRNT.DE no tiene balance general disponible (anual/quarterly).
# VA7A.DE no tiene balance general disponible (anual/quarterly).
# WLBU.DE no tiene balance general disponible (anual/quarterly).
# WPT.DE no tiene balance general disponible (anual/quarterly).
# AJPG.DE no tiene balance general disponible (anual/quarterly).
# FFPP.DE no tiene balance general disponible (anual/quarterly).
# LAGA.DE no tiene balance general disponible (anual/quarterly).
# BICY.DE no tiene balance general disponible (anual/quarterly).
# BKY.DE no tiene balance general disponible (anual/quarterly).
# EQXA.DE no tiene balance general disponible (anual/quarterly).
# WE7.DE no tiene balance general disponible (anual/quarterly).
# EXR2.DE no tiene balance general disponible (anual/quarterly).
# ELYA.DE no tiene balance general disponible (anual/quarterly).
# WEB.DE no tiene balance general disponible (anual/quarterly).
# VALE3.DE no tiene balance general disponible (anual/quarterly).
# PWTN.DE no tiene balance general disponible (anual/quarterly).
# 2HR.DE no tiene balance general disponible (anual/quarterly).
# AOXG.DE no tiene balance general disponible (anual/quarterly).
# AMDG.DE no tiene balance general disponible (anual/quarterly).
# BIOG_P.DE no tiene balance general disponible (anual/quarterly).
# CDBG.DE no tiene balance general disponible (anual/quarterly).
# CEVG.DE no tiene balance general disponible (anual/quarterly).
# CWCG.DE no tiene balance general disponible (anual/quarterly).
# DICN.DE no tiene balance general disponible (anual/quarterly).
# DBANN.DE no tiene balance general disponible (anual/quarterly).
# DUEG.DE no tiene balance general disponible (anual/quarterly).
# EV4G.DE no tiene balance general disponible (anual/quarterly).
# EVDG.DE no tiene balance general disponible (anual/quarterly).
# GLJN.DE no tiene balance general disponible (anual/quarterly).
# GSC1N.DE no tiene balance general disponible (anual/quarterly).
# HABG.DE no tiene balance general disponible (anual/quarterly).
# HAWG.DE no tiene balance general disponible (anual/quarterly).
# HBH.DE procesado correctamente.
# HLGZ.DE no tiene balance general disponible (anual/quarterly).
# INHG.DE no tiene balance general disponible (anual/quarterly).
# JUNG_P.DE no tiene balance general disponible (anual/quarterly).
# KWSG.DE no tiene balance general disponible (anual/quarterly).
# MVVGN.DE no tiene balance general disponible (anual/quarterly).
# NOEJ.DE procesado correctamente.
# O2C.DE no tiene balance general disponible (anual/quarterly).
# PATGN.DE no tiene balance general disponible (anual/quarterly).
# SAXG.DE no tiene balance general disponible (anual/quarterly).
# SCUGE.DE no tiene balance general disponible (anual/quarterly).
# SFQN.DE no tiene balance general disponible (anual/quarterly).
# SIXG.DE no tiene balance general disponible (anual/quarterly).
# SKBG.DE no tiene balance general disponible (anual/quarterly).
# SLTG.DE no tiene balance general disponible (anual/quarterly).
# TEGG.DE no tiene balance general disponible (anual/quarterly).
# TIMAN.DE no tiene balance general disponible (anual/quarterly).
# TTIGN.DE no tiene balance general disponible (anual/quarterly).
# TTKG.DE no tiene balance general disponible (anual/quarterly).
# WACGN.DE no tiene balance general disponible (anual/quarterly).
# ZO1G.DE no tiene balance general disponible (anual/quarterly).
# EVTG.DE no tiene balance general disponible (anual/quarterly).
# NWON.DE no tiene balance general disponible (anual/quarterly).
# PSAGN.DE no tiene balance general disponible (anual/quarterly).
# SBSG.DE no tiene balance general disponible (anual/quarterly).
# GIBG.DE no tiene balance general disponible (anual/quarterly).
# LM.DE no tiene balance general disponible (anual/quarterly).
# T6A.DE procesado correctamente.
# WPEN.DE no tiene balance general disponible (anual/quarterly).
# XY6.DE procesado correctamente.
# AVMR.DE no tiene balance general disponible (anual/quarterly).
# DXCM.DE no tiene balance general disponible (anual/quarterly).
# AVT.DE no tiene balance general disponible (anual/quarterly).
# HG1G.DE no tiene balance general disponible (anual/quarterly).
# AVX.DE no tiene balance general disponible (anual/quarterly).
# UUUG.DE no tiene balance general disponible (anual/quarterly).
# VSCK.DE no tiene balance general disponible (anual/quarterly).
# AAQG.DE no tiene balance general disponible (anual/quarterly).
# APME.DE no tiene balance general disponible (anual/quarterly).
# AZZ.DE no tiene balance general disponible (anual/quarterly).
# ADDG.DE no tiene balance general disponible (anual/quarterly).
# AGXG.DE no tiene balance general disponible (anual/quarterly).
# AAHG.DE no tiene balance general disponible (anual/quarterly).
# B.DE no tiene balance general disponible (anual/quarterly).
# E0P.DE procesado correctamente.
# B8JN.DE no tiene balance general disponible (anual/quarterly).
# AYDGN.DE no tiene balance general disponible (anual/quarterly).
# ACWNN.DE no tiene balance general disponible (anual/quarterly).
# AOFG.DE no tiene balance general disponible (anual/quarterly).
# BSLG.DE no tiene balance general disponible (anual/quarterly).
# BYWG.DE no tiene balance general disponible (anual/quarterly).
# BAH.DE no tiene balance general disponible (anual/quarterly).
# BIOG.DE no tiene balance general disponible (anual/quarterly).
# BTBB.DE no tiene balance general disponible (anual/quarterly).
# BMWG_P.DE no tiene balance general disponible (anual/quarterly).
# BMMG.DE no tiene balance general disponible (anual/quarterly).
# COKG.DE no tiene balance general disponible (anual/quarterly).
# CSHG.DE no tiene balance general disponible (anual/quarterly).
# EBIX.DE no tiene balance general disponible (anual/quarterly).
# CSGG.DE no tiene balance general disponible (anual/quarterly).
# ECHO.DE no tiene balance general disponible (anual/quarterly).
# COPMA.DE no tiene balance general disponible (anual/quarterly).
# 3ER.DE no tiene balance general disponible (anual/quarterly).
# CE2G.DE no tiene balance general disponible (anual/quarterly).
# ECPG.DE no tiene balance general disponible (anual/quarterly).
# BDN.DE no tiene balance general disponible (anual/quarterly).
# DAMG.DE no tiene balance general disponible (anual/quarterly).
# LOUDG.DE no tiene balance general disponible (anual/quarterly).
# DFTKN.DE no tiene balance general disponible (anual/quarterly).
# HNLG.DE no tiene balance general disponible (anual/quarterly).
# DRWG.DE no tiene balance general disponible (anual/quarterly).
# BE4A.DE no tiene balance general disponible (anual/quarterly).
# BGSN.DE no tiene balance general disponible (anual/quarterly).
# EUZG.DE no tiene balance general disponible (anual/quarterly).
# E4CG.DE no tiene balance general disponible (anual/quarterly).
# EING_P.DE no tiene balance general disponible (anual/quarterly).
# EE.DE no tiene balance general disponible (anual/quarterly).
# ELGG.DE no tiene balance general disponible (anual/quarterly).
# ETGG.DE no tiene balance general disponible (anual/quarterly).
# ECXN.DE no tiene balance general disponible (anual/quarterly).
# SQ7B.DE no tiene balance general disponible (anual/quarterly).
# A4Y.DE procesado correctamente.
# EUCAN.DE no tiene balance general disponible (anual/quarterly).
# EWI1.DE no tiene balance general disponible (anual/quarterly).
# EXCL.DE no tiene balance general disponible (anual/quarterly).
# FAAS.DE no tiene balance general disponible (anual/quarterly).
# FVIG.DE no tiene balance general disponible (anual/quarterly).
# SISG.DE no tiene balance general disponible (anual/quarterly).
# FEVG.DE no tiene balance general disponible (anual/quarterly).
# FPHG.DE no tiene balance general disponible (anual/quarterly).
# BID.DE no tiene balance general disponible (anual/quarterly).
# FEWG.DE no tiene balance general disponible (anual/quarterly).
# GMEG.DE no tiene balance general disponible (anual/quarterly).
# GFTG.DE no tiene balance general disponible (anual/quarterly).
# GKSG.DE no tiene balance general disponible (anual/quarterly).
# EFII.DE no tiene balance general disponible (anual/quarterly).
# G7BG.DE no tiene balance general disponible (anual/quarterly).
# BIOA.DE no tiene balance general disponible (anual/quarterly).
# HXCKK.DE no tiene balance general disponible (anual/quarterly).
# HPBGN.DE no tiene balance general disponible (anual/quarterly).
# HNKG.DE no tiene balance general disponible (anual/quarterly).
# HWSAK.DE no tiene balance general disponible (anual/quarterly).
# HBMG.DE no tiene balance general disponible (anual/quarterly).
# HYQGN.DE no tiene balance general disponible (anual/quarterly).
# EG1.DE no tiene balance general disponible (anual/quarterly).
# EGB.DE no tiene balance general disponible (anual/quarterly).
# IXXG.DE no tiene balance general disponible (anual/quarterly).
# EGCA.DE no tiene balance general disponible (anual/quarterly).
# ISHG.DE no tiene balance general disponible (anual/quarterly).
# IS7G.DE no tiene balance general disponible (anual/quarterly).
# IVXG.DE no tiene balance general disponible (anual/quarterly).
# ISRG.DE no tiene balance general disponible (anual/quarterly).
# BKS.DE no tiene balance general disponible (anual/quarterly).
# IVUG.DE no tiene balance general disponible (anual/quarterly).
# EGHT.DE no tiene balance general disponible (anual/quarterly).
# EGOV.DE no tiene balance general disponible (anual/quarterly).
# K1RG.DE no tiene balance general disponible (anual/quarterly).
# KU2G.DE no tiene balance general disponible (anual/quarterly).
# LEIG.DE no tiene balance general disponible (anual/quarterly).
# L1OGK.DE no tiene balance general disponible (anual/quarterly).
# EGVY.DE no tiene balance general disponible (anual/quarterly).
# TGHN.DE procesado correctamente.
# LPKG.DE no tiene balance general disponible (anual/quarterly).
# ECKG.DE no tiene balance general disponible (anual/quarterly).
# EGY.DE no tiene balance general disponible (anual/quarterly).
# MANG_P.DE no tiene balance general disponible (anual/quarterly).
# BKU.DE no tiene balance general disponible (anual/quarterly).
# MZXG.DE no tiene balance general disponible (anual/quarterly).
# MBBG.DE no tiene balance general disponible (anual/quarterly).
# MEDG.DE no tiene balance general disponible (anual/quarterly).
# CEC1_P.DE no tiene balance general disponible (anual/quarterly).
# M3VGN.DE no tiene balance general disponible (anual/quarterly).
# MBQGN.DE no tiene balance general disponible (anual/quarterly).
# MGNK.DE no tiene balance general disponible (anual/quarterly).
# MUBG.DE no tiene balance general disponible (anual/quarterly).
# NEKG.DE no tiene balance general disponible (anual/quarterly).
# NXUG.DE no tiene balance general disponible (anual/quarterly).
# BOH.DE no tiene balance general disponible (anual/quarterly).
# OHBG.DE no tiene balance general disponible (anual/quarterly).
# BRKA.DE no tiene balance general disponible (anual/quarterly).
# O4BG.DE no tiene balance general disponible (anual/quarterly).
# EIG.DE no tiene balance general disponible (anual/quarterly).
# PA8G.DE no tiene balance general disponible (anual/quarterly).
# PGNG.DE no tiene balance general disponible (anual/quarterly).
# RM11.DE no tiene balance general disponible (anual/quarterly).
# PNEGN.DE no tiene balance general disponible (anual/quarterly).
# ELY.DE no tiene balance general disponible (anual/quarterly).
# BRO.DE no tiene balance general disponible (anual/quarterly).
# BW.DE no tiene balance general disponible (anual/quarterly).
# PWOG.DE no tiene balance general disponible (anual/quarterly).
# PUS.DE no tiene balance general disponible (anual/quarterly).
# TPEG.DE no tiene balance general disponible (anual/quarterly).
# SANT1.DE no tiene balance general disponible (anual/quarterly).
# RSL2.DE procesado correctamente.
# RTCG.DE no tiene balance general disponible (anual/quarterly).
# BYD.DE no tiene balance general disponible (anual/quarterly).
# RIB.DE no tiene balance general disponible (anual/quarterly).
# C08.DE no tiene balance general disponible (anual/quarterly).
# RWEG_P.DE no tiene balance general disponible (anual/quarterly).
# ENS.DE no tiene balance general disponible (anual/quarterly).
# SATG.DE no tiene balance general disponible (anual/quarterly).
# SATG_P.DE no tiene balance general disponible (anual/quarterly).
# YSNG.DE no tiene balance general disponible (anual/quarterly).
# C9S.DE no tiene balance general disponible (anual/quarterly).
# F3CG.DE no tiene balance general disponible (anual/quarterly).
# SW1.DE no tiene balance general disponible (anual/quarterly).
# SZZG.DE no tiene balance general disponible (anual/quarterly).
# SIXG_P.DE no tiene balance general disponible (anual/quarterly).
# S4AG.DE no tiene balance general disponible (anual/quarterly).
# SYTG.DE no tiene balance general disponible (anual/quarterly).
# SFXG.DE no tiene balance general disponible (anual/quarterly).
# ENZ.DE no tiene balance general disponible (anual/quarterly).
# CAE.DE no tiene balance general disponible (anual/quarterly).
# SURG.DE no tiene balance general disponible (anual/quarterly).
# EXNGN.DE no tiene balance general disponible (anual/quarterly).
# CALX.DE no tiene balance general disponible (anual/quarterly).
# SYZG.DE no tiene balance general disponible (anual/quarterly).
# TTRGN.DE no tiene balance general disponible (anual/quarterly).
# TGTG.DE no tiene balance general disponible (anual/quarterly).
# TLIG.DE no tiene balance general disponible (anual/quarterly).
# HOC.DE no tiene balance general disponible (anual/quarterly).
# TVDGK.DE no tiene balance general disponible (anual/quarterly).
# US5.DE no tiene balance general disponible (anual/quarterly).
# ULCG.DE no tiene balance general disponible (anual/quarterly).
# UP7G.DE no tiene balance general disponible (anual/quarterly).
# OSPGK.DE no tiene balance general disponible (anual/quarterly).
# ER2N.DE no tiene balance general disponible (anual/quarterly).
# VIBG_P.DE no tiene balance general disponible (anual/quarterly).
# V3VGN.DE no tiene balance general disponible (anual/quarterly).
# WSUG.DE no tiene balance general disponible (anual/quarterly).
# WUGG.DE no tiene balance general disponible (anual/quarterly).
# WUGG_P.DE no tiene balance general disponible (anual/quarterly).
# WL6G.DE no tiene balance general disponible (anual/quarterly).
# WZM.DE no tiene balance general disponible (anual/quarterly).
# YOCG.DE no tiene balance general disponible (anual/quarterly).
# AMA1.DE no tiene balance general disponible (anual/quarterly).
# ZEFG.DE no tiene balance general disponible (anual/quarterly).
# EOCY.DE no tiene balance general disponible (anual/quarterly).
# BR.DE no tiene balance general disponible (anual/quarterly).
# PHGY.DE no tiene balance general disponible (anual/quarterly).
# WX7.DE no tiene balance general disponible (anual/quarterly).
# T6O.DE no tiene balance general disponible (anual/quarterly).
# 2U3.DE procesado correctamente.
# SNH.DE no tiene balance general disponible (anual/quarterly).
# SIX.DE no tiene balance general disponible (anual/quarterly).
# ACC.DE no tiene balance general disponible (anual/quarterly).
# UI51.DE no tiene balance general disponible (anual/quarterly).
# CBL.DE no tiene balance general disponible (anual/quarterly).
# 8CW.DE no tiene balance general disponible (anual/quarterly).
# CNPC.DE no tiene balance general disponible (anual/quarterly).
# F1EF.DE no tiene balance general disponible (anual/quarterly).
# NZT.DE no tiene balance general disponible (anual/quarterly).
# ORPI.DE no tiene balance general disponible (anual/quarterly).
# C0Q.DE no tiene balance general disponible (anual/quarterly).
# CNR.DE no tiene balance general disponible (anual/quarterly).
# QCSB.DE no tiene balance general disponible (anual/quarterly).
# OHI.DE no tiene balance general disponible (anual/quarterly).
# POR.DE no tiene balance general disponible (anual/quarterly).
# AEOS.DE no tiene balance general disponible (anual/quarterly).
# BUEY.DE no tiene balance general disponible (anual/quarterly).
# OII.DE no tiene balance general disponible (anual/quarterly).
# AFG.DE no tiene balance general disponible (anual/quarterly).
# CP.DE no tiene balance general disponible (anual/quarterly).
# CYH.DE no tiene balance general disponible (anual/quarterly).
# IVR.DE no tiene balance general disponible (anual/quarterly).
# RBA.DE no tiene balance general disponible (anual/quarterly).
# SQM.DE no tiene balance general disponible (anual/quarterly).
# B7S.DE no tiene balance general disponible (anual/quarterly).
# GR0A.DE no tiene balance general disponible (anual/quarterly).
# PSRA.DE no tiene balance general disponible (anual/quarterly).
# LTI.DE no tiene balance general disponible (anual/quarterly).
# 9M1N.DE no tiene balance general disponible (anual/quarterly).
# 2600Y.DE no tiene balance general disponible (anual/quarterly).
# ALLD.DE no tiene balance general disponible (anual/quarterly).
# FR.DE no tiene balance general disponible (anual/quarterly).
# CCK.DE no tiene balance general disponible (anual/quarterly).
# NNN.DE no tiene balance general disponible (anual/quarterly).
# SCI.DE no tiene balance general disponible (anual/quarterly).
# AXS.DE no tiene balance general disponible (anual/quarterly).
# 43D.DE no tiene balance general disponible (anual/quarterly).
# 07G.DE no tiene balance general disponible (anual/quarterly).
# H9B1.DE no tiene balance general disponible (anual/quarterly).
# MKO1.DE no tiene balance general disponible (anual/quarterly).
# NCI2.DE no tiene balance general disponible (anual/quarterly).
# PKG.DE no tiene balance general disponible (anual/quarterly).
# SGM.DE procesado correctamente.
# AJGH.DE no tiene balance general disponible (anual/quarterly).
# BCBG.DE no tiene balance general disponible (anual/quarterly).
# CHD.DE no tiene balance general disponible (anual/quarterly).
# DKS.DE no tiene balance general disponible (anual/quarterly).
# HIW.DE no tiene balance general disponible (anual/quarterly).
# WFK.DE no tiene balance general disponible (anual/quarterly).
# LXI.DE no tiene balance general disponible (anual/quarterly).
# C19.DE no tiene balance general disponible (anual/quarterly).
# EXRS.DE no tiene balance general disponible (anual/quarterly).
# MFC.DE no tiene balance general disponible (anual/quarterly).
# AWN.DE no tiene balance general disponible (anual/quarterly).
# AKOYB.DE no tiene balance general disponible (anual/quarterly).
# 4BW.DE no tiene balance general disponible (anual/quarterly).
# CDH1.DE no tiene balance general disponible (anual/quarterly).
# EGG.DE no tiene balance general disponible (anual/quarterly).
# LPX.DE no tiene balance general disponible (anual/quarterly).
# PL6.DE no tiene balance general disponible (anual/quarterly).
# E6Z.DE no tiene balance general disponible (anual/quarterly).
# ARW.DE no tiene balance general disponible (anual/quarterly).
# BFPY.DE no tiene balance general disponible (anual/quarterly).
# CNK.DE no tiene balance general disponible (anual/quarterly).
# CPT.DE no tiene balance general disponible (anual/quarterly).
# DLPA.DE no tiene balance general disponible (anual/quarterly).
# GNRC.DE no tiene balance general disponible (anual/quarterly).
# GNWR.DE no tiene balance general disponible (anual/quarterly).
# MHK.DE no tiene balance general disponible (anual/quarterly).
# RPM.DE no tiene balance general disponible (anual/quarterly).
# AGO.DE no tiene balance general disponible (anual/quarterly).
# ALK.DE no tiene balance general disponible (anual/quarterly).
# AWK.DE no tiene balance general disponible (anual/quarterly).
# 1P6.DE no tiene balance general disponible (anual/quarterly).
# 6CL.DE no tiene balance general disponible (anual/quarterly).
# CVA.DE no tiene balance general disponible (anual/quarterly).
# FAF.DE no tiene balance general disponible (anual/quarterly).
# KSU.DE no tiene balance general disponible (anual/quarterly).
# 6MD.DE no tiene balance general disponible (anual/quarterly).
# R2U.DE no tiene balance general disponible (anual/quarterly).
# RY.DE no tiene balance general disponible (anual/quarterly).
# SLG.DE no tiene balance general disponible (anual/quarterly).
# NWJ.DE no tiene balance general disponible (anual/quarterly).
# H.DE no tiene balance general disponible (anual/quarterly).
# GPN.DE no tiene balance general disponible (anual/quarterly).
# LNT.DE no tiene balance general disponible (anual/quarterly).
# LGAY.DE no tiene balance general disponible (anual/quarterly).
# OAS.DE no tiene balance general disponible (anual/quarterly).
# SIG.DE no tiene balance general disponible (anual/quarterly).
# SKMY.DE no tiene balance general disponible (anual/quarterly).
# DEI.DE no tiene balance general disponible (anual/quarterly).
# HL8.DE no tiene balance general disponible (anual/quarterly).
# KRC.DE no tiene balance general disponible (anual/quarterly).
# KTCY.DE no tiene balance general disponible (anual/quarterly).
# MBTLY.DE no tiene balance general disponible (anual/quarterly).
# O.DE no tiene balance general disponible (anual/quarterly).
# PJ1A.DE no tiene balance general disponible (anual/quarterly).
# 4DH.DE no tiene balance general disponible (anual/quarterly).
# FLOF.DE no tiene balance general disponible (anual/quarterly).
# 2KD.DE no tiene balance general disponible (anual/quarterly).
# OC.DE no tiene balance general disponible (anual/quarterly).
# RYN.DE no tiene balance general disponible (anual/quarterly).
# STGY.DE no tiene balance general disponible (anual/quarterly).
# SU.DE no tiene balance general disponible (anual/quarterly).
# RDEDY.DE no tiene balance general disponible (anual/quarterly).
# EVN.DE no tiene balance general disponible (anual/quarterly).
# NVONY.DE no tiene balance general disponible (anual/quarterly).
# 3SM.DE no tiene balance general disponible (anual/quarterly).
# AZNPY.DE no tiene balance general disponible (anual/quarterly).
# HANB.DE no tiene balance general disponible (anual/quarterly).
# OPK.DE no tiene balance general disponible (anual/quarterly).
# ALLE.DE no tiene balance general disponible (anual/quarterly).
# CHILY.DE no tiene balance general disponible (anual/quarterly).
# Z.DE no tiene balance general disponible (anual/quarterly).
# GRA.DE no tiene balance general disponible (anual/quarterly).
# KMT.DE no tiene balance general disponible (anual/quarterly).
# M6G.DE no tiene balance general disponible (anual/quarterly).
# MARY.DE no tiene balance general disponible (anual/quarterly).
# DG3.DE no tiene balance general disponible (anual/quarterly).
# CLGX.DE no tiene balance general disponible (anual/quarterly).
# 25E.DE no tiene balance general disponible (anual/quarterly).
# HLF.DE no tiene balance general disponible (anual/quarterly).
# HUN.DE no tiene balance general disponible (anual/quarterly).
# MAN.DE no tiene balance general disponible (anual/quarterly).
# MTH.DE no tiene balance general disponible (anual/quarterly).
# QEN.DE no tiene balance general disponible (anual/quarterly).
# ECY.DE no tiene balance general disponible (anual/quarterly).
# ENBD.DE no tiene balance general disponible (anual/quarterly).
# LFLY.DE no tiene balance general disponible (anual/quarterly).
# AWC.DE procesado correctamente.
# BKE.DE no tiene balance general disponible (anual/quarterly).
# C52.DE no tiene balance general disponible (anual/quarterly).
# ECA.DE no tiene balance general disponible (anual/quarterly).
# NERGY.DE no tiene balance general disponible (anual/quarterly).
# GART.DE no tiene balance general disponible (anual/quarterly).
# AAN.DE no tiene balance general disponible (anual/quarterly).
# DOX.DE no tiene balance general disponible (anual/quarterly).
# FR9.DE no tiene balance general disponible (anual/quarterly).
# GES.DE no tiene balance general disponible (anual/quarterly).
# R2RCY.DE no tiene balance general disponible (anual/quarterly).
# AGCO.DE no tiene balance general disponible (anual/quarterly).
# AME.DE no tiene balance general disponible (anual/quarterly).
# D8SY.DE no tiene balance general disponible (anual/quarterly).
# BU3.DE no tiene balance general disponible (anual/quarterly).
# IEXC.DE no tiene balance general disponible (anual/quarterly).
# LEA.DE no tiene balance general disponible (anual/quarterly).
# FBHS.DE no tiene balance general disponible (anual/quarterly).
# PVH.DE no tiene balance general disponible (anual/quarterly).
# SXEA.DE no tiene balance general disponible (anual/quarterly).
# EXPD.DE no tiene balance general disponible (anual/quarterly).
# IDH.DE no tiene balance general disponible (anual/quarterly).
# SIU.DE no tiene balance general disponible (anual/quarterly).
# FPH.DE procesado correctamente.
# JBHT.DE no tiene balance general disponible (anual/quarterly).
# MDRX.DE no tiene balance general disponible (anual/quarterly).
# MCE.DE no tiene balance general disponible (anual/quarterly).
# AUD.DE no tiene balance general disponible (anual/quarterly).
# FCXB.DE no tiene balance general disponible (anual/quarterly).
# MXIM.DE no tiene balance general disponible (anual/quarterly).
# SFER.DE no tiene balance general disponible (anual/quarterly).
# ALXN.DE no tiene balance general disponible (anual/quarterly).
# ERA.DE no tiene balance general disponible (anual/quarterly).
# FIS.DE no tiene balance general disponible (anual/quarterly).
# GGGA.DE no tiene balance general disponible (anual/quarterly).
# IAG.DE no tiene balance general disponible (anual/quarterly).
# IC1H.DE no tiene balance general disponible (anual/quarterly).
# PEG.DE no tiene balance general disponible (anual/quarterly).
# PTMA.DE no tiene balance general disponible (anual/quarterly).
# APD.DE no tiene balance general disponible (anual/quarterly).
# RF6.DE no tiene balance general disponible (anual/quarterly).
# CVAG.DE no tiene balance general disponible (anual/quarterly).
# DISCA.DE no tiene balance general disponible (anual/quarterly).
# YC51.DE no tiene balance general disponible (anual/quarterly).
# GWI2K.DE no tiene balance general disponible (anual/quarterly).
# HHFGN.DE no tiene balance general disponible (anual/quarterly).
# HIG.DE no tiene balance general disponible (anual/quarterly).
# JEC.DE no tiene balance general disponible (anual/quarterly).
# CAP.DE no tiene balance general disponible (anual/quarterly).
# MRVL.DE no tiene balance general disponible (anual/quarterly).
# YULC.DE no tiene balance general disponible (anual/quarterly).
# AIV1.DE no tiene balance general disponible (anual/quarterly).
# AEDAY.DE no tiene balance general disponible (anual/quarterly).
# CBAX.DE no tiene balance general disponible (anual/quarterly).
# CHRW.DE no tiene balance general disponible (anual/quarterly).
# DFS.DE no tiene balance general disponible (anual/quarterly).
# FHN.DE no tiene balance general disponible (anual/quarterly).
# NAB.DE no tiene balance general disponible (anual/quarterly).
# 4I1.DE procesado correctamente.
# TEVAY.DE no tiene balance general disponible (anual/quarterly).
# UPS.DE no tiene balance general disponible (anual/quarterly).
# WP2A.DE no tiene balance general disponible (anual/quarterly).
# ATI.DE no tiene balance general disponible (anual/quarterly).
# C9F.DE no tiene balance general disponible (anual/quarterly).
# HBAN.DE no tiene balance general disponible (anual/quarterly).
# KCN.DE no tiene balance general disponible (anual/quarterly).
# LSP.DE no tiene balance general disponible (anual/quarterly).
# MMC.DE no tiene balance general disponible (anual/quarterly).
# NOV.DE procesado correctamente.
# 19O.DE no tiene balance general disponible (anual/quarterly).
# PNW.DE no tiene balance general disponible (anual/quarterly).
# RDO.DE no tiene balance general disponible (anual/quarterly).
# STZ.DE no tiene balance general disponible (anual/quarterly).
# VAR.DE no tiene balance general disponible (anual/quarterly).
# VRTX.DE no tiene balance general disponible (anual/quarterly).
# VZ.DE no tiene balance general disponible (anual/quarterly).
# DY2.DE no tiene balance general disponible (anual/quarterly).
# ADM.DE procesado correctamente.
# AVB.DE no tiene balance general disponible (anual/quarterly).
# BLD.DE no tiene balance general disponible (anual/quarterly).
# BPSI.DE no tiene balance general disponible (anual/quarterly).
# CDNS.DE no tiene balance general disponible (anual/quarterly).
# CHKP.DE no tiene balance general disponible (anual/quarterly).
# CINF.DE no tiene balance general disponible (anual/quarterly).
# DO.DE no tiene balance general disponible (anual/quarterly).
# FIIU.DE no tiene balance general disponible (anual/quarterly).
# GT.DE no tiene balance general disponible (anual/quarterly).
# HMTA.DE no tiene balance general disponible (anual/quarterly).
# IFF.DE no tiene balance general disponible (anual/quarterly).
# IIJIY.DE no tiene balance general disponible (anual/quarterly).
# ITRK.DE no tiene balance general disponible (anual/quarterly).
# LH.DE no tiene balance general disponible (anual/quarterly).
# 54M.DE no tiene balance general disponible (anual/quarterly).
# PFGF.DE no tiene balance general disponible (anual/quarterly).
# PXD.DE no tiene balance general disponible (anual/quarterly).
# SFF.DE no tiene balance general disponible (anual/quarterly).
# S5YA.DE no tiene balance general disponible (anual/quarterly).
# NY7.DE no tiene balance general disponible (anual/quarterly).
# TEP.DE no tiene balance general disponible (anual/quarterly).
# A.DE no tiene balance general disponible (anual/quarterly).
# A4S.DE no tiene balance general disponible (anual/quarterly).
# ANF.DE no tiene balance general disponible (anual/quarterly).
# CPW.DE no tiene balance general disponible (anual/quarterly).
# CTSH.DE no tiene balance general disponible (anual/quarterly).
# FITB.DE no tiene balance general disponible (anual/quarterly).
# IC2.DE no tiene balance general disponible (anual/quarterly).
# LBL.DE no tiene balance general disponible (anual/quarterly).
# MCHP.DE no tiene balance general disponible (anual/quarterly).
# MPN.DE no tiene balance general disponible (anual/quarterly).
# NTRS.DE no tiene balance general disponible (anual/quarterly).
# PUFCX.DE no tiene balance general disponible (anual/quarterly).
# PTEN.DE no tiene balance general disponible (anual/quarterly).
# SIH.DE no tiene balance general disponible (anual/quarterly).
# TMO.DE no tiene balance general disponible (anual/quarterly).
# X.DE no tiene balance general disponible (anual/quarterly).
# AEP.DE no tiene balance general disponible (anual/quarterly).
# AIG.DE no tiene balance general disponible (anual/quarterly).
# AKAM.DE no tiene balance general disponible (anual/quarterly).
# BXB.DE no tiene balance general disponible (anual/quarterly).
# GK6.DE no tiene balance general disponible (anual/quarterly).
# 4CR1.DE no tiene balance general disponible (anual/quarterly).
# CLVG.DE no tiene balance general disponible (anual/quarterly).
# CVN.DE no tiene balance general disponible (anual/quarterly).
# DP5.DE no tiene balance general disponible (anual/quarterly).
# ED.DE no tiene balance general disponible (anual/quarterly).
# GVP1.DE no tiene balance general disponible (anual/quarterly).
# GS.DE no tiene balance general disponible (anual/quarterly).
# ITW.DE no tiene balance general disponible (anual/quarterly).
# PNC.DE no tiene balance general disponible (anual/quarterly).
# QBE.DE no tiene balance general disponible (anual/quarterly).
# REDYY.DE no tiene balance general disponible (anual/quarterly).
# RWL.DE no tiene balance general disponible (anual/quarterly).
# SGH.DE no tiene balance general disponible (anual/quarterly).
# STI.DE no tiene balance general disponible (anual/quarterly).
# ABEC.DE procesado correctamente.
# ADYA.DE no tiene balance general disponible (anual/quarterly).
# AMD.DE procesado correctamente.
# BDX.DE no tiene balance general disponible (anual/quarterly).
# BEN.DE no tiene balance general disponible (anual/quarterly).
# BN9.DE no tiene balance general disponible (anual/quarterly).
# BLY.DE no tiene balance general disponible (anual/quarterly).
# BSXU.DE no tiene balance general disponible (anual/quarterly).
# CF.DE no tiene balance general disponible (anual/quarterly).
# CHK.DE no tiene balance general disponible (anual/quarterly).
# CIRX.DE no tiene balance general disponible (anual/quarterly).
# CNP.DE no tiene balance general disponible (anual/quarterly).
# D.DE no tiene balance general disponible (anual/quarterly).
# TDSC.DE no tiene balance general disponible (anual/quarterly).
# DRI.DE no tiene balance general disponible (anual/quarterly).
# ETFC.DE no tiene balance general disponible (anual/quarterly).
# FMG.DE no tiene balance general disponible (anual/quarterly).
# FM.DE no tiene balance general disponible (anual/quarterly).
# GNW.DE no tiene balance general disponible (anual/quarterly).
# G9KB.DE no tiene balance general disponible (anual/quarterly).
# HLS.DE no tiene balance general disponible (anual/quarterly).
# ISRGD.DE no tiene balance general disponible (anual/quarterly).
# KLAC.DE no tiene balance general disponible (anual/quarterly).
# 471A.DE no tiene balance general disponible (anual/quarterly).
# 8MP.DE no tiene balance general disponible (anual/quarterly).
# MTFTY.DE no tiene balance general disponible (anual/quarterly).
# FPO.DE no tiene balance general disponible (anual/quarterly).
# 1BF.DE no tiene balance general disponible (anual/quarterly).
# RF.DE no tiene balance general disponible (anual/quarterly).
# RIM.DE no tiene balance general disponible (anual/quarterly).
# DLLNG.DE no tiene balance general disponible (anual/quarterly).
# ...
# NAUTN.L no tiene balance general disponible (anual/quarterly).
# HGM.L no tiene balance general disponible (anual/quarterly).
# DEMG.L no tiene balance general disponible (anual/quarterly).
# AGY.L procesado correctamente.
# UCG.L no tiene balance general disponible (anual/quarterly).
# BOUB.L no tiene balance general disponible (anual/quarterly).
# TRX.L procesado correctamente.
# PTCM.L no tiene balance general disponible (anual/quarterly).
# MFX.L procesado correctamente.
# IIP.L procesado correctamente.
# FCRM.L no tiene balance general disponible (anual/quarterly).
# ATT.L procesado correctamente.
# TELT.L no tiene balance general disponible (anual/quarterly).
# BPET.L no tiene balance general disponible (anual/quarterly).
# HUW.L procesado correctamente.
# LVCG.L no tiene balance general disponible (anual/quarterly).
# CKT.L procesado correctamente.
# LOGP.L procesado correctamente.
# PFP.L no tiene balance general disponible (anual/quarterly).
# CAML.L procesado correctamente.
# YOLO.L no tiene balance general disponible (anual/quarterly).
# HNE.L no tiene balance general disponible (anual/quarterly).
# ATS.L procesado correctamente.
# KDNC.L procesado correctamente.
# AMAMP.L no tiene balance general disponible (anual/quarterly).
# SRC.L procesado correctamente.
# AEGR.L no tiene balance general disponible (anual/quarterly).
# PALO.L no tiene balance general disponible (anual/quarterly).
# ADL.L no tiene balance general disponible (anual/quarterly).
# JZCP.L procesado correctamente.
# TSG.L no tiene balance general disponible (anual/quarterly).
# ATYM.L procesado correctamente.
# HDT.L no tiene balance general disponible (anual/quarterly).
# BIOM.L no tiene balance general disponible (anual/quarterly).
# WHI.L procesado correctamente.
# DBOX.L procesado correctamente.
# AMO.L no tiene balance general disponible (anual/quarterly).
# AAZ.L procesado correctamente.
# RRR.L procesado correctamente.
# MPAYM.L no tiene balance general disponible (anual/quarterly).
# HZM.L no tiene balance general disponible (anual/quarterly).
# PANR.L procesado correctamente.
# OPG.L procesado correctamente.
# BREE.L procesado correctamente.
# IAT.L no tiene balance general disponible (anual/quarterly).
# B4S.L no tiene balance general disponible (anual/quarterly).
# RLDR.L no tiene balance general disponible (anual/quarterly).
# TSTRE.L no tiene balance general disponible (anual/quarterly).
# MAFL.L procesado correctamente.
# SMLP.L no tiene balance general disponible (anual/quarterly).
# SPDI.L procesado correctamente.
# CRSL.L no tiene balance general disponible (anual/quarterly).
# MTL.L procesado correctamente.
# WATRI.L no tiene balance general disponible (anual/quarterly).
# BRDY.L no tiene balance general disponible (anual/quarterly).
# LOK.L no tiene balance general disponible (anual/quarterly).
# JDG.L procesado correctamente.
# JIM.L procesado correctamente.
# PHC.L no tiene balance general disponible (anual/quarterly).
# SRES.L procesado correctamente.
# REAT.L procesado correctamente.
# ORR.L procesado correctamente.
# GLR.L procesado correctamente.
# AVO.L no tiene balance general disponible (anual/quarterly).
# CNKS.L no tiene balance general disponible (anual/quarterly).
# ZOO.L procesado correctamente.
# SYS1.L procesado correctamente.
# WSG.L procesado correctamente.
# ORCP.L procesado correctamente.
# MSYS.L no tiene balance general disponible (anual/quarterly).
# SOM.L procesado correctamente.
# CGH.L no tiene balance general disponible (anual/quarterly).
# ALY.L no tiene balance general disponible (anual/quarterly).
# FSJ.L procesado correctamente.
# HFG.L procesado correctamente.
# BODP.L no tiene balance general disponible (anual/quarterly).
# FDPF.L no tiene balance general disponible (anual/quarterly).
# FIPPG.L no tiene balance general disponible (anual/quarterly).
# STBS.L no tiene balance general disponible (anual/quarterly).
# BLPU.L no tiene balance general disponible (anual/quarterly).
# BLUS.L no tiene balance general disponible (anual/quarterly).
# RLE.L procesado correctamente.
# ARSA.L no tiene balance general disponible (anual/quarterly).
# JLP.L procesado correctamente.
# ANCR.L procesado correctamente.
# SRSP.L no tiene balance general disponible (anual/quarterly).
# AXM.L no tiene balance general disponible (anual/quarterly).
# ACPA.L no tiene balance general disponible (anual/quarterly).
# KZG.L procesado correctamente.
# DSG.L procesado correctamente.
# BOTB.L no tiene balance general disponible (anual/quarterly).
# GDRG.L no tiene balance general disponible (anual/quarterly).
# SYNS.L no tiene balance general disponible (anual/quarterly).
# MOGP.L no tiene balance general disponible (anual/quarterly).
# DOTD.L procesado correctamente.
# THRU.L procesado correctamente.
# HGT.L procesado correctamente.
# MCKS.L no tiene balance general disponible (anual/quarterly).
# EDLE.L no tiene balance general disponible (anual/quarterly).
# EMPR.L no tiene balance general disponible (anual/quarterly).
# PRR.L no tiene balance general disponible (anual/quarterly).
# WNRG.L no tiene balance general disponible (anual/quarterly).
# ZOLQ.L no tiene balance general disponible (anual/quarterly).
# RICA_P.L no tiene balance general disponible (anual/quarterly).
# LEAF.L no tiene balance general disponible (anual/quarterly).
# MBLT.L no tiene balance general disponible (anual/quarterly).
# GHH.L procesado correctamente.
# IGP.L procesado correctamente.
# N4P.L procesado correctamente.
# CCT.L procesado correctamente.
# GRL.L procesado correctamente.
# SAR.L procesado correctamente.
# CNGC.L no tiene balance general disponible (anual/quarterly).
# STAF.L procesado correctamente.
# SND.L no tiene balance general disponible (anual/quarterly).
# CLON.L procesado correctamente.
# SJH.L no tiene balance general disponible (anual/quarterly).
# GATC.L procesado correctamente.
# AFS.L no tiene balance general disponible (anual/quarterly).
# SALVS.L no tiene balance general disponible (anual/quarterly).
# ZIOC.L procesado correctamente.
# CSRT.L no tiene balance general disponible (anual/quarterly).
# VTC.L no tiene balance general disponible (anual/quarterly).
# CINE.L no tiene balance general disponible (anual/quarterly).
# ARGR.L no tiene balance general disponible (anual/quarterly).
# IMGE.L no tiene balance general disponible (anual/quarterly).
# ACCI.L no tiene balance general disponible (anual/quarterly).
# RED.L no tiene balance general disponible (anual/quarterly).
# BIDS.L no tiene balance general disponible (anual/quarterly).
# ARCMA.L no tiene balance general disponible (anual/quarterly).
# BURF.L no tiene balance general disponible (anual/quarterly).
# EGRE.L no tiene balance general disponible (anual/quarterly).
# INSEI.L no tiene balance general disponible (anual/quarterly).
# LSR.L no tiene balance general disponible (anual/quarterly).
# CRU.L procesado correctamente.
# PMG.L procesado correctamente.
# BEM.L procesado correctamente.
# FUM.L procesado correctamente.
# HYR.L no tiene balance general disponible (anual/quarterly).
# ALT.L procesado correctamente.
# PCA.L procesado correctamente.
# ARDN.L no tiene balance general disponible (anual/quarterly).
# CERP.L no tiene balance general disponible (anual/quarterly).
# CASPC.L no tiene balance general disponible (anual/quarterly).
# LTGL.L no tiene balance general disponible (anual/quarterly).
# ORM.L no tiene balance general disponible (anual/quarterly).
# UFO.L procesado correctamente.
# KIT.L no tiene balance general disponible (anual/quarterly).
# LWI.L procesado correctamente.
# FOUR.L procesado correctamente.
# RWA.L procesado correctamente.
# GAGO.L no tiene balance general disponible (anual/quarterly).
# HERS.L no tiene balance general disponible (anual/quarterly).
# GGPL.L no tiene balance general disponible (anual/quarterly).
# ETXP.L no tiene balance general disponible (anual/quarterly).
# SAGS.L no tiene balance general disponible (anual/quarterly).
# CMBC.L no tiene balance general disponible (anual/quarterly).
# ID2A.L no tiene balance general disponible (anual/quarterly).
# IQG.L no tiene balance general disponible (anual/quarterly).
# APT.L no tiene balance general disponible (anual/quarterly).
# RHL.L no tiene balance general disponible (anual/quarterly).
# CFX.L procesado correctamente.
# SOG.L no tiene balance general disponible (anual/quarterly).
# TCN.L no tiene balance general disponible (anual/quarterly).
# ROSER.L no tiene balance general disponible (anual/quarterly).
# MLVN.L procesado correctamente.
# RGM.L no tiene balance general disponible (anual/quarterly).
# VRP.L no tiene balance general disponible (anual/quarterly).
# XTR.L procesado correctamente.
# LND.L procesado correctamente.
# CYAN.L procesado correctamente.
# ADT.L no tiene balance general disponible (anual/quarterly).
# PHD.L no tiene balance general disponible (anual/quarterly).
# NTBR.L procesado correctamente.
# CALL.L no tiene balance general disponible (anual/quarterly).
# KEFI.L procesado correctamente.
# TYMN.L no tiene balance general disponible (anual/quarterly).
# PGRP.L no tiene balance general disponible (anual/quarterly).
# STCM.L procesado correctamente.
# BUT.L procesado correctamente.
# MKLW.L no tiene balance general disponible (anual/quarterly).
# SHRS.L procesado correctamente.
# CAU.L procesado correctamente.
# MWEE.L no tiene balance general disponible (anual/quarterly).
# PETA.L no tiene balance general disponible (anual/quarterly).
# NAK.L no tiene balance general disponible (anual/quarterly).
# TFW.L procesado correctamente.
# MXCP.L no tiene balance general disponible (anual/quarterly).
# SUMM.L no tiene balance general disponible (anual/quarterly).
# UKR.L procesado correctamente.
# GTC.L procesado correctamente.
# DRV.L no tiene balance general disponible (anual/quarterly).
# VNET.L procesado correctamente.
# VTU.L procesado correctamente.
# ASH.L no tiene balance general disponible (anual/quarterly).
# MWG.L no tiene balance general disponible (anual/quarterly).
# LWRF.L no tiene balance general disponible (anual/quarterly).
# TND.L procesado correctamente.
# WBI.L procesado correctamente.
# GVC.L no tiene balance general disponible (anual/quarterly).
# GEOG.L no tiene balance general disponible (anual/quarterly).
# RAV.L no tiene balance general disponible (anual/quarterly).
# TRS.L no tiene balance general disponible (anual/quarterly).
# AVTG.L no tiene balance general disponible (anual/quarterly).
# WRESW.L no tiene balance general disponible (anual/quarterly).
# ASCR.L no tiene balance general disponible (anual/quarterly).
# ARNR.L no tiene balance general disponible (anual/quarterly).
# ECRE.L no tiene balance general disponible (anual/quarterly).
# ILND.L no tiene balance general disponible (anual/quarterly).
# CNDR.L no tiene balance general disponible (anual/quarterly).
# MAIH.L no tiene balance general disponible (anual/quarterly).
# MURG.L no tiene balance general disponible (anual/quarterly).
# ROCKR.L no tiene balance general disponible (anual/quarterly).
# ZAMB.L no tiene balance general disponible (anual/quarterly).
# EVRH.L no tiene balance general disponible (anual/quarterly).
# SRO.L no tiene balance general disponible (anual/quarterly).
# SOLI.L procesado correctamente.
# LID.L no tiene balance general disponible (anual/quarterly).
# SAA.L procesado correctamente.
# CLL.L no tiene balance general disponible (anual/quarterly).
# SRB.L procesado correctamente.
# KIBO.L procesado correctamente.
# MATD.L procesado correctamente.
# MBO.L procesado correctamente.
# AVON.L procesado correctamente.
# LWB.L no tiene balance general disponible (anual/quarterly).
# MAJE.L procesado correctamente.
# HAN.L procesado correctamente.
# M2Z.L no tiene balance general disponible (anual/quarterly).
# ALAPH.L no tiene balance general disponible (anual/quarterly).
# TOWR.L no tiene balance general disponible (anual/quarterly).
# EMEL.L no tiene balance general disponible (anual/quarterly).
# SOSS.L no tiene balance general disponible (anual/quarterly).
# CNCTC.L no tiene balance general disponible (anual/quarterly).
# CTEA.L no tiene balance general disponible (anual/quarterly).
# PURE.L no tiene balance general disponible (anual/quarterly).
# CMH.L no tiene balance general disponible (anual/quarterly).
# AVG.L procesado correctamente.
# IMM.L procesado correctamente.
# PUR.L no tiene balance general disponible (anual/quarterly).
# BLTGB.L no tiene balance general disponible (anual/quarterly).
# DTG.L no tiene balance general disponible (anual/quarterly).
# ABAL.L no tiene balance general disponible (anual/quarterly).
# CLPC.L no tiene balance general disponible (anual/quarterly).
# OVB.L procesado correctamente.
# URU.L procesado correctamente.
# BOOT.L procesado correctamente.
# RBDR.L no tiene balance general disponible (anual/quarterly).
# PYSM.L no tiene balance general disponible (anual/quarterly).
# UKOGA.L no tiene balance general disponible (anual/quarterly).
# AFEN.L no tiene balance general disponible (anual/quarterly).
# JWNG.L no tiene balance general disponible (anual/quarterly).
# ARGOA.L no tiene balance general disponible (anual/quarterly).
# MTWL.L no tiene balance general disponible (anual/quarterly).
# MOSE.L no tiene balance general disponible (anual/quarterly).
# RQE.L no tiene balance general disponible (anual/quarterly).
# WYWYN.L no tiene balance general disponible (anual/quarterly).
# VITA.L no tiene balance general disponible (anual/quarterly).
# GUS.L no tiene balance general disponible (anual/quarterly).
# NWF.L procesado correctamente.
# SIXH.L no tiene balance general disponible (anual/quarterly).
# ITM.L procesado correctamente.
# SOU.L procesado correctamente.
# MUBL.L no tiene balance general disponible (anual/quarterly).
# DCD.L no tiene balance general disponible (anual/quarterly).
# CRW.L procesado correctamente.
# CVSG.L procesado correctamente.
# NUOG.L no tiene balance general disponible (anual/quarterly).
# LSAI.L no tiene balance general disponible (anual/quarterly).
# DPP.L procesado correctamente.
# FTC.L procesado correctamente.
# IHC.L procesado correctamente.
# AGTAR.L no tiene balance general disponible (anual/quarterly).
# INDII.L no tiene balance general disponible (anual/quarterly).
# STMG.L no tiene balance general disponible (anual/quarterly).
# EBQ.L procesado correctamente.
# ZYT.L no tiene balance general disponible (anual/quarterly).
# ZIN.L procesado correctamente.
# TAVI.L procesado correctamente.
# LTHM.L procesado correctamente.
# SPA.L procesado correctamente.
# SOLO.L no tiene balance general disponible (anual/quarterly).
# CTPC.L no tiene balance general disponible (anual/quarterly).
# CKN.L procesado correctamente.
# CSN.L procesado correctamente.
# IPO.L procesado correctamente.
# SWGS.L no tiene balance general disponible (anual/quarterly).
# GLDP.L no tiene balance general disponible (anual/quarterly).
# OTM.L no tiene balance general disponible (anual/quarterly).
# TLY.L no tiene balance general disponible (anual/quarterly).
# YGEN.L no tiene balance general disponible (anual/quarterly).
# RUR.L no tiene balance general disponible (anual/quarterly).
# HDD.L procesado correctamente.
# TSTL.L procesado correctamente.
# BYOT.L procesado correctamente.
# NASA.L no tiene balance general disponible (anual/quarterly).
# SOLG.L procesado correctamente.
# ASTO.L no tiene balance general disponible (anual/quarterly).
# PEB.L procesado correctamente.
# GDWN.L procesado correctamente.
# MCB.L procesado correctamente.
# RCDO.L procesado correctamente.
# KCT.L no tiene balance general disponible (anual/quarterly).
# NXR.L procesado correctamente.
# TPG.L no tiene balance general disponible (anual/quarterly).
# SHAN.L no tiene balance general disponible (anual/quarterly).
# THRL.L procesado correctamente.
# ANP.L procesado correctamente.
# RSTP.L no tiene balance general disponible (anual/quarterly).
# SSY.L no tiene balance general disponible (anual/quarterly).
# AUG.L no tiene balance general disponible (anual/quarterly).
# CHRT.L procesado correctamente.
# YOU.L procesado correctamente.
# IBPO.L no tiene balance general disponible (anual/quarterly).
# FST.L no tiene balance general disponible (anual/quarterly).
# RNO.L procesado correctamente.
# KRS.L procesado correctamente.
# INS.L no tiene balance general disponible (anual/quarterly).
# VALX.L no tiene balance general disponible (anual/quarterly).
# HNTS.L no tiene balance general disponible (anual/quarterly).
# NBB.L procesado correctamente.
# MIRA.L no tiene balance general disponible (anual/quarterly).
