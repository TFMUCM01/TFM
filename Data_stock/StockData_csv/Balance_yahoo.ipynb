# %% [markdown]
# ### Balance geneal

# %%
import re
import time
import pandas as pd
import yfinance as yf
from difflib import get_close_matches

def norm(s: str) -> str:
    return re.sub(r'[^a-z0-9]', '', str(s).lower())

def best_match(target_norm: str, candidates_norm: dict) -> str | None:
    if target_norm in candidates_norm:
        return target_norm
    m = get_close_matches(target_norm, list(candidates_norm.keys()), n=1, cutoff=0.84)
    if m:
        return m[0]
    for c in candidates_norm:
        if target_norm in c or c in target_norm:
            return c
    return None

def to_millions(x):
    try:
        val = float(x)
        return round(val / 1_000_000, 2)
    except (TypeError, ValueError):
        return None

df_tickers = pd.read_csv("Tickets_componentes_indices.csv", sep=None, engine="python")
tickers = (
    df_tickers["ticker_market"]
    .dropna()
    .astype(str)
    .str.strip()
    .unique()
    .tolist()
)

balance_general_keys = [
    # ACTIVOS
    "cashAndCashEquivalents",
    "shortTermInvestments",
    "netReceivables",
    "inventory",
    "prepaidExpenses",
    "otherCurrentAssets",
    "propertyPlantEquipment",
    "intangibleAssets",
    "goodwill",
    "longTermInvestments",
    "deferredTaxAssets",
    "otherNonCurrentAssets",

    # PASIVOS
    "accountsPayable",
    "shortLongTermDebt",
    "accruedLiabilities",
    "incomeTaxesPayable",
    "otherCurrentLiabilities",
    "longTermDebt",
    "capitalLeaseObligations",
    "deferredTaxLiabilities",
    "otherNonCurrentLiabilities",

    # PATRIMONIO NETO
    "commonStock",
    "retainedEarnings",
    "netIncome",
    "accumulatedOtherComprehensiveIncome",
    "treasuryStock",
    "totalStockholderEquity",
]

balance_general_dict = {}

for ti in tickers:
    retry = 3
    while retry > 0:
        try:
            t = yf.Ticker(ti)
            bs = t.balance_sheet
            if bs is None or bs.empty:
                bs = t.quarterly_balance_sheet

            if bs is None or bs.empty:
                print(f"{ti} no tiene balance general disponible (anual/quarterly).")
                break
            last_period = bs.columns[0]
            norm_index_map = {norm(idx): idx for idx in bs.index}

            data_balance = {}
            for key in balance_general_keys:
                nk = norm(key)
                match_norm = best_match(nk, norm_index_map)
                if match_norm is None:
                    data_balance[key] = None
                    continue
                yahoo_label = norm_index_map[match_norm]
                value = bs.loc[yahoo_label, last_period]
                data_balance[key] = to_millions(value)

            balance_general_dict[ti] = data_balance
            print(f"{ti} procesado correctamente.")
            break

        except Exception as e:
            msg = str(e).lower()
            if "too many requests" in msg or "rate limit" in msg:
                retry -= 1
                wait_time = 10
                print(f"Rate limit detectado para {ti}. Esperando {wait_time}s. Intentos restantes: {retry}")
                time.sleep(wait_time)
            else:
                print(f"Error al procesar {ti}: {e}")
                break

    time.sleep(1)

df_balance_general = pd.DataFrame.from_dict(balance_general_dict, orient='index')
df_balance_general.index.name = "Empresa"
outfile = "balances_generales12.csv"
df_balance_general.to_csv(outfile)
print(f"Archivo guardado como {outfile}")
# Out:
# AIR.PA procesado correctamente.
# VIV.PA procesado correctamente.
# STM.PA no tiene balance general disponible (anual/quarterly).
# VIE.PA procesado correctamente.
# SAF.PA procesado correctamente.
# BVI.PA procesado correctamente.
# EDEN.PA procesado correctamente.
# INGA.AS procesado correctamente.
# ASMI.AS no tiene balance general disponible (anual/quarterly).
# RAND.AS procesado correctamente.
# AD.AS procesado correctamente.
# MT.AS procesado correctamente.
# KPN.AS procesado correctamente.
# ASML.AS procesado correctamente.
# BESI.AS procesado correctamente.
# NN.AS procesado correctamente.
# IMCD.AS procesado correctamente.
# ASRNL.AS procesado correctamente.
# UNA.AS procesado correctamente.
# ADYEN.AS procesado correctamente.
# PRX.AS procesado correctamente.
# CFR.SW procesado correctamente.
# ABBN.SW procesado correctamente.
# LOGN.SW procesado correctamente.
# ZURN.SW procesado correctamente.
# SLHN.SW procesado correctamente.
# NOVN.SW procesado correctamente.
# NESN.SW procesado correctamente.
# ROG.SW procesado correctamente.
# LONN.SW procesado correctamente.
# SCMN.SW procesado correctamente.
# GEBN.SW procesado correctamente.
# SIKA.SW procesado correctamente.
# PGHN.SW procesado correctamente.
# KNIN.SW procesado correctamente.
# SOON.SW procesado correctamente.
# UBSG.SW procesado correctamente.
# GIVN.SW procesado correctamente.
# BOL.ST procesado correctamente.
# AZN.ST procesado correctamente.
# ALFA.ST procesado correctamente.
# ABB.ST procesado correctamente.
# SAND.ST procesado correctamente.
# TELIA.ST procesado correctamente.
# ACS.MC procesado correctamente.
# ACX.MC procesado correctamente.
# BBVA.MC procesado correctamente.
# BKT.MC procesado correctamente.
# ANA.MC procesado correctamente.
# CABK.MC procesado correctamente.
# NTGY.MC procesado correctamente.
# FER.MC procesado correctamente.
# ITX.MC procesado correctamente.
# REP.MC procesado correctamente.
# IBE.MC procesado correctamente.
# IDR.MC procesado correctamente.
# MAP.MC procesado correctamente.
# TEF.MC procesado correctamente.
# SCYR.MC procesado correctamente.
# SAN.MC procesado correctamente.
# COL.MC procesado correctamente.
# ELE.MC procesado correctamente.
# ROVI.MC procesado correctamente.
# MTS.MC procesado correctamente.
# MRL.MC procesado correctamente.
# LOG.MC procesado correctamente.
# AENA.MC procesado correctamente.
# CLNX.MC procesado correctamente.
# UNI.MC procesado correctamente.
# SRG.MI procesado correctamente.
# PIRC.MI procesado correctamente.
# PRY.MI procesado correctamente.
# ISP.MI procesado correctamente.
# BMED.MI procesado correctamente.
# ENI.MI procesado correctamente.
# BMPS.MI procesado correctamente.
# BZU.MI procesado correctamente.
# TRN.MI procesado correctamente.
# BAMI.MI procesado correctamente.
# LDO.MI procesado correctamente.
# MONC.MI procesado correctamente.
# FBK.MI procesado correctamente.
# PST.MI procesado correctamente.
# RACE.MI procesado correctamente.
# IG.MI procesado correctamente.
# Archivo guardado como balances_generales12.csv

# %%
import pandas as pd
import yfinance as yf
import time

df_tickers = pd.read_csv("Ticketsvalidos.csv", sep=None, engine="python")
tickers = df_tickers["ticker_market"].dropna().astype(str).str.strip().unique().tolist()

balance_general_keys = [
    # ACTIVOS
    "cashAndCashEquivalents",
    "shortTermInvestments",
    "netReceivables",
    "inventory",
    "prepaidExpenses",
    "otherCurrentAssets",
    "propertyPlantEquipment",
    "intangibleAssets",
    "goodwill",
    "longTermInvestments",
    "deferredTaxAssets",
    "otherNonCurrentAssets",

    # PASIVOS
    "accountsPayable",
    "shortLongTermDebt",
    "accruedLiabilities",
    "incomeTaxesPayable",
    "otherCurrentLiabilities",
    "longTermDebt",
    "capitalLeaseObligations",
    "deferredTaxLiabilities",
    "otherNonCurrentLiabilities",

    # PATRIMONIO NETO
    "commonStock",
    "retainedEarnings",
    "netIncome",
    "accumulatedOtherComprehensiveIncome",
    "treasuryStock",
    "totalStockholderEquity"
]


balance_general_dict = {}

for ti in tickers:
    retry = 3
    while retry > 0:
        try:
            ticker = yf.Ticker(ti)
            balance_sheet = ticker.balance_sheet
            if balance_sheet.empty:
                print(f"{ti} no tiene balance general disponible.")
                break
            last_period_bs = balance_sheet.columns[0]
            data_balance = {}
            for key in balance_general_keys:
                value = balance_sheet.loc[key, last_period_bs] if key in balance_sheet.index else None
                if pd.isna(value):
                    value = None
                if isinstance(value, (int, float)):
                    value = round(value / 1_000_000, 2)
                data_balance[key] = value
            balance_general_dict[ti] = data_balance
            print(f"{ti} procesado correctamente.")
            break
        except Exception as e:
            msg = str(e).lower()
            if "too many requests" in msg or "rate limit" in msg:
                retry -= 1
                wait_time = 10
                print(f"Rate limit detectado para {ti}. Esperando {wait_time} segundos. Intentos restantes: {retry}")
                time.sleep(wait_time)
            else:
                print(f"Error al procesar {ti}: {e}")
                break
    time.sleep(1)

df_balance_general = pd.DataFrame.from_dict(balance_general_dict, orient='index')
df_balance_general.index.name = "Empresa"
df_balance_general.to_csv("balances_generales.csv")
print("Archivo guardado como balances_generales.csv")
# Out:
# BASFN.DE no tiene balance general disponible.
# BAYGN.DE no tiene balance general disponible.
# ALVG.DE no tiene balance general disponible.
# ADSGN.DE no tiene balance general disponible.
# LHAG.DE no tiene balance general disponible.
# SIEGN.DE no tiene balance general disponible.
# VOWG.DE no tiene balance general disponible.
# DBKGN.DE no tiene balance general disponible.
# CONG.DE no tiene balance general disponible.
# DPWGN.DE no tiene balance general disponible.
# DAIGN.DE no tiene balance general disponible.
# PSHG_P.DE no tiene balance general disponible.
# HNKG_P.DE no tiene balance general disponible.
# CBKG.DE no tiene balance general disponible.
# DB1GN.DE no tiene balance general disponible.
# BMWG.DE no tiene balance general disponible.
# FMEG.DE no tiene balance general disponible.
# DTEGN.DE no tiene balance general disponible.
# MANG.DE no tiene balance general disponible.
# MRCG.DE no tiene balance general disponible.
# IFXGN.DE no tiene balance general disponible.
# CECG.DE no tiene balance general disponible.
# MUVGN.DE no tiene balance general disponible.
# SAPG.DE no tiene balance general disponible.
# TKAG.DE no tiene balance general disponible.
# RHMG.DE no tiene balance general disponible.
# TUIGN.DE no tiene balance general disponible.
# WDIG.DE no tiene balance general disponible.
# LXSG.DE no tiene balance general disponible.
# BEIG.DE no tiene balance general disponible.
# FREG.DE no tiene balance general disponible.
# FNTGN.DE no tiene balance general disponible.
# SZGG.DE no tiene balance general disponible.
# A3B.DE no tiene balance general disponible.
# FRAG.DE no tiene balance general disponible.
# WCHG.DE no tiene balance general disponible.
# QSCG.DE no tiene balance general disponible.
# ZILGN.DE no tiene balance general disponible.
# VOSG.DE no tiene balance general disponible.
# KRNG.DE no tiene balance general disponible.
# G1AG.DE no tiene balance general disponible.
# HNRGN.DE no tiene balance general disponible.
# GBFG.DE no tiene balance general disponible.
# DRWG_P.DE no tiene balance general disponible.
# SOWGN.DE no tiene balance general disponible.
# KCOGN.DE no tiene balance general disponible.
# HOTG.DE no tiene balance general disponible.
# RWEG.DE no tiene balance general disponible.
# DEQGN.DE no tiene balance general disponible.
# NDXG.DE no tiene balance general disponible.
# NAFG.DE no tiene balance general disponible.
# A6W.DE no tiene balance general disponible.
# AIXGN.DE no tiene balance general disponible.
# RHKG.DE no tiene balance general disponible.
# GILG.DE no tiene balance general disponible.
# ABM.DE no tiene balance general disponible.
# SGCG.DE no tiene balance general disponible.
# SDFGN.DE no tiene balance general disponible.
# MTXGN.DE no tiene balance general disponible.
# SZUG.DE no tiene balance general disponible.
# HDDG.DE no tiene balance general disponible.
# ARLG.DE no tiene balance general disponible.
# B5AG.DE no tiene balance general disponible.
# DEZG.DE no tiene balance general disponible.
# SY1G.DE no tiene balance general disponible.
# CTNGK.DE no tiene balance general disponible.
# PV.DE no tiene balance general disponible.
# SNGGK.DE no tiene balance general disponible.
# HEIG.DE no tiene balance general disponible.
# AD8.DE no tiene balance general disponible.
# QIA.DE procesado.
# ADC.DE no tiene balance general disponible.
# UTDI.DE procesado.
# LEOGN.DE no tiene balance general disponible.
# GGS.DE no tiene balance general disponible.
# AEL.DE no tiene balance general disponible.
# AF4.DE no tiene balance general disponible.
# MORG.DE no tiene balance general disponible.
# M5ZG.DE no tiene balance general disponible.
# MDNG.DE no tiene balance general disponible.
# AGM.DE no tiene balance general disponible.
# AFXG.DE no tiene balance general disponible.
# BOSSN.DE no tiene balance general disponible.
# LOGNN.DE no tiene balance general disponible.
# BC8G.DE no tiene balance general disponible.
# ERICB.DE no tiene balance general disponible.
# MLPG.DE no tiene balance general disponible.
# 55O1.DE no tiene balance general disponible.
# ADAG.DE no tiene balance general disponible.
# CBRO.DE no tiene balance general disponible.
# DGII.DE no tiene balance general disponible.
# MQFA.DE no tiene balance general disponible.
# STM.DE procesado.
# EURA.DE no tiene balance general disponible.
# KORI.DE no tiene balance general disponible.
# PC6AY.DE no tiene balance general disponible.
# TQK.DE no tiene balance general disponible.
# RIOAY.DE no tiene balance general disponible.
# GTTG.DE no tiene balance general disponible.
# GSKY.DE no tiene balance general disponible.
# CCLC.DE no tiene balance general disponible.
# ARRJY.DE no tiene balance general disponible.
# NJY.DE no tiene balance general disponible.
# BHPY.DE no tiene balance general disponible.
# DIO.DE procesado.
# NOKY.DE no tiene balance general disponible.
# MCA.DE no tiene balance general disponible.
# ACEL.DE no tiene balance general disponible.
# EPWA.DE no tiene balance general disponible.
# HITY.DE no tiene balance general disponible.
# STEL.DE no tiene balance general disponible.
# 31L.DE no tiene balance general disponible.
# INVP.DE no tiene balance general disponible.
# DRFNY.DE no tiene balance general disponible.
# NPNJ.DE no tiene balance general disponible.
# AODCQ.DE no tiene balance general disponible.
# SLMJ.DE no tiene balance general disponible.
# AVA.DE no tiene balance general disponible.
# 0941.DE no tiene balance general disponible.
# BUDY.DE no tiene balance general disponible.
# AIRG.DE no tiene balance general disponible.
# HDJA.DE no tiene balance general disponible.
# 6762.DE no tiene balance general disponible.
# TJH7.DE no tiene balance general disponible.
# NNN1Y.DE no tiene balance general disponible.
# DISCKC.DE no tiene balance general disponible.
# EONGN.DE no tiene balance general disponible.
# ELO1.DE no tiene balance general disponible.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 75
#      73                 print(f"Error en {ti}: {e}")
#      74                 break
# ---> 75     time.sleep(1)
#      77 # DataFrame final
#      78 df_balance_general = pd.DataFrame.from_dict(balance_general_dict, orient="index")
#
# KeyboardInterrupt:
