# %% [markdown]
# ### CashFlow

# %%
import pandas as pd
import yfinance as yf

df = pd.read_csv("Ticketsvalidos.csv")
tickers = df["ticker_market"].dropna().astype(str).str.strip().unique().tolist()

print(f"Total de tickers a procesar: {len(tickers)}")

cashflow_keys = [
    "Free Cash Flow",
    "Operating Cash Flow",
    "Cash Flow From Continuing Operating Activities",
    "Capital Expenditure",
    "Repurchase Of Capital Stock",
    "Issuance Of Capital Stock",
    "Repayment Of Debt",
    "Long Term Debt Payments",
    "Issuance Of Debt",
    "Long Term Debt Issuance",
    "Net Long Term Debt Issuance",
    "Cash Dividends Paid",
    "Common Stock Dividend Paid",
    "Investing Cash Flow",
    "Cash Flow From Continuing Investing Activities",
    "Financing Cash Flow",
    "Cash Flow From Continuing Financing Activities",
    "Changes In Cash",
    "End Cash Position",
    "Beginning Cash Position"
]

cashflow_dict = {}
tickers_sin_cashflow = []
processed = 0
failed = 0

for ti in tickers:
    try:
        tkr = yf.Ticker(ti)
        cf = tkr.cashflow
        if cf is None or cf.empty:
            cf = tkr.quarterly_cashflow
        if cf is None or cf.empty or len(cf.columns) == 0:
            cashflow_dict[ti] = {k: None for k in cashflow_keys}
            tickers_sin_cashflow.append(ti)
            failed += 1
            print(f"{ti} sin datos")
            continue
        last_period = cf.columns[0]
        data_cf = {}
        for key in cashflow_keys:
            v = cf.loc[key, last_period] if key in cf.index else None
            if pd.isna(v):
                v = None
            else:
                try:
                    v = round(float(v) / 1_000_000, 2)
                except Exception:
                    v = None
            data_cf[key] = v
        cashflow_dict[ti] = data_cf
        processed += 1
        print(f"{ti} procesado")
    except Exception as e:
        cashflow_dict[ti] = {k: None for k in cashflow_keys}
        tickers_sin_cashflow.append(ti)
        failed += 1
        print(f"{ti} error: {e}")

df_cashflow = pd.DataFrame.from_dict(cashflow_dict, orient="index")
df_cashflow.index.name = "Ticker"
df_cashflow = df_cashflow.reindex(columns=cashflow_keys)

df_cashflow.to_csv("cashflow.csv", index=True)
pd.DataFrame({"Ticker": tickers_sin_cashflow}).to_csv("sin_cashflow.csv", index=False)

print("-" * 60)
print(f"Proceso terminado. Procesados: {processed} | Sin cashflow/errores: {failed}")
print("Archivos generados: cashflow.csv, sin_cashflow.csv")
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# 3ER.DE sin datos
# CE2G.DE sin datos
# ECPG.DE sin datos
# BDN.DE sin datos
# DAMG.DE sin datos
# LOUDG.DE sin datos
# DFTKN.DE sin datos
# HNLG.DE sin datos
# DRWG.DE sin datos
# BE4A.DE sin datos
# BGSN.DE sin datos
# EUZG.DE sin datos
# E4CG.DE sin datos
# EING_P.DE sin datos
# EE.DE sin datos
# ELGG.DE sin datos
# ETGG.DE sin datos
# ECXN.DE sin datos
# SQ7B.DE sin datos
# A4Y.DE procesado
# EUCAN.DE sin datos
# EWI1.DE sin datos
# EXCL.DE sin datos
# FAAS.DE sin datos
# FVIG.DE sin datos
# SISG.DE sin datos
# FEVG.DE sin datos
# FPHG.DE sin datos
# BID.DE sin datos
# FEWG.DE sin datos
# GMEG.DE sin datos
# GFTG.DE sin datos
# GKSG.DE sin datos
# EFII.DE sin datos
# G7BG.DE sin datos
# BIOA.DE sin datos
# HXCKK.DE sin datos
# HPBGN.DE sin datos
# HNKG.DE sin datos
# HWSAK.DE sin datos
# HBMG.DE sin datos
# HYQGN.DE sin datos
# EG1.DE sin datos
# EGB.DE sin datos
# IXXG.DE sin datos
# EGCA.DE sin datos
# ISHG.DE sin datos
# IS7G.DE sin datos
# IVXG.DE sin datos
# ISRG.DE sin datos
# BKS.DE sin datos
# IVUG.DE sin datos
# EGHT.DE sin datos
# EGOV.DE sin datos
# K1RG.DE sin datos
# KU2G.DE sin datos
# LEIG.DE sin datos
# L1OGK.DE sin datos
# EGVY.DE sin datos
# TGHN.DE procesado
# LPKG.DE sin datos
# ECKG.DE sin datos
# EGY.DE sin datos
# MANG_P.DE sin datos
# BKU.DE sin datos
# MZXG.DE sin datos
# MBBG.DE sin datos
# MEDG.DE sin datos
# CEC1_P.DE sin datos
# M3VGN.DE sin datos
# MBQGN.DE sin datos
# MGNK.DE sin datos
# MUBG.DE sin datos
# NEKG.DE sin datos
# NXUG.DE sin datos
# BOH.DE sin datos
# OHBG.DE sin datos
# BRKA.DE sin datos
# O4BG.DE sin datos
# EIG.DE sin datos
# PA8G.DE sin datos
# PGNG.DE sin datos
# RM11.DE sin datos
# PNEGN.DE sin datos
# ELY.DE sin datos
# BRO.DE sin datos
# BW.DE sin datos
# PWOG.DE sin datos
# PUS.DE sin datos
# TPEG.DE sin datos
# SANT1.DE sin datos
# RSL2.DE procesado
# RTCG.DE sin datos
# BYD.DE sin datos
# RIB.DE sin datos
# C08.DE sin datos
# RWEG_P.DE sin datos
# ENS.DE sin datos
# SATG.DE sin datos
# SATG_P.DE sin datos
# YSNG.DE sin datos
# C9S.DE sin datos
# F3CG.DE sin datos
# SW1.DE sin datos
# SZZG.DE sin datos
# SIXG_P.DE sin datos
# S4AG.DE sin datos
# SYTG.DE sin datos
# SFXG.DE sin datos
# ENZ.DE sin datos
# CAE.DE sin datos
# SURG.DE sin datos
# EXNGN.DE sin datos
# CALX.DE sin datos
# SYZG.DE sin datos
# TTRGN.DE sin datos
# TGTG.DE sin datos
# TLIG.DE sin datos
# HOC.DE sin datos
# TVDGK.DE sin datos
# US5.DE sin datos
# ULCG.DE sin datos
# UP7G.DE sin datos
# OSPGK.DE sin datos
# ER2N.DE sin datos
# VIBG_P.DE sin datos
# V3VGN.DE sin datos
# WSUG.DE sin datos
# WUGG.DE sin datos
# WUGG_P.DE sin datos
# WL6G.DE sin datos
# WZM.DE sin datos
# YOCG.DE sin datos
# AMA1.DE sin datos
# ZEFG.DE sin datos
# EOCY.DE sin datos
# BR.DE sin datos
# PHGY.DE sin datos
# WX7.DE sin datos
# T6O.DE sin datos
# 2U3.DE procesado
# SNH.DE sin datos
# SIX.DE sin datos
# ACC.DE sin datos
# UI51.DE sin datos
# CBL.DE sin datos
# 8CW.DE sin datos
# CNPC.DE sin datos
# F1EF.DE sin datos
# NZT.DE sin datos
# ORPI.DE sin datos
# C0Q.DE sin datos
# CNR.DE sin datos
# QCSB.DE sin datos
# OHI.DE sin datos
# POR.DE sin datos
# AEOS.DE sin datos
# BUEY.DE sin datos
# OII.DE sin datos
# AFG.DE sin datos
# CP.DE sin datos
# CYH.DE sin datos
# IVR.DE sin datos
# RBA.DE sin datos
# SQM.DE sin datos
# B7S.DE sin datos
# GR0A.DE sin datos
# PSRA.DE sin datos
# LTI.DE sin datos
# 9M1N.DE sin datos
# 2600Y.DE sin datos
# ALLD.DE sin datos
# FR.DE sin datos
# CCK.DE sin datos
# NNN.DE sin datos
# SCI.DE sin datos
# AXS.DE sin datos
# 43D.DE sin datos
# 07G.DE sin datos
# H9B1.DE sin datos
# MKO1.DE sin datos
# NCI2.DE sin datos
# PKG.DE sin datos
# SGM.DE procesado
# AJGH.DE sin datos
# BCBG.DE sin datos
# CHD.DE sin datos
# DKS.DE sin datos
# HIW.DE sin datos
# WFK.DE sin datos
# LXI.DE sin datos
# C19.DE sin datos
# EXRS.DE sin datos
# MFC.DE sin datos
# AWN.DE sin datos
# AKOYB.DE sin datos
# 4BW.DE sin datos
# CDH1.DE sin datos
# EGG.DE sin datos
# LPX.DE sin datos
# PL6.DE sin datos
# E6Z.DE sin datos
# ARW.DE sin datos
# BFPY.DE sin datos
# CNK.DE sin datos
# CPT.DE sin datos
# DLPA.DE sin datos
# GNRC.DE sin datos
# GNWR.DE sin datos
# MHK.DE sin datos
# RPM.DE sin datos
# AGO.DE sin datos
# ALK.DE sin datos
# AWK.DE sin datos
# 1P6.DE sin datos
# 6CL.DE sin datos
# CVA.DE sin datos
# FAF.DE sin datos
# KSU.DE sin datos
# 6MD.DE sin datos
# R2U.DE sin datos
# RY.DE sin datos
# SLG.DE sin datos
# NWJ.DE sin datos
# H.DE sin datos
# GPN.DE sin datos
# LNT.DE sin datos
# LGAY.DE sin datos
# OAS.DE sin datos
# SIG.DE sin datos
# SKMY.DE sin datos
# DEI.DE sin datos
# HL8.DE sin datos
# KRC.DE sin datos
# KTCY.DE sin datos
# MBTLY.DE sin datos
# O.DE sin datos
# PJ1A.DE sin datos
# 4DH.DE sin datos
# FLOF.DE sin datos
# 2KD.DE sin datos
# OC.DE sin datos
# RYN.DE sin datos
# STGY.DE sin datos
# SU.DE sin datos
# RDEDY.DE sin datos
# EVN.DE sin datos
# NVONY.DE sin datos
# 3SM.DE sin datos
# AZNPY.DE sin datos
# HANB.DE sin datos
# OPK.DE sin datos
# ALLE.DE sin datos
# CHILY.DE sin datos
# Z.DE sin datos
# GRA.DE sin datos
# KMT.DE sin datos
# M6G.DE sin datos
# MARY.DE sin datos
# DG3.DE sin datos
# CLGX.DE sin datos
# 25E.DE sin datos
# HLF.DE sin datos
# HUN.DE sin datos
# MAN.DE sin datos
# MTH.DE sin datos
# QEN.DE sin datos
# ECY.DE sin datos
# ENBD.DE sin datos
# LFLY.DE sin datos
# AWC.DE procesado
# BKE.DE sin datos
# C52.DE sin datos
# ECA.DE sin datos
# NERGY.DE sin datos
# GART.DE sin datos
# AAN.DE sin datos
# DOX.DE sin datos
# FR9.DE sin datos
# GES.DE sin datos
# R2RCY.DE sin datos
# AGCO.DE sin datos
# AME.DE sin datos
# D8SY.DE sin datos
# BU3.DE sin datos
# IEXC.DE sin datos
# LEA.DE sin datos
# FBHS.DE sin datos
# PVH.DE sin datos
# SXEA.DE sin datos
# EXPD.DE sin datos
# IDH.DE sin datos
# SIU.DE sin datos
# FPH.DE procesado
# JBHT.DE sin datos
# MDRX.DE sin datos
# MCE.DE sin datos
# AUD.DE sin datos
# FCXB.DE sin datos
# MXIM.DE sin datos
# SFER.DE sin datos
# ALXN.DE sin datos
# ERA.DE sin datos
# FIS.DE sin datos
# GGGA.DE sin datos
# IAG.DE sin datos
# IC1H.DE sin datos
# PEG.DE sin datos
# PTMA.DE sin datos
# APD.DE sin datos
# RF6.DE sin datos
# CVAG.DE sin datos
# DISCA.DE sin datos
# YC51.DE sin datos
# GWI2K.DE sin datos
# HHFGN.DE sin datos
# HIG.DE sin datos
# JEC.DE sin datos
# CAP.DE sin datos
# MRVL.DE sin datos
# YULC.DE sin datos
# AIV1.DE sin datos
# AEDAY.DE sin datos
# CBAX.DE sin datos
# CHRW.DE sin datos
# DFS.DE sin datos
# FHN.DE sin datos
# NAB.DE sin datos
# 4I1.DE procesado
# TEVAY.DE sin datos
# UPS.DE sin datos
# WP2A.DE sin datos
# ATI.DE sin datos
# C9F.DE sin datos
# HBAN.DE sin datos
# KCN.DE sin datos
# LSP.DE sin datos
# MMC.DE sin datos
# NOV.DE procesado
# 19O.DE sin datos
# PNW.DE sin datos
# RDO.DE sin datos
# STZ.DE sin datos
# VAR.DE sin datos
# VRTX.DE sin datos
# VZ.DE sin datos
# DY2.DE sin datos
# ADM.DE procesado
# AVB.DE sin datos
# BLD.DE sin datos
# BPSI.DE sin datos
# CDNS.DE sin datos
# CHKP.DE sin datos
# CINF.DE sin datos
# DO.DE sin datos
# FIIU.DE sin datos
# GT.DE sin datos
# HMTA.DE sin datos
# IFF.DE sin datos
# IIJIY.DE sin datos
# ITRK.DE sin datos
# LH.DE sin datos
# 54M.DE sin datos
# PFGF.DE sin datos
# PXD.DE sin datos
# SFF.DE sin datos
# S5YA.DE sin datos
# NY7.DE sin datos
# TEP.DE sin datos
# A.DE sin datos
# A4S.DE sin datos
# ANF.DE sin datos
# CPW.DE sin datos
# CTSH.DE sin datos
# FITB.DE sin datos
# IC2.DE sin datos
# LBL.DE sin datos
# MCHP.DE sin datos
# MPN.DE sin datos
# NTRS.DE sin datos
# PUFCX.DE sin datos
# PTEN.DE sin datos
# SIH.DE sin datos
# TMO.DE sin datos
# X.DE sin datos
# AEP.DE sin datos
# AIG.DE sin datos
# AKAM.DE sin datos
# BXB.DE sin datos
# GK6.DE sin datos
# 4CR1.DE sin datos
# CLVG.DE sin datos
# CVN.DE sin datos
# DP5.DE sin datos
# ED.DE sin datos
# GVP1.DE sin datos
# GS.DE sin datos
# ITW.DE sin datos
# PNC.DE sin datos
# QBE.DE sin datos
# REDYY.DE sin datos
# RWL.DE sin datos
# SGH.DE sin datos
# STI.DE sin datos
# ABEC.DE procesado
# ADYA.DE sin datos
# AMD.DE procesado
# BDX.DE sin datos
# BEN.DE sin datos
# BN9.DE sin datos
# BLY.DE sin datos
# BSXU.DE sin datos
# CF.DE sin datos
# CHK.DE sin datos
# CIRX.DE sin datos
# CNP.DE sin datos
# D.DE sin datos
# TDSC.DE sin datos
# DRI.DE sin datos
# ETFC.DE sin datos
# FMG.DE sin datos
# FM.DE sin datos
# GNW.DE sin datos
# G9KB.DE sin datos
# HLS.DE sin datos
# ISRGD.DE sin datos
# KLAC.DE sin datos
# 471A.DE sin datos
# 8MP.DE sin datos
# MTFTY.DE sin datos
# FPO.DE sin datos
# 1BF.DE sin datos
# RF.DE sin datos
# RIM.DE sin datos
# DLLNG.DE sin datos
# SFM1.DE sin datos
# SKC.DE sin datos
# M2O.DE sin datos
# SWK.DE sin datos
# SWN.DE sin datos
# TROW.DE sin datos
# UNH.DE procesado
# A60.DE sin datos
# WPL.DE sin datos
# WYN.DE sin datos
# ABC.DE sin datos
# BZTA.DE sin datos
# AMAT.DE sin datos
# A0T.DE sin datos
# W6P.DE sin datos
# BAB.DE sin datos
# BBBY.DE sin datos
# BXP.DE sin datos
# COF.DE sin datos
# COST.DE sin datos
# TBN2.DE sin datos
# DNR.DE sin datos
# EER.DE sin datos
# FBU.DE sin datos
# G4U.DE sin datos
# HIK.DE sin datos
# IGO.DE sin datos
# IPG.DE sin datos
# LNC.DE sin datos
# LUV.DE sin datos
# MA2.DE sin datos
# MNMA.DE sin datos
# MAPA.DE sin datos
# MML.DE sin datos
# MU.DE sin datos
# NBR.DE sin datos
# NOC.DE sin datos
# NSC.DE sin datos
# NUAN.DE sin datos
# NWL.DE sin datos
# RQQ1.DE sin datos
# PAFR.DE sin datos
# RSGU.DE sin datos
# SCCO.DE sin datos
# SQP.DE sin datos
# TVY.DE sin datos
# TXN.DE sin datos
# VBA.DE sin datos
# WICG.DE sin datos
# 33A.DE sin datos
# PNH.DE sin datos
# BAC.DE procesado
# BFGA.DE sin datos
# BMY.DE sin datos
# BBN1.DE sin datos
# XC2.DE sin datos
# COCA.DE sin datos
# CL.DE sin datos
# CUE.DE sin datos
# CFJA.DE sin datos
# FLEX.DE sin datos
# 1T1.DE sin datos
# JLL.DE sin datos
# HAIN.DE sin datos
# ICAY.DE sin datos
# 7IG.DE procesado
# JMX.DE sin datos
# TYIA.DE sin datos
# JNPR.DE sin datos
# KHNZ.DE procesado
# LOOL.DE sin datos
# 34LA.DE sin datos
# OXY.DE sin datos
# PH.DE sin datos
# RHI.DE sin datos
# RRC.DE sin datos
# SCH.DE sin datos
# XRP1.DE sin datos
# SIPG.DE sin datos
# S9P2.DE sin datos
# WA7.DE sin datos
# TCL.DE sin datos
# TTWO.DE sin datos
# URBN.DE sin datos
# VNO.DE sin datos
# WBC.DE sin datos
# WDC.DE sin datos
# UW.DE sin datos
# WPOB.DE sin datos
# ABT.DE sin datos
# AV3.DE sin datos
# AXP.DE sin datos
# BFB.DE sin datos
# BSLS.DE sin datos
# CAH.DE sin datos
# FG9.DE sin datos
# CR8.DE sin datos
# CEXAY.DE sin datos
# DEL.DE sin datos
# 2DBN.DE sin datos
# EMN.DE sin datos
# EMR.DE sin datos
# GEC.DE sin datos
# GILD.DE sin datos
# 2U4.DE sin datos
# HOG.DE sin datos
# IACI.DE sin datos
# ICAG.DE sin datos
# ILU.DE procesado
# IPGP.DE sin datos
# JPM.DE sin datos
# KOFY.DE sin datos
# LNNM.DE sin datos
# LRE.DE sin datos
# MAB.DE sin datos
# MGA.DE sin datos
# MHP.DE sin datos
# MQG.DE sin datos
# NCM.DE sin datos
# NEM.DE procesado
# NYTA.DE sin datos
# OZLN.DE sin datos
# PDN.DE sin datos
# PFG.DE sin datos
# PG.DE sin datos
# POG.DE sin datos
# RDSB.DE sin datos
# RL.DE sin datos
# SHLD.DE sin datos
# SHW.DE sin datos
# SK3.DE sin datos
# SIIG.DE sin datos
# 1JD.DE sin datos
# TWI.DE sin datos
# UTX.DE sin datos
# VMC.DE sin datos
# WHC.DE sin datos
# WMT.DE procesado
# ZMRHV.DE sin datos
# ABX.DE sin datos
# ACKB.DE sin datos
# ADI.DE sin datos
# AEM.DE sin datos
# AKS.DE sin datos
# A7L.DE sin datos
# GMN.DE sin datos
# 1YD.DE procesado
# BV51.DE sin datos
# BRKB.DE sin datos
# CTXS.DE sin datos
# CVS.DE procesado
# DKOB.DE sin datos
# DWNG.DE sin datos
# EQR.DE procesado
# EW.DE sin datos
# HON.DE sin datos
# 7HP.DE procesado
# HRS.DE sin datos
# HSY.DE sin datos
# SREI.DE sin datos
# 1LG.DE sin datos
# LB3B.DE sin datos
# LTD.DE sin datos
# METEX.DE sin datos
# MOT.DE sin datos
# NS.DE sin datos
# NXPI.DE sin datos
# OI.DE sin datos
# OXIG.DE sin datos
# PPG.DE sin datos
# P4Q.DE sin datos
# QAN.DE sin datos
# RMS.DE sin datos
# 2S7.DE sin datos
# SBM.DE sin datos
# SIA.DE sin datos
# STX.DE sin datos
# SUNC.DE sin datos
# UNP.DE procesado
# V1L.DE procesado
# VO9V.DE sin datos
# WHN.DE sin datos
# ZION.DE sin datos
# ADBE.DE sin datos
# ANZ.DE sin datos
# ASMI.DE sin datos
# CAG.DE procesado
# CMA.DE sin datos
# CGDG.DE sin datos
# CPSH.DE sin datos
# CRUS.DE sin datos
# 2XT.DE sin datos
# VOWG_P.DE sin datos
# VNAN.DE sin datos
# 1COV.DE procesado
# LINI.DE sin datos
# DEXD.DE sin datos
# GXID.DE sin datos
# HHFAD.DE sin datos
# RAAD.DE sin datos
# FPEG.DE sin datos
# BDTG.DE sin datos
# SPRGN.DE sin datos
# BYWGNX.DE sin datos
# LEGN.DE sin datos
# LO24N.DE sin datos
# TLXGN.DE sin datos
# EVKN.DE sin datos
# BVB.DE procesado
# OSRN.DE sin datos
# KGX.DE procesado
# ADLG.DE sin datos
# HWAG.DE sin datos
# BST1.DE sin datos
# STAB.DE sin datos
# ZALG.DE sin datos
# RKET.DE sin datos
# TLGG.DE sin datos
# HLE.DE procesado
# TC1N.DE sin datos
# FRU.DE sin datos
# MXHNN.DE sin datos
# LNSX.DE sin datos
# RY8.DE sin datos
# WDLK.DE sin datos
# ELBG.DE sin datos
# PBBG.DE sin datos
# PUMG.DE sin datos
# G24N.DE sin datos
# HLAG.DE procesado
# ADJ.DE procesado
# SNHG.DE sin datos
# SHA_P.DE sin datos
# BNNN.DE sin datos
# ARTG.DE sin datos
# DMRE.DE procesado
# ED4.DE procesado
# WCMKK.DE sin datos
# WUWGN.DE sin datos
# UN01.DE sin datos
# IGY.DE sin datos
# SAEG.DE sin datos
# GXIG.DE sin datos
# PSMGN.DE sin datos
# O2DN.DE sin datos
# WAFGN.DE sin datos
# AT1.DE procesado
# GYC.DE procesado
# DHER.DE procesado
# B4B.DE sin datos
# SHLG.DE sin datos
# KBX.DE procesado
# MDG1K.DE sin datos
# A1OS.DE procesado
# B8FGN.DE sin datos
# AM3D.DE sin datos
# SHFG.DE sin datos
# V6CG.DE sin datos
# FBENN.DE sin datos
# HACGN.DE sin datos
# DBD.DE sin datos
# SENG.DE sin datos
# VBX.DE procesado
# VAR1.DE sin datos
# SJJG.DE sin datos
# NFN.DE procesado
# H2FN.DE sin datos
# 37NN.DE sin datos
# VQTG.DE sin datos
# RAAG.DE sin datos
# WEG1.DE sin datos
# JSTG.DE sin datos
# AAGG.DE sin datos
# CCAG.DE sin datos
# HFGG.DE sin datos
# BFSA.DE procesado
# DWSG.DE sin datos
# 8TRA.DE procesado
# DEXGN.DE sin datos
# A6TG.DE sin datos
# BEZ.DE procesado
# H5EG.DE sin datos
# HAKG.DE sin datos
# AIRF.PA sin datos
# ACCP.PA sin datos
# APRL.PA sin datos
# AIRP.PA sin datos
# CAPP.PA sin datos
# EDF.PA sin datos
# AXAF.PA sin datos
# DANO.PA sin datos
# ENGIE.PA sin datos
# BNPP.PA sin datos
# BOUY.PA sin datos
# LVMH.PA sin datos
# OREP.PA sin datos
# SCHN.PA sin datos
# PEUP.PA sin datos
# SGOB.PA sin datos
# CARR.PA sin datos
# ESLX.PA sin datos
# PERP.PA sin datos
# CAGR.PA sin datos
# VLLP.PA sin datos
# ORAN.PA sin datos
# SOGN.PA sin datos
# MICP.PA sin datos
# AIR.PA procesado
# ALSO.PA sin datos
# SASY.PA sin datos
# VIV.PA procesado
# TOTF.PA sin datos
# STM.PA sin datos
# SGEF.PA sin datos
# RENA.PA sin datos
# VIE.PA procesado
# LAGA.PA sin datos
# PRTP.PA sin datos
# MMTP.PA sin datos
# PVAC.PA sin datos
# ERMT.PA sin datos
# TCFP.PA sin datos
# GFCP.PA sin datos
# DIOR.PA sin datos
# DAST.PA sin datos
# EPED.PA sin datos
# CASP.PA sin datos
# ADP.PA procesado
# EUFI.PA sin datos
# IMTP.PA sin datos
# RXL.PA procesado
# RCOP.PA sin datos
# NCOX.PA sin datos
# SESFD.PA sin datos
# GPBN.PA sin datos
# VIRB.PA sin datos
# PUBP.PA sin datos
# AKE.PA procesado
# EXHO.PA sin datos
# ILD.PA sin datos
# UBIP.PA sin datos
# HRMS.PA sin datos
# SOIT.PA sin datos
# SAF.PA procesado
# QDT.PA procesado
# MWDP.PA sin datos
# MERY.PA procesado
# FOUG.PA sin datos
# GENC.PA sin datos
# CNPP.PA sin datos
# SEBF.PA sin datos
# TRIA.PA sin datos
# SAVEN.PA sin datos
# ABIO.PA sin datos
# FTI.PA sin datos
# SCOR.PA sin datos
# STDM.PA sin datos
# CVO.PA sin datos
# ETL.PA procesado
# ATOS.PA sin datos
# CNAT.PA sin datos
# VLOF.PA sin datos
# DVTM.PA sin datos
# PLOF.PA sin datos
# NEXS.PA sin datos
# BOIR.PA sin datos
# PYHE.PA sin datos
# BICP.PA sin datos
# TRNG.PA sin datos
# ARCH.PA sin datos
# ISOS.PA sin datos
# ESSF.PA sin datos
# FTRN.PA sin datos
# ALTT.PA sin datos
# LTEN.PA sin datos
# INGC.PA sin datos
# GEPH.PA sin datos
# NEXI.PA sin datos
# CHBE.PA sin datos
# LOCAL.PA procesado
# LEGD.PA sin datos
# MANP.PA sin datos
# GFII.PA sin datos
# VILM.PA sin datos
# MAUP.PA sin datos
# TESI.PA sin datos
# LOIM.PA sin datos
# CBLP.PA sin datos
# IPN.PA procesado
# CCHE.PA sin datos
# ORP.PA sin datos
# JCDX.PA sin datos
# BIOX.PA sin datos
# RXPA.PA sin datos
# TFFP.PA sin datos
# TEPRF.PA sin datos
# CRIP.PA sin datos
# SDGI.PA sin datos
# EPMF.PA sin datos
# KOF.PA procesado
# SOPR.PA sin datos
# RUBF.PA sin datos
# ADUX.PA sin datos
# PARP.PA procesado
# SONO.PA sin datos
# ASY.PA procesado
# GECI.PA sin datos
# BOND.PA sin datos
# STF.PA procesado
# SWOR.PA sin datos
# AVOM.PA sin datos
# XPO.PA sin datos
# UFFP.PA sin datos
# CNIM.PA sin datos
# LAEP.PA sin datos
# VEIL.PA sin datos
# AVQ.PA sin datos
# LOUP.PA procesado
# PARRO.PA procesado
# TFF.PA procesado
# CITT.PA sin datos
# ALHRG.PA procesado
# IPAR.PA sin datos
# CGR.PA sin datos
# TGEL.PA sin datos
# HIGH.PA sin datos
# LECS.PA sin datos
# GFLO.PA sin datos
# SPIS.PA sin datos
# ALBI.PA procesado
# THHG.PA sin datos
# MATP.PA sin datos
# LDSV.PA sin datos
# ALPHY.PA sin datos
# LPER.PA sin datos
# ALU10.PA procesado
# ROBF.PA sin datos
# PHAI.PA sin datos
# MED6.PA sin datos
# GRBT.PA sin datos
# IISP.PA sin datos
# ALBOU.PA procesado
# VRKP.PA sin datos
# OPEN.PA sin datos
# SAMS.PA procesado
# MBRI.PA sin datos
# LAFU.PA sin datos
# GLTN.PA sin datos
# BAIN.PA procesado
# ALPDX.PA procesado
# GDSF.PA sin datos
# FLMI.PA sin datos
# HEXAO.PA sin datos
# ALDAR.PA procesado
# GAUM.PA sin datos
# SIGF.PA sin datos
# AFON.PA sin datos
# CGDM.PA sin datos
# PSBP.PA sin datos
# EXEP.PA sin datos
# CDAF.PA sin datos
# BVI.PA procesado
# SEVI.PA sin datos
# DBG.PA procesado
# ICAD.PA procesado
# ETGM.PA sin datos
# GETP.PA sin datos
# EURR.PA sin datos
# EDEN.PA procesado
# ATAR.PA sin datos
# BOLL.PA sin datos
# TCH.PA sin datos
# VCTP.PA sin datos
# ALLAN.PA procesado
# MBWS.PA procesado
# PROAC.PA procesado
# ALECR.PA sin datos
# AXW.PA sin datos
# JCQ.PA procesado
# METEX.PA procesado
# VDLO.PA sin datos
# ABS.PA sin datos
# CFMP.PA sin datos
# IMAF.PA sin datos
# ARGAN.PA sin datos
# ASTP.PA sin datos
# C4X.PA sin datos
# BZDK.PA sin datos
# BDRP.PA sin datos
# YAS.PA sin datos
# ALDEV.PA procesado
# ALDNX.PA procesado
# EDSP.PA sin datos
# EUMD.PA sin datos
# COVH.PA procesado
# GENX.PA sin datos
# GOEG.PA sin datos
# GPEP.PA sin datos
# IFDE.PA sin datos
# ITXA.PA sin datos
# ALLDL.PA procesado
# NVC.PA sin datos
# TEDE.PA sin datos
# ARTE.PA procesado
# PARF.PA sin datos
# PCAS.PA sin datos
# PRSW.PA sin datos
# SDIF.PA sin datos
# STEN.PA sin datos
# TERR.PA sin datos
# CBQP.PA sin datos
# BITI.PA sin datos
# DTNC.PA sin datos
# MRSP.PA sin datos
# ALDV.PA procesado
# ALDP.PA sin datos
# FPN.PA sin datos
# ADVI.PA sin datos
# AKA.PA sin datos
# AMOS.PA sin datos
# ALMP.PA sin datos
# AREIT.PA procesado
# AUBT.PA sin datos
# AUCP.PA sin datos
# AUER.PA sin datos
# AURS.PA sin datos
# ADVA.PA sin datos
# CDBP.PA sin datos
# BBUI.PA sin datos
# BATD.PA sin datos
# BGBN.PA sin datos
# BLEE.PA procesado
# CBSM.PA procesado
# BULY.PA sin datos
# CAT31.PA procesado
# CAFO.PA procesado
# CAPLI.PA sin datos
# CRPP.PA sin datos
# FCMC.PA procesado
# CFI.PA procesado
# CIBP.PA sin datos
# CCAP.PA sin datos
# GALIM.PA sin datos
# CTRG.PA sin datos
# COHE.PA sin datos
# COLP.PA sin datos
# CRTS.PA sin datos
# CARM.PA procesado
# CROS.PA procesado
# ALCYB.PA procesado
# DALE.PA sin datos
# AVMD.PA sin datos
# ALDEL.PA procesado
# DLTA.PA sin datos
# DIGP.PA sin datos
# DMSP.PA sin datos
# ECASA.PA sin datos
# EGID.PA sin datos
# EEMA.PA sin datos
# SFPI.PA procesado
# ALDUB.PA procesado
# ESIG.PA sin datos
# ECP.PA sin datos
# PPCF.PA sin datos
# EEPC.PA sin datos
# FSDV.PA sin datos
# FAUV.PA sin datos
# FFPP.PA sin datos
# SACP.PA sin datos
# PADI.PA sin datos
# ILSB.PA sin datos
# FINM.PA procesado
# LINP.PA sin datos
# FIPP.PA procesado
# BLIM.PA sin datos
# FATL.PA sin datos
# LOEX.PA sin datos
# INEA.PA procesado
# FLYP.PA sin datos
# SPOE.PA sin datos
# SFCA.PA procesado
# FREY.PA procesado
# FROB.PA sin datos
# GEAP.PA sin datos
# JAJP.PA sin datos
# GTCN.PA sin datos
# HFCO.PA sin datos
# ALHIO.PA sin datos
# LZTL.PA sin datos
# IDVP.PA sin datos
# IGXA.PA sin datos
# FINA.PA sin datos
# ARTO.PA procesado
# ETOF.PA sin datos
# IPH.PA procesado
# INN.PA sin datos
# OLLI.PA sin datos
# IRD.PA sin datos
# ITLI.PA sin datos
# ITFT.PA sin datos
# ITS.PA sin datos
# JBOG.PA procesado
# KEYR.PA sin datos
# CHSS.PA sin datos
# LACP.PA sin datos
# LBEL.PA sin datos
# LNA.PA procesado
# ALTAN.PA sin datos
# LEBO.PA sin datos
# ALLEX.PA procesado
# MFBP.PA sin datos
# EFIN.PA sin datos
# ALMEC.PA sin datos
# DEDAL.PA sin datos
# MEMS.PA procesado
# AKW.PA procesado
# MIPO.PA sin datos
# MRM.PA sin datos
# MUSE.PA sin datos
# NRO.PA procesado
# ALNSC.PA procesado
# SABT.PA sin datos
# OLG.PA sin datos
# ORPF.PA sin datos
# KAZI.PA sin datos
# ROTH.PA sin datos
# PASS.PA sin datos
# PATC.PA sin datos
# GPIF.PA sin datos
# PLVP.PA sin datos
# CATGR.PA sin datos
# PREP.PA sin datos
# ALPRI.PA procesado
# HOP.PA sin datos
# LBIRD.PA procesado
# RIBE.PA sin datos
# ALRGR.PA procesado
# SABL.PA sin datos
# SELER.PA procesado
# GIRO.PA sin datos
# SIPH.PA sin datos
# SDTC.PA sin datos
# SPBS.PA sin datos
# SRAG.PA sin datos
# SCLR.PA sin datos
# WAVE.PA procesado
# DAMA.PA sin datos
# SQLI.PA sin datos
# DPTP.PA sin datos
# SESL.PA sin datos
# TYNN.PA sin datos
# TIPK.PA sin datos
# TIVO.PA sin datos
# TETR.PA sin datos
# TEIF.PA sin datos
# SMTPC.PA sin datos
# ALUMS.PA sin datos
# UTIN.PA sin datos
# TCNP.PA sin datos
# VETO.PA procesado
# VDNT.PA sin datos
# VLS.PA sin datos
# VLTZ.PA sin datos
# XIL.PA procesado
# OFP.PA sin datos
# DPAP.PA sin datos
# AGTA.PA sin datos
# ALCLS.PA procesado
# ALERS.PA procesado
# ALGEN.PA procesado
# GNFT.PA procesado
# ALHYG.PA sin datos
# ALINT.PA sin datos
# ALNEV.PA procesado
# ALVIA.PA procesado
# ALODI.PA sin datos
# KORI.PA sin datos
# EURA.PA sin datos
# CATR.PA sin datos
# MRK.PA procesado
# HBC.PA sin datos
# DGE.PA procesado
# GNE.PA sin datos
# MKEA.PA sin datos
# PRC.PA procesado
# ADOC.PA procesado
# BRCP.PA sin datos
# CADNI.PA sin datos
# CALCI.PA sin datos
# CBOT.PA procesado
# CFOA.PA sin datos
# CRBP2.PA procesado
# CRLA.PA procesado
# DBV.PA procesado
# EGAB.PA sin datos
# EOSI.PA sin datos
# FOEQ.PA sin datos
# IDLA.PA sin datos
# VMX.PA procesado
# NANOB.PA sin datos
# TLVB.PA sin datos
# FNAC.PA procesado
# ALIMP.PA procesado
# EKI.PA procesado
# ALMIL.PA sin datos
# ALVDM.PA procesado
# ALEUP.PA procesado
# SPIE.PA procesado
# ALPCI.PA sin datos
# MLFDV.PA sin datos
# ALDR.PA sin datos
# MLGEL.PA sin datos
# ALICR.PA sin datos
# MLMUL.PA sin datos
# MLCIO.PA sin datos
# SLBP.PA sin datos
# ALCOI.PA procesado
# ALHEO.PA sin datos
# ALANT.PA sin datos
# ALGEV.PA procesado
# ALBDM.PA procesado
# ALESK.PA sin datos
# CRAP.PA procesado
# CCNP.PA sin datos
# ALADO.PA procesado
# ALLOG.PA procesado
# ALENR.PA sin datos
# CIV.PA procesado
# CRLO.PA procesado
# CRTO.PA procesado
# CRSU.PA procesado
# CAIF.PA sin datos
# CMO.PA procesado
# ALGIL.PA procesado
# ALADA.PA sin datos
# ALCOF.PA procesado
# ALSIP.PA sin datos
# ALIDS.PA sin datos
# ALPJT.PA procesado
# ALDBL.PA procesado
# ALMAK.PA sin datos
# ALATF.PA sin datos
# ALDOL.PA sin datos
# ALVIV.PA sin datos
# ALMIC.PA sin datos
# ALNSE.PA procesado
# ALCLA.PA sin datos
# ALVER.PA procesado
# ALMAS.PA procesado
# ALTVO.PA sin datos
# ALNXT.PA procesado
# ALBUD.PA sin datos
# ALBLD.PA procesado
# ALMED.PA sin datos
# ALFRE.PA procesado
# TKTT.PA procesado
# ALTHE.PA procesado
# ALI2S.PA procesado
# ALLHB.PA procesado
# ALIVA.PA sin datos
# ALBFR.PA procesado
# ALMGI.PA procesado
# ALHVS.PA sin datos
# ALVEL.PA sin datos
# ALEZV.PA sin datos
# ALS30.PA sin datos
# ALTEV.PA sin datos
# ALINN.PA procesado
# ALPRO.PA procesado
# ALOBR.PA procesado
# ALWEB.PA sin datos
# ALUPG.PA procesado
# ALAQU.PA sin datos
# ALGAU.PA sin datos
# ALMDG.PA procesado
# ALDIE.PA sin datos
# ALTUR.PA sin datos
# ALHIT.PA sin datos
# ALNOV.PA procesado
# ALAMG.PA procesado
# ALTRI.PA procesado
# ALDSL.PA sin datos
# ALENT.PA procesado
# ALGEM.PA sin datos
# ALADM.PA sin datos
# ALEO2.PA procesado
# ALFPC.PA procesado
# ALIMO.PA sin datos
# ALALO.PA procesado
# ALROC.PA procesado
# SSI.PA sin datos
# ALSTW.PA procesado
# ALCES.PA sin datos
# OREGE.PA procesado
# ALAGR.PA procesado
# COFA.PA procesado
# ALWED.PA sin datos
# ALMER.PA procesado
# ALMNG.PA sin datos
# ALREW.PA procesado
# ALDEI.PA sin datos
# ALQWA.PA procesado
# ALCAR.PA procesado
# ALBIO.PA procesado
# ALMOU.PA procesado
# ALACT.PA sin datos
# ALMDT.PA procesado
# ALGBE.PA procesado
# ALTBG.PA procesado
# ALVMG.PA sin datos
# ALUCR.PA sin datos
# ALCOG.PA sin datos
# ALINS.PA procesado
# ALGLD.PA procesado
# ALMET.PA sin datos
# FALG.PA sin datos
# ALGEP.PA sin datos
# ALSPW.PA procesado
# ALSGD.PA procesado
# ERYP.PA sin datos
# MAGIS.PA sin datos
# ALMND.PA sin datos
# BLUE.PA sin datos
# ALCRB.PA procesado
# FGA.PA procesado
# ALCJ.PA procesado
# GTT.PA procesado
# MCPHY.PA sin datos
# ALONC.PA sin datos
# GKTX.PA sin datos
# GVI.PA sin datos
# AWOX.PA sin datos
# ALREA.PA procesado
# ALUCI.PA procesado
# PIX.PA sin datos
# SEFER.PA procesado
# ELIOR.PA procesado
# PID.PA sin datos
# ATEME.PA procesado
# MSTY.PA sin datos
# IAM.PA procesado
# ENX.PA procesado
# VALED3.PA sin datos
# FBAP.PA sin datos
# ALEMV.PA procesado
# ALFIL.PA sin datos
# ALSER.PA sin datos
# ALSAS.PA procesado
# ALOCA.PA sin datos
# ALTRA.PA sin datos
# ALSIM.PA sin datos
# ALBLU.PA procesado
# ALTHER.PA sin datos
# ALANV.PA sin datos
# ALPLA.PA sin datos
# AIRFXB.PA sin datos
# ALSAF.PA procesado
# ELIS.PA procesado
# ALFOC.PA sin datos
# ALTRO.PA procesado
# POXEL.PA procesado
# ALTTI.PA sin datos
# ALEUA.PA procesado
# ALQGC.PA procesado
# MLSUM.PA procesado
# ALESA.PA procesado
# ALPAT.PA procesado
# ABNX.PA procesado
# OSE.PA procesado
# ALSEN.PA procesado
# EPS.PA sin datos
# ALDRV.PA procesado
# MLIDP.PA sin datos
# VLTSA.PA procesado
# MLPRO.PA sin datos
# ALUNT.PA procesado
# WLN.PA procesado
# ALLIX.PA procesado
# ABVX.PA procesado
# AMPLI.PA procesado
# EUCAR.PA sin datos
# HIPAY.PA sin datos
# ALBPS.PA procesado
# ALCOR.PA sin datos
# AMEBA.PA sin datos
# CLNV.PA sin datos
# LHN.PA sin datos
# MLGEQ.PA procesado
# MLVAL.PA sin datos
# MLIFE.PA sin datos
# MLORC.PA sin datos
# MLAEM.PA sin datos
# MLDYH.PA sin datos
# MLSKN.PA sin datos
# ALFST.PA sin datos
# MLDTB.PA sin datos
# MLOVE.PA sin datos
# SRPG.PA sin datos
# ALKKO.PA procesado
# AMUN.PA procesado
# MLCMG.PA sin datos
# MLHK.PA procesado
# NOKIA.PA procesado
# ALPOU.PA procesado
# MLCLI.PA sin datos
# ALDBT.PA procesado
# ALMLB.PA procesado
# ALIMR.PA sin datos
# ALWEC.PA procesado
# MLOSA.PA sin datos
# MLAAT.PA sin datos
# ALWIT.PA procesado
# GNRO.PA procesado
# ALQP.PA sin datos
# MLSFI.PA sin datos
# ALKLK.PA procesado
# MDM.PA procesado
# MLSDN.PA sin datos
# LFDE.PA sin datos
# ALPCV.PA procesado
# STID.PA sin datos
# ALENE.PA sin datos
# SIGHT.PA procesado
# ALINV.PA procesado
# MLUTP.PA sin datos
# PHARN.PA sin datos
# 3CHN.PA sin datos
# ALTXC.PA procesado
# ARDPA.PA sin datos
# BLBP.PA sin datos
# CHMS.PA sin datos
# CHRA.PA sin datos
# CNV.PA sin datos
# CSCE.PA sin datos
# DJTK.PA sin datos
# DYND.PA sin datos
# EARO.PA sin datos
# EDDS.PA sin datos
# IDSP.PA sin datos
# KRNI.PA sin datos
# ML350.PA sin datos
# MLAAH.PA procesado
# MLBAT.PA sin datos
# MLCEC.PA sin datos
# MLERO.PA sin datos
# MLETA.PA sin datos
# MLFIR.PA procesado
# MLFTI.PA sin datos
# MLFXO.PA sin datos
# MLGES.PA sin datos
# MLIML.PA sin datos
# MLLED.PA sin datos
# MLMFI.PA sin datos
# MLMON.PA sin datos
# MLOLM.PA sin datos
# MLONE.PA sin datos
# MLPFX.PA sin datos
# MLRAM.PA sin datos
# MLSEQ.PA procesado
# MLSML.PA procesado
# MLUMG.PA sin datos
# MLV4S.PA sin datos
# MLVIS.PA sin datos
# MLWEY.PA sin datos
# NEWS.PA sin datos
# NWZI.PA sin datos
# PGOA.PA sin datos
# PLAP.PA sin datos
# ROBFI.PA sin datos
# SION.PA sin datos
# UMHS.PA sin datos
# ZCCM.PA sin datos
# ALNLF.PA procesado
# ALNOX.PA sin datos
# ABEO.PA procesado
# ALPAR.PA sin datos
# ALPHS.PA sin datos
# MLGML.PA sin datos
# ALHSW.PA sin datos
# NEXTS.PA sin datos
# DRIS.PA sin datos
# MLMMC.PA sin datos
# ALOSM.PA sin datos
# LYS.PA sin datos
# IVAA.PA sin datos
# TKOO.PA sin datos
# MLCHE.PA sin datos
# XFAB.PA procesado
# MDW.PA sin datos
# PWG.PA procesado
# ALVAL.PA procesado
# BALYO.PA procesado
# ALDA.PA sin datos
# ANTAL.PA sin datos
# MLAHC.PA sin datos
# ALUVI.PA sin datos
# ALMII.PA procesado
# BUP.PA sin datos
# ALARF.PA sin datos
# MLALV.PA sin datos
# SMCP.PA procesado
# ALTHX.PA procesado
# ADVIC.PA sin datos
# ALVU.PA procesado
# ALOXA.PA sin datos
# MLOCT.PA sin datos
# ALDNE.PA procesado
# ALNN6.PA procesado
# VTX.PA sin datos
# COGEC.PA sin datos
# ALKAL.PA procesado
# MLPRXP.PA sin datos
# 2CRSI.PA sin datos
# ALORD.PA procesado
# ALTUV.PA procesado
# RBO.PA procesado
# ALAVY.PA sin datos
# NAVYA.PA sin datos
# MLGDI.PA sin datos
# ALMBG.PA sin datos
# MEDCL.PA procesado
# NEOEN.PA sin datos
# ALVGO.PA procesado
# ALPRE.PA procesado
# ALLLN.PA procesado
# ALBKK.PA procesado
# ALCUR.PA procesado
# MLWRC.PA procesado
# MLVAP.PA sin datos
# MLEAS.PA procesado
# ALEAC.PA procesado
# ALGTR.PA procesado
# MLAGA.PA sin datos
# MLIPO.PA sin datos
# ALPER.PA procesado
# VRLA.PA procesado
# BOOST.PA sin datos
# ALAGP.PA procesado
# FDJ.PA sin datos
# BATS.L procesado
# HSBA.L procesado
# BARC.L procesado
# IHG.L procesado
# BP.L procesado
# NXT.L procesado
# LLOY.L procesado
# EZJ.L procesado
# MKS.L procesado
# BIRG.L procesado
# GNS.L procesado
# OMU.L procesado
# RBS.L sin datos
# PRU.L procesado
# PFD.L procesado
# VOD.L procesado
# BNKR.L procesado
# GNK.L sin datos
# BWNG.L sin datos
# MGNS.L procesado
# PFC.L procesado
# FERG.L procesado
# HOCM.L sin datos
# AZN.L procesado
# JKX.L sin datos
# BWY.L procesado
# LGEN.L procesado
# IMB.L procesado
# RB.L sin datos
# KGF.L procesado
# REL.L procesado
# MRW.L sin datos
# CNA.L procesado
# III.L procesado
# WPP.L procesado
# VCTX.L sin datos
# HRGV.L sin datos
# TSCO.L procesado
# SLA.L sin datos
# DGE.L procesado
# BALF.L sin datos
# HIK.L procesado
# WG.L procesado
# RDSA.L sin datos
# FCIT.L procesado
# INVP.L procesado
# RIO.L procesado
# JMAT.L procesado
# HFD.L procesado
# AAL.L procesado
# CPI.L procesado
# BNZL.L procesado
# BRBY.L procesado
# GSK.L procesado
# BDEV.L sin datos
# AV.L procesado
# BHPB.L sin datos
# SGE.L procesado
# SMWH.L procesado
# PSON.L procesado
# HMSO.L procesado
# GOG.L sin datos
# TAN.L procesado
# ABF.L procesado
# ISA.L sin datos
# TLW.L procesado
# LSE.L sin datos
# JDW.L procesado
# CNE.L procesado
# BAES.L sin datos
# ANTO.L procesado
# SRP.L procesado
# 3IN.L procesado
# EMG.L procesado
# TCAPI.L sin datos
# CPRC.L sin datos
# BVIC.L sin datos
# RR.L procesado
# WTB.L procesado
# PNN.L procesado
# TATE.L procesado
# KAZ.L sin datos
# RSA.L sin datos
# BVS.L sin datos
# PSN.L procesado
# QQ.L procesado
# ADML.L sin datos
# UU.L procesado
# ULVR.L procesado
# SHI.L procesado
# COB.L sin datos
# CRH.L procesado
# GPOR.L sin datos
# SSE.L procesado
# STAN.L procesado
# PAGE.L procesado
# BLND.L procesado
# INF.L procesado
# WEIR.L procesado
# DMGOA.L sin datos
# ASHM.L procesado
# SVT.L procesado
# GFS.L sin datos
# TPK.L procesado
# SJP.L sin datos
# VSVS.L procesado
# SMIN.L procesado
# IGG.L procesado
# DRX.L procesado
# BAB.L procesado
# MRON.L sin datos
# SDRT.L sin datos
# SN.L procesado
# ITRK.L procesado
# MAB.L procesado
# MTO.L procesado
# POG.L sin datos
# AGGK.L sin datos
# MNDI.L procesado
# ROR.L procesado
# WMH.L sin datos
# SBRY.L procesado
# PFG.L sin datos
# FGP.L procesado
# CRDA.L procesado
# WIN.L sin datos
# NG.L procesado
# EIGE.L sin datos
# IMI.L procesado
# KIE.L procesado
# PMO.L sin datos
# BT.L sin datos
# INCH.L procesado
# HTG.L procesado
# SGRO.L procesado
# SGC.L sin datos
# SDR.L procesado
# ITV.L procesado
# RTO.L procesado
# CPG.L procesado
# HAYS.L sin datos
# ICP.L sin datos
# ULE.L sin datos
# TPT.L procesado
# SREI.L procesado
# CCL.L procesado
# RPT.L sin datos
# HSX.L procesado
# ASL.L procesado
# SVS.L procesado
# RNK.L procesado
# LAND.L procesado
# CCC.L procesado
# CLDN.L procesado
# MCRO.L sin datos
# SMT.L procesado
# RPS.L sin datos
# MGGT.L sin datos
# HLCL.L procesado
# RDW.L sin datos
# IWG.L procesado
# TRY.L procesado
# SXS.L procesado
# HLMA.L procesado
# JMG.L procesado
# RMV.L procesado
# SPD.L sin datos
# PZC.L procesado
# KLR.L procesado
# NEX.L sin datos
# SAFE.L procesado
# GFRD.L procesado
# IPF.L procesado
# SMDS.L sin datos
# CHG.L procesado
# ESNT.L procesado
# RTN.L sin datos
# SHB.L sin datos
# DLAR.L procesado
# GEMD.L procesado
# MLC.L sin datos
# PHARP.L sin datos
# CWR.L procesado
# TW.L procesado
# BYG.L procesado
# RCP.L procesado
# RSW.L procesado
# BOY.L procesado
# EDIN.L procesado
# SPX.L procesado
# AGT.L procesado
# DTY.L sin datos
# PLI.L sin datos
# PVCS.L sin datos
# TEM.L procesado
# GRG.L procesado
# BBA.L sin datos
# ATST.L sin datos
# AVV.L sin datos
# ASOS.L sin datos
# MONY.L procesado
# CLLN.L sin datos
# HSV.L sin datos
# RCH.L procesado
# ITE.L sin datos
# ECM.L sin datos
# SCIN.L sin datos
# AHT.L procesado
# SPT.L procesado
# STHR.L sin datos
# MSLH.L procesado
# MERG.L sin datos
# SFR.L procesado
# GRI.L procesado
# NTG.L sin datos
# FXPO.L procesado
# UTG.L procesado
# DLN.L procesado
# RWI.L sin datos
# MUT.L procesado
# FLTRF.L sin datos
# MNKS.L procesado
# ADIG.L procesado
# WKP.L procesado
# CTY.L sin datos
# MRCH.L procesado
# GCC.L sin datos
# BEZG.L sin datos
# ERM.L sin datos
# TMPL.L procesado
# PAYP.L sin datos
# CTH.L sin datos
# SEY.L sin datos
# WTAN.L sin datos
# SDY.L procesado
# HSTN.L sin datos
# JETX.L sin datos
# ELTA.L sin datos
# RAT.L procesado
# CLSH.L sin datos
# WINEW.L sin datos
# STUS.L sin datos
# JII.L procesado
# MYI.L procesado
# PRM.L procesado
# HASE.L sin datos
# FEV.L sin datos
# BLVN.L sin datos
# OXB.L procesado
# SPHN.L sin datos
# SMP.L sin datos
# VGAS.L sin datos
# JHD.L procesado
# KMR.L procesado
# COSG.L sin datos
# NUM.L sin datos
# SQZ.L procesado
# REDD.L sin datos
# AGRP.L sin datos
# CAL.L sin datos
# ACCS.L sin datos
# MPE.L procesado
# GOAL.L sin datos
# HEAD.L procesado
# LMS.L procesado
# PDG.L sin datos
# 0JYA.L sin datos
# 0Y7S.L sin datos
# RDSB.L sin datos
# RYA.L sin datos
# UKCM.L sin datos
# MARS.L procesado
# DOM.L procesado
# 888.L sin datos
# INTUP.L sin datos
# FRES.L procesado
# GAZPQ.L sin datos
# EXPN.L procesado
# RKH.L procesado
# PTEC.L procesado
# BKGH.L sin datos
# HWDN.L procesado
# ENQ.L procesado
# ACAA.L sin datos
# INFAT.L sin datos
# PARA.L sin datos
# MRS.L sin datos
# OCDO.L procesado
# BPCB.L sin datos
# BSTH.L sin datos
# GLEN.L procesado
# ICAG.L sin datos
# BOCH.L sin datos
# ABCA.L sin datos
# AVN.L sin datos
# HTCF.L sin datos
# BAG.L procesado
# BEG.L procesado
# BHGG.L sin datos
# BHGGU.L sin datos
# BHMG.L procesado
# BHMGU.L sin datos
# BRW.L sin datos
# BRWM.L procesado
# CAPCC.L sin datos
# CEY.L sin datos
# CIC.L procesado
# CPPG.L sin datos
# DC.L sin datos
# CWK.L procesado
# DJAN.L sin datos
# DNLM.L procesado
# EFM.L sin datos
# ELM.L procesado
# EXIL.L sin datos
# BCPT.L procesado
# FCSS.L procesado
# 0P6E.L sin datos
# FSV.L procesado
# GSS.L sin datos
# GKP.L procesado
# HICL.L procesado
# HRI.L procesado
# HTGR.L sin datos
# IDH.L sin datos
# IEM.L procesado
# INPP.L procesado
# JAI.L sin datos
# JAM.L procesado
# JD.L procesado
# JESC.L sin datos
# JUP.L procesado
# LAM.L sin datos
# LRE.L procesado
# LMPL.L sin datos
# LWDB.L procesado
# MRCM.L sin datos
# MTC.L procesado
# NICL.L procesado
# PCT.L procesado
# PHNX.L procesado
# RPC.L sin datos
# RWS.L procesado
# SDL.L sin datos
# SDP.L sin datos
# SDRY.L sin datos
# SLN.L sin datos
# STOB.L sin datos
# TALK.L sin datos
# VOG.L sin datos
# PERE.L sin datos
# YNGT.L sin datos
# AMER.L sin datos
# A7L.L sin datos
# BZT.L procesado
# BRSC.L procesado
# CADP.L sin datos
# CHARC.L sin datos
# DVO.L sin datos
# HSL.L procesado
# IQE.L procesado
# JMI.L sin datos
# JRS.L sin datos
# MTU.L sin datos
# MUL.L procesado
# PDL.L procesado
# SCP.L sin datos
# SNR.L procesado
# SXX.L sin datos
# SKG.L procesado
# SLS.L sin datos
# TEP.L procesado
# VEC.L sin datos
# DUPD.L sin datos
# HAOG.L sin datos
# IPEL.L sin datos
# LOOK.L sin datos
# PAFR.L sin datos
# POLO.L sin datos
# SLEN.L sin datos
# THRG.L procesado
# TRBG.L sin datos
# SYNTS.L sin datos
# NANON.L sin datos
# EVRE.L sin datos
# POLYP.L sin datos
# 0QYF.L sin datos
# 0JSJ.L sin datos
# 0RPW.L sin datos
# CABC.L sin datos
# 0GQY.L sin datos
# APF.L sin datos
# KCOM.L sin datos
# OXIG.L procesado
# PNL.L procesado
# CCEPC.L sin datos
# PTR.L sin datos
# MCMM.L sin datos
# FDI.L sin datos
# ALTNA.L sin datos
# MGAMM.L sin datos
# 0K34.L sin datos
# 0QYR.L sin datos
# PGD.L sin datos
# ASOA.L sin datos
# AVM.L sin datos
# PXSP.L sin datos
# 0N7L.L sin datos
# 0RIH.L procesado
# TUIT.L sin datos
# DCC.L procesado
# CBRO.L sin datos
# GMRG.L sin datos
# YNGA.L procesado
# 0QYC.L sin datos
# 0R0J.L sin datos
# CODC.L sin datos
# BVAB.L sin datos
# 0TDE.L sin datos
# BNC.L procesado
# JARB.L sin datos
# OEX.L sin datos
# BKY.L procesado
# WJA.L sin datos
# OMIN.L sin datos
# CBUY.L sin datos
# CALQ.L sin datos
# EUZ.L procesado
# GBPQ.L sin datos
# RMPQ.L sin datos
# SGZ.L sin datos
# 88E.L procesado
# WEN.L sin datos
# SO4.L sin datos
# CARRC.L sin datos
# AGOL.L sin datos
# PACL.L sin datos
# VOF.L procesado
# PMEA.L sin datos
# KUBCQ.L sin datos
# AOF.L procesado
# OPPPP.L sin datos
# VNHQ.L sin datos
# TAU.L sin datos
# VNLQ.L sin datos
# EIH.L sin datos
# INME.L sin datos
# OGN.L procesado
# SRET.L sin datos
# AUK.L sin datos
# AAS.L procesado
# CYNL.L sin datos
# BRMS.L sin datos
# ANEA.L sin datos
# BIOGW.L sin datos
# GFM.L procesado
# AYM.L procesado
# NTAS.L sin datos
# DUNE.L sin datos
# SOST.L sin datos
# IPX.L procesado
# AMSU.L sin datos
# PANI.L sin datos
# CGNR.L procesado
# SYMU.L sin datos
# WIPA.L sin datos
# LAS.L procesado
# EUTP.L sin datos
# TSTT.L sin datos
# C21.L sin datos
# ABD.L procesado
# BMTT.L sin datos
# PNIG.L sin datos
# NZX.L sin datos
# MACP.L sin datos
# TRT.L procesado
# SUNU.L sin datos
# PXOG.L sin datos
# LIO.L procesado
# SGI.L sin datos
# APCL.L sin datos
# RGO.L procesado
# JUS.L sin datos
# FIF.L sin datos
# CNCT.L sin datos
# IGRI.L sin datos
# TIRU.L sin datos
# SCEU.L sin datos
# TYM.L procesado
# MACT.L sin datos
# PRIMP.L sin datos
# WGB.L sin datos
# PET.L procesado
# FSTP.L sin datos
# LGHT.L sin datos
# PACA.L sin datos
# ARC.L procesado
# 7DIG.L sin datos
# GNC.L procesado
# ANSY.L sin datos
# STLO.L sin datos
# LSC.L procesado
# REAH.L sin datos
# EUA.L procesado
# RNWH.L procesado
# GHS.L procesado
# UNG.L sin datos
# UANC.L sin datos
# CTR.L sin datos
# WEBH.L sin datos
# CRPR.L procesado
# PMGR.L procesado
# HVT.L procesado
# MIN.L procesado
# NWMS.L sin datos
# GRAG.L sin datos
# D4T4.L sin datos
# SNXS.L sin datos
# CTID.L sin datos
# SCPA.L sin datos
# CHCH.L sin datos
# C3U.L sin datos
# SVE.L sin datos
# IOMG.L sin datos
# APP.L sin datos
# SHRE.L sin datos
# AFN.L sin datos
# ELCO.L procesado
# AIEA.L procesado
# PHWK.L sin datos
# GBGP.L sin datos
# CAME.L sin datos
# PTTD.L sin datos
# NETC.L sin datos
# BSDB.L sin datos
# RM.L procesado
# VP.L procesado
# SLPE.L procesado
# RQIH.L sin datos
# JPGI.L sin datos
# EWI.L procesado
# JMC.L sin datos
# ASEI.L sin datos
# SOI.L procesado
# AFMC.L sin datos
# KBT.L procesado
# QFI.L sin datos
# BGSC.L sin datos
# JFJ.L procesado
# BRGE.L procesado
# BERI.L procesado
# JEMI.L procesado
# SAVS.L sin datos
# R4ER.L sin datos
# DATA.L procesado
# NBI.L sin datos
# TMGT.L sin datos
# FJET.L sin datos
# ANIC.L procesado
# JEO.L sin datos
# BGFD.L procesado
# JPS.L sin datos
# DIG.L procesado
# IVI.L sin datos
# SCF.L sin datos
# HHI.L procesado
# GRIT.L procesado
# PCGH.L procesado
# AEMC.L sin datos
# CMHY.L sin datos
# TILST.L sin datos
# BBGIB.L sin datos
# PCF.L sin datos
# NTOG.L procesado
# VAST.L procesado
# INSP.L procesado
# CSSG.L procesado
# HEFT.L sin datos
# FGT.L procesado
# GCPI.L sin datos
# RGD.L sin datos
# MBH.L procesado
# HVO.L procesado
# KDR.L procesado
# GWMO.L procesado
# BCIB.L sin datos
# TIGT.L procesado
# MNP.L sin datos
# ANII.L procesado
# SJG.L sin datos
# SLI.L sin datos
# AAIF.L procesado
# JETI.L procesado
# FFWD.L sin datos
# DMTR.L sin datos
# SDIS.L sin datos
# FIH.L procesado
# OPTIO.L sin datos
# MNL.L procesado
# JMF.L procesado
# ICGT.L procesado
# PHP.L procesado
# BRFI.L procesado
# AD4.L sin datos
# EPGT.L sin datos
# SESTS.L sin datos
# JLH.L sin datos
# EKF.L procesado
# ARKA.L sin datos
# HCM.L procesado
# BRLA.L procesado
# SCAM.L sin datos
# TRG.L procesado
# BREI.L sin datos
# IPU.L sin datos
# BGEO.L procesado
# HDIV.L sin datos
# MCT_P.L sin datos
# PGH.L procesado
# ARBB.L procesado
# SUH.L procesado
# NFC.L sin datos
# IRONI.L sin datos
# EAH.L procesado
# RMM.L sin datos
# SNT.L procesado
# ODX.L sin datos
# OKYO.L sin datos
# NAIT.L procesado
# JCH.L procesado
# BGUK.L procesado
# CNSP.L sin datos
# BRH.L procesado
# OCIO.L sin datos
# BIRD.L procesado
# BRK.L procesado
# ALBA.L procesado
# GLIF.L sin datos
# POLR.L procesado
# AEO.L procesado
# UAI.L sin datos
# TOWNT.L sin datos
# VIN.L sin datos
# BEE.L sin datos
# PCTN.L procesado
# DISD.L sin datos
# MPL.L procesado
# SMSS.L sin datos
# JSG.L procesado
# AOR.L sin datos
# FEN.L procesado
# EOG.L procesado
# IGC.L procesado
# ECHOE.L sin datos
# PRES.L sin datos
# INGI.L sin datos
# VELA.L sin datos
# SPPC.L sin datos
# UVEL.L sin datos
# TREE.L sin datos
# NCCL.L sin datos
# MMXM.L sin datos
# CGT.L procesado
# FAS.L sin datos
# HILS.L procesado
# PHI.L procesado
# LSL.L procesado
# HFEL.L procesado
# SORA.L sin datos
# DOLC.L sin datos
# NAUTN.L sin datos
# HGM.L sin datos
# DEMG.L sin datos
# AGY.L procesado
# UCG.L sin datos
# BOUB.L sin datos
# TRX.L procesado
# PTCM.L sin datos
# MFX.L procesado
# IIP.L procesado
# FCRM.L sin datos
# ATT.L sin datos
# TELT.L sin datos
# BPET.L sin datos
# HUW.L procesado
# LVCG.L sin datos
# CKT.L procesado
# LOGP.L procesado
# PFP.L sin datos
# CAML.L procesado
# YOLO.L sin datos
# HNE.L sin datos
# ATS.L procesado
# KDNC.L procesado
# AMAMP.L sin datos
# SRC.L procesado
# AEGR.L sin datos
# PALO.L sin datos
# ADL.L sin datos
# JZCP.L procesado
# TSG.L sin datos
# ATYM.L procesado
# HDT.L sin datos
# BIOM.L sin datos
# WHI.L procesado
# DBOX.L procesado
# AMO.L sin datos
# AAZ.L procesado
# RRR.L procesado
# MPAYM.L sin datos
# HZM.L sin datos
# PANR.L procesado
# OPG.L procesado
# BREE.L procesado
# IAT.L sin datos
# B4S.L sin datos
# RLDR.L sin datos
# TSTRE.L sin datos
# MAFL.L procesado
# SMLP.L sin datos
# SPDI.L procesado
# CRSL.L sin datos
# MTL.L procesado
# WATRI.L sin datos
# BRDY.L sin datos
# LOK.L sin datos
# JDG.L procesado
# JIM.L procesado
# PHC.L sin datos
# SRES.L procesado
# REAT.L procesado
# ORR.L procesado
# GLR.L procesado
# AVO.L sin datos
# CNKS.L sin datos
# ZOO.L procesado
# SYS1.L procesado
# WSG.L procesado
# ORCP.L procesado
# MSYS.L sin datos
# SOM.L procesado
# CGH.L sin datos
# ALY.L sin datos
# FSJ.L procesado
# HFG.L procesado
# BODP.L sin datos
# FDPF.L sin datos
# FIPPG.L sin datos
# STBS.L sin datos
# BLPU.L sin datos
# BLUS.L sin datos
# RLE.L procesado
# ARSA.L sin datos
# JLP.L procesado
# ANCR.L procesado
# SRSP.L sin datos
# AXM.L sin datos
# ACPA.L sin datos
# KZG.L procesado
# DSG.L procesado
# BOTB.L sin datos
# GDRG.L sin datos
# SYNS.L sin datos
# MOGP.L sin datos
# DOTD.L procesado
# THRU.L procesado
# HGT.L procesado
# MCKS.L sin datos
# EDLE.L sin datos
# EMPR.L sin datos
# PRR.L sin datos
# WNRG.L sin datos
# ZOLQ.L sin datos
# RICA_P.L sin datos
# LEAF.L sin datos
# MBLT.L sin datos
# GHH.L procesado
# IGP.L procesado
# N4P.L procesado
# CCT.L procesado
# GRL.L procesado
# SAR.L procesado
# CNGC.L sin datos
# STAF.L procesado
# SND.L sin datos
# CLON.L procesado
# SJH.L sin datos
# GATC.L procesado
# AFS.L sin datos
# SALVS.L sin datos
# ZIOC.L procesado
# CSRT.L sin datos
# VTC.L sin datos
# CINE.L sin datos
# ARGR.L sin datos
# IMGE.L sin datos
# ACCI.L sin datos
# RED.L sin datos
# BIDS.L sin datos
# ARCMA.L sin datos
# BURF.L sin datos
# EGRE.L sin datos
# INSEI.L sin datos
# LSR.L sin datos
# CRU.L procesado
# PMG.L procesado
# BEM.L procesado
# FUM.L procesado
# HYR.L sin datos
# ALT.L procesado
# PCA.L procesado
# ARDN.L sin datos
# CERP.L sin datos
# CASPC.L sin datos
# LTGL.L sin datos
# ORM.L sin datos
# UFO.L procesado
# KIT.L sin datos
# LWI.L procesado
# FOUR.L procesado
# RWA.L procesado
# GAGO.L sin datos
# HERS.L sin datos
# GGPL.L sin datos
# ETXP.L sin datos
# SAGS.L sin datos
# CMBC.L sin datos
# ID2A.L sin datos
# IQG.L sin datos
# APT.L sin datos
# RHL.L sin datos
# CFX.L procesado
# SOG.L sin datos
# TCN.L sin datos
# ROSER.L sin datos
# MLVN.L procesado
# RGM.L sin datos
# VRP.L sin datos
# XTR.L procesado
# LND.L procesado
# CYAN.L procesado
# ADT.L sin datos
# PHD.L sin datos
# NTBR.L procesado
# CALL.L sin datos
# KEFI.L procesado
# TYMN.L sin datos
# PGRP.L sin datos
# STCM.L procesado
# BUT.L procesado
# MKLW.L sin datos
# SHRS.L procesado
# CAU.L procesado
# MWEE.L sin datos
# PETA.L sin datos
# NAK.L sin datos
# TFW.L procesado
# MXCP.L sin datos
# SUMM.L sin datos
# UKR.L procesado
# GTC.L procesado
# DRV.L sin datos
# VNET.L procesado
# VTU.L procesado
# ASH.L sin datos
# MWG.L sin datos
# LWRF.L sin datos
# TND.L procesado
# WBI.L procesado
# GVC.L sin datos
# GEOG.L sin datos
# RAV.L sin datos
# TRS.L sin datos
# AVTG.L sin datos
# WRESW.L sin datos
# ASCR.L sin datos
# ARNR.L sin datos
# ECRE.L sin datos
# ILND.L sin datos
# CNDR.L sin datos
# MAIH.L sin datos
# MURG.L sin datos
# ROCKR.L sin datos
# ZAMB.L sin datos
# EVRH.L sin datos
# SRO.L sin datos
# SOLI.L procesado
# LID.L sin datos
# SAA.L procesado
# CLL.L sin datos
# SRB.L procesado
# KIBO.L procesado
# MATD.L procesado
# MBO.L procesado
# AVON.L procesado
# LWB.L sin datos
# MAJE.L procesado
# HAN.L procesado
# M2Z.L sin datos
# ALAPH.L sin datos
# TOWR.L sin datos
# EMEL.L sin datos
# SOSS.L sin datos
# CNCTC.L sin datos
# CTEA.L sin datos
# PURE.L sin datos
# CMH.L sin datos
# AVG.L procesado
# IMM.L procesado
# PUR.L sin datos
# BLTGB.L sin datos
# DTG.L sin datos
# ABAL.L sin datos
# CLPC.L sin datos
# OVB.L procesado
# URU.L procesado
# BOOT.L procesado
# RBDR.L sin datos
# PYSM.L sin datos
# UKOGA.L sin datos
# AFEN.L sin datos
# JWNG.L sin datos
# ARGOA.L sin datos
# MTWL.L sin datos
# MOSE.L sin datos
# RQE.L sin datos
# WYWYN.L sin datos
# VITA.L sin datos
# GUS.L sin datos
# NWF.L procesado
# SIXH.L sin datos
# ITM.L procesado
# SOU.L procesado
# MUBL.L sin datos
# DCD.L sin datos
# CRW.L procesado
# CVSG.L procesado
# NUOG.L sin datos
# LSAI.L sin datos
# DPP.L procesado
# FTC.L procesado
# IHC.L procesado
# AGTAR.L sin datos
# INDII.L sin datos
# STMG.L sin datos
# EBQ.L procesado
# ZYT.L sin datos
# ZIN.L procesado
# TAVI.L procesado
# LTHM.L procesado
# SPA.L procesado
# SOLO.L sin datos
# CTPC.L sin datos
# CKN.L procesado
# CSN.L procesado
# IPO.L procesado
# SWGS.L sin datos
# GLDP.L sin datos
# OTM.L sin datos
# TLY.L sin datos
# YGEN.L sin datos
# RUR.L sin datos
# HDD.L procesado
# TSTL.L procesado
# BYOT.L procesado
# NASA.L sin datos
# SOLG.L procesado
# ASTO.L sin datos
# PEB.L procesado
# GDWN.L procesado
# MCB.L procesado
# RCDO.L procesado
# KCT.L sin datos
# NXR.L procesado
# TPG.L sin datos
# SHAN.L sin datos
# THRL.L procesado
# ANP.L procesado
# RSTP.L sin datos
# SSY.L sin datos
# AUG.L sin datos
# CHRT.L procesado
# YOU.L procesado
# IBPO.L sin datos
# FST.L sin datos
# RNO.L procesado
# KRS.L procesado
# INS.L sin datos
# VALX.L sin datos
# HNTS.L sin datos
# NBB.L procesado
# MIRA.L sin datos
# ECK.L sin datos
# BGO.L procesado
# TAST.L procesado
# EQTE.L sin datos
# SUS.L procesado
# AGLE.L sin datos
# MDZE.L sin datos
# NCCG.L sin datos
# DLGD.L sin datos
# NMC.L sin datos
# CCH.L procesado
# JE.L sin datos
# AUTOA.L sin datos
# NBLS.L sin datos
# WWH.L procesado
# DPH.L sin datos
# DPLM.L procesado
# TED.L sin datos
# SYNCS.L sin datos
# NRRT.L sin datos
# UDG.L sin datos
# RMG.L sin datos
# MDCM.L sin datos
# CRST.L procesado
# JUSTJ.L sin datos
# NOGN.L sin datos
# ETO.L sin datos
# TRIG.L procesado
# UKWG.L sin datos
# GFTU_U.L sin datos
# RSER.L sin datos
# PETSP.L sin datos
# RDI.L sin datos
# PLP.L sin datos
# CARDC.L sin datos
# SAGAG.L sin datos
# SSPG.L procesado
# SPI.L procesado
# BBOXT.L sin datos
# FDM.L procesado
# OSBO.L sin datos
# PSSL.L sin datos
# INDV.L procesado
# JLG.L sin datos
# SEQI.L procesado
# WIZZ.L procesado
# COA.L procesado
# AAAA.L sin datos
# BMEB.L sin datos
# SNNS.L sin datos
# MERL.L sin datos
# WPCT.L sin datos
# SOPH.L sin datos
# EQN.L sin datos
# HSTG.L sin datos
# IBST.L procesado
# MCS.L sin datos
# SCTS.L sin datos
# CSPC.L sin datos
# ASCL.L sin datos
# VMUK.L sin datos
# MTRO.L procesado
# VEILV.L sin datos
# TBCG.L procesado
# HVPEA.L sin datos
# PSHP.L sin datos
# ALFAAL.L sin datos
# CTEC.L procesado
# ALML.L sin datos
# CMCX.L procesado
# AO.L procesado
# INGA.AS procesado
# RDSA.AS sin datos
# HEIN.AS sin datos
# AEGN.AS sin datos
# PHG.AS sin datos
# ARBN.AS sin datos
# RDSB.AS sin datos
# HOLCO.AS procesado
# URW.AS sin datos
# ASMI.AS sin datos
# RAND.AS procesado
# FUGRC.AS sin datos
# CORB.AS sin datos
# VASN.AS sin datos
# AMG.AS procesado
# WLSNC.AS sin datos
# SBMO.AS procesado
# ORDN.AS sin datos
# AKZO.AS sin datos
# VOPA.AS sin datos
# TOM2.AS procesado
# DSMN.AS sin datos
# BSWSC.AS sin datos
# KARD.AS sin datos
# AD.AS procesado
# MT.AS procesado
# BINCK.AS sin datos
# KPN.AS procesado
# BAMN.AS sin datos
# ASML.AS procesado
# NSTEC.AS sin datos
# AALB.AS procesado
# WEHA.AS sin datos
# ARDS.AS sin datos
# BRUN.AS sin datos
# BOSN.AS sin datos
# HLAN.AS sin datos
# HEIJ.AS sin datos
# SVEL.AS sin datos
# PHAR.AS sin datos
# ACCG.AS sin datos
# SIPFC.AS sin datos
# HUDN.AS sin datos
# LVIDE.AS procesado
# CTAN.AS sin datos
# BETR.AS sin datos
# SNOW.AS sin datos
# TWKNC.AS sin datos
# KASNC.AS sin datos
# BESI.AS procesado
# NEDP.AS sin datos
# AJAX.AS procesado
# ICTA.AS sin datos
# BRIL.AS sin datos
# ORANW.AS sin datos
# VLAN.AS sin datos
# ROON.AS sin datos
# DGB.AS procesado
# NEWN.AS sin datos
# EAS2P.AS procesado
# ARTN.AS sin datos
# YATRA.AS procesado
# REL.AS sin datos
# DPA.AS sin datos
# PHLX.AS sin datos
# NEDSE.AS procesado
# APAM.AS procesado
# PTNL.AS sin datos
# HYDRA.AS procesado
# TFG.AS procesado
# IEX.AS sin datos
# GLPG.AS procesado
# ACCS.AS sin datos
# ANDP.AS sin datos
# ATRS.AS procesado
# BGHL.AS sin datos
# ESPE.AS sin datos
# NSEN.AS sin datos
# SLIGR.AS procesado
# ARCPF.AS sin datos
# TIEH.AS sin datos
# CCEP.AS procesado
# PRCF.AS sin datos
# CLB.AS sin datos
# NOVI.AS sin datos
# AAA.AS sin datos
# MORE.AS procesado
# BEVA.AS sin datos
# VALU8.AS sin datos
# ECT.AS procesado
# HEIO.AS procesado
# OCI.AS procesado
# TBIRD.AS sin datos
# VTA.AS procesado
# PSH.AS procesado
# VVY.AS procesado
# NN.AS procesado
# IMCD.AS procesado
# THXLE.AS sin datos
# BOLS.AS sin datos
# GVNV.AS sin datos
# FLOW.AS procesado
# KDS.AS sin datos
# ATCA.AS sin datos
# INTER.AS sin datos
# RNTO.AS sin datos
# ABND.AS sin datos
# CURE.AS sin datos
# ATCB.AS sin datos
# SIFG.AS procesado
# LIGHT.AS procesado
# FFARM.AS procesado
# ASRNL.AS procesado
# BFIT.AS procesado
# ENVI.AS procesado
# RBEN.AS sin datos
# RLIN.AS sin datos
# UNA.AS procesado
# TKWY.AS procesado
# AVTX.AS procesado
# VON.AS sin datos
# KVW.AS sin datos
# NRP.AS procesado
# REINA.AS procesado
# PREVA_P.AS sin datos
# DSC1.AS sin datos
# ALFEN.AS procesado
# BSGR.AS procesado
# NIBC.AS sin datos
# ADYEN.AS procesado
# FASTN.AS sin datos
# MAREL.AS sin datos
# PRX.AS procesado
# ALHGR.AS sin datos
# CMCOM.AS procesado
# CSGN.SW sin datos
# ADEN.SW procesado
# CFR.SW procesado
# BAER.SW procesado
# ABBN.SW procesado
# LHN.SW sin datos
# BALN.SW procesado
# LOGN.SW procesado
# CLN.SW procesado
# ZURN.SW procesado
# UHR.SW procesado
# SLHN.SW procesado
# NOVN.SW procesado
# NESN.SW procesado
# SRENH.SW sin datos
# ROG.SW procesado
# LONN.SW procesado
# SCMN.SW procesado
# SGSN.SW procesado
# KURN.SW procesado
# OERL.SW procesado
# RIGN.SW sin datos
# BASFZ.SW sin datos
# SIEGN.SW sin datos
# DANO.SW sin datos
# GE.SW sin datos
# GEBN.SW procesado
# AMS.SW procesado
# BEAN.SW procesado
# VALN.SW sin datos
# BUCN.SW procesado
# RIEN.SW procesado
# ALLN.SW procesado
# FHZN.SW procesado
# KOMN.SW procesado
# IFCN.SW procesado
# MOBN.SW procesado
# ASCN.SW procesado
# DOKA.SW procesado
# TECN.SW procesado
# BOS.SW sin datos
# VONN.SW procesado
# EMMN.SW procesado
# BCVN.SW procesado
# EMSN.SW procesado
# EVE.SW procesado
# IMPN.SW procesado
# SCHN.SW procesado
# DAE.SW procesado
# KARN.SW procesado
# ARBNO.SW sin datos
# ZEHN.SW procesado
# COPN.SW procesado
# BION.SW procesado
# SIKA.SW procesado
# SPSN.SW procesado
# BARN.SW procesado
# LISN.SW procesado
# HELN.SW procesado
# PSPN.SW procesado
# PGHN.SW procesado
# SCHP.SW procesado
# KNIN.SW procesado
# SUN.SW procesado
# ARYN.SW procesado
# DKSH.SW procesado
# FIN.SW sin datos
# SOON.SW procesado
# VATN.SW procesado
# VIFN.SW sin datos
# PARG.SW sin datos
# GAMH.SW sin datos
# LMN.SW procesado
# NESNEE.SW sin datos
# HBMNN.SW sin datos
# MOLN.SW procesado
# LISP.SW procesado
# UHRN.SW procesado
# UBSG.SW procesado
# ...
# BIOVICB.ST sin datos
# ISOFOL.ST procesado
# PRLD.ST procesado
# ATIC.ST procesado
# FMMB.ST sin datos
# IVACC.ST procesado
# SONE.ST procesado
# SSM.ST sin datos
# TANGI.ST procesado
# ANNX.ST procesado
# ACUC.ST procesado
# IPCOR.ST sin datos
# MATRA.ST sin datos
# XMR.ST procesado
# COMPIT.ST sin datos
# RENT.ST procesado
# BUSER.ST procesado
# LOGS.ST sin datos
# MANTEX.ST procesado
# INSTAL.ST procesado
# INTEGB.ST sin datos
# SDIPB.ST sin datos
# SECIT.ST sin datos
# BIOSE.ST sin datos
# MCOVB.ST sin datos
# MPLUS.ST sin datos
# MTRS.ST procesado
# ABIGR.ST sin datos
# AYIMAB.ST sin datos
# BOOZT.ST procesado
# TERRNTB.ST sin datos
# NTGRP.ST sin datos
# ESSITYA.ST sin datos
# ESSITYB.ST sin datos
# BONEX.ST procesado
# MMGRB.ST sin datos
# LUMIN.ST sin datos
# ENERS.ST procesado
# NITRO.ST procesado
# QUART.ST procesado
# ZAPLOX.ST procesado
# PAX.ST procesado
# TCC.ST sin datos
# TRIANB.ST sin datos
# SEDANA.ST procesado
# SUSW.ST sin datos
# CIMCO.ST sin datos
# ASPIRE.ST sin datos
# PROMO.ST sin datos
# URBIT.ST procesado
# REALFI.ST procesado
# PANION.ST sin datos
# IAPO.ST sin datos
# OMNIC.ST sin datos
# NETMB.ST sin datos
# SDSY.ST sin datos
# ENRAD.ST procesado
# SECS.ST sin datos
# N55.ST sin datos
# NXTCL.ST procesado
# SENZA.ST procesado
# ISAB.ST procesado
# XSPRAY.ST procesado
# BALCO.ST procesado
# HANDI.ST sin datos
# BIOAB.ST sin datos
# FRAMB.ST sin datos
# SBBPREF.ST sin datos
# CLIMEB.ST sin datos
# QIIWI.ST procesado
# GLOBAL.ST sin datos
# LOGIST.ST procesado
# ESEN.ST sin datos
# FNMA.ST sin datos
# BIBB.ST procesado
# 3KRI.ST sin datos
# ASAIN.ST sin datos
# IRRAS.ST sin datos
# 2CUREX.ST procesado
# AWRD.ST sin datos
# TSEC.ST procesado
# DEVPB.ST sin datos
# MAGIN.ST sin datos
# ACCON.ST procesado
# SCOUT.ST procesado
# ARJOB.ST sin datos
# LYKOA.ST sin datos
# ATVEXAB.ST sin datos
# COREB.ST sin datos
# BIOWKS.ST procesado
# FLEXQ.ST procesado
# HDWB.ST sin datos
# AKELPREF.ST sin datos
# LEMSE.ST procesado
# LIVIH.ST sin datos
# BONES.ST sin datos
# CIBUS.ST procesado
# NP3PREF.ST sin datos
# ZUTEC.ST sin datos
# GREENL.ST sin datos
# BHGF.ST sin datos
# ICO.ST procesado
# FLUIC.ST sin datos
# INFREA.ST procesado
# AECO.ST sin datos
# OVZON.ST procesado
# JDT.ST procesado
# ITECH.ST procesado
# NCAB.ST procesado
# BETCO.ST procesado
# FLEXM.ST procesado
# ELKNOK.ST sin datos
# EPIRB.ST sin datos
# EPIRA.ST sin datos
# PENGB.ST sin datos
# MIDSU.ST sin datos
# CALTX.ST sin datos
# RAKE.ST procesado
# RPLAN.ST procesado
# VNESDB.ST sin datos
# TOUCH.ST procesado
# ASAPH.ST sin datos
# NIO.ST procesado
# INFRAC.ST sin datos
# TOAD.ST sin datos
# 247.ST sin datos
# OBST.ST procesado
# STENO.ST sin datos
# AXOLOT.ST procesado
# NYFO.ST sin datos
# AROSPREF.ST sin datos
# S2ME.ST sin datos
# ALZCUR.ST procesado
# JETPAK.ST sin datos
# LIMET.ST sin datos
# QLINEA.ST procesado
# AZELIO.ST sin datos
# CAGGR.ST sin datos
# SBBD.ST sin datos
# FOOTB.ST sin datos
# INCOAX.ST procesado
# ACELP.ST sin datos
# FERRO.ST procesado
# GIGSEK.ST sin datos
# NENTA.ST sin datos
# NENTB.ST sin datos
# FRILLB.ST sin datos
# TEQ.ST procesado
# COLAB.ST sin datos
# CALMAB.ST sin datos
# ZICC.ST procesado
# SCOLG.ST sin datos
# ADVTY.ST sin datos
# RISK.ST procesado
# BUBL.ST sin datos
# KARNO.ST sin datos
# TRIBOB.ST sin datos
# UPSALE.ST procesado
# OSSD.ST procesado
# SLITE.ST sin datos
# VERTB.ST sin datos
# JOMA.ST procesado
# K2AB.ST sin datos
# NHCBHFFS.ST sin datos
# ADAPT.ST sin datos
# SEAF.ST procesado
# QBITTO1.ST sin datos
# QBIT.ST procesado
# NUSTAY.ST sin datos
# ATANA.ST procesado
# SMOL.ST procesado
# ZORDIXB.ST sin datos
# EQTAB.ST sin datos
# MNTC.ST procesado
# LIPI.ST sin datos
# ZIGN.ST sin datos
# ACS.MC procesado
# ABG.MC sin datos
# A3M.MC procesado
# ACX.MC procesado
# BBVA.MC procesado
# BKT.MC procesado
# BME.MC sin datos
# ANA.MC procesado
# CABK.MC procesado
# ENAG.MC sin datos
# FCC.MC procesado
# NTGY.MC procesado
# SGREN.MC sin datos
# GRLS.MC sin datos
# FER.MC procesado
# REE.MC sin datos
# ITX.MC procesado
# REP.MC procesado
# IBE.MC procesado
# IDR.MC procesado
# MAP.MC procesado
# TEF.MC procesado
# TL5.MC sin datos
# SCYR.MC procesado
# SABE.MC sin datos
# SAN.MC procesado
# COL.MC procesado
# TRE.MC procesado
# OHL.MC sin datos
# ICAG.MC sin datos
# EBRO.MC procesado
# ELE.MC procesado
# AMA.MC sin datos
# BKIA.MC sin datos
# DIDA.MC sin datos
# VTSG.MC sin datos
# ROVI.MC procesado
# GALQ.MC sin datos
# SLRS.MC sin datos
# AI.MC procesado
# ALNTA.MC sin datos
# ALB.MC sin datos
# PRS.MC procesado
# MEL.MC procesado
# GSJ.MC procesado
# NXTE.MC sin datos
# ADXR.MC sin datos
# MCM.MC procesado
# GCO.MC procesado
# SPSL.MC sin datos
# ENC.MC procesado
# CAF.MC procesado
# UBS.MC procesado
# ISUR.MC procesado
# QBT.MC sin datos
# LGT.MC procesado
# IBG.MC procesado
# BRIO.MC sin datos
# ADZ.MC procesado
# RLIA.MC procesado
# IBES.MC sin datos
# CBAV.MC procesado
# RDM.MC sin datos
# NEA.MC procesado
# CIEA.MC sin datos
# RTA4.MC sin datos
# RJFE.MC sin datos
# EZEN.MC sin datos
# MDF.MC procesado
# ZOT.MC sin datos
# BDL.MC sin datos
# MTBA.MC sin datos
# MVC.MC procesado
# NHH.MC procesado
# FAE.MC procesado
# TUR.MC sin datos
# PVA.MC procesado
# GRLSBN.MC sin datos
# BIOS.MC sin datos
# VIS.MC procesado
# PSG.MC procesado
# ALM.MC procesado
# VOC.MC procesado
# VID.MC procesado
# CCMC.MC sin datos
# TUBA.MC sin datos
# REN.MC procesado
# FLUI.MC sin datos
# ENOR.MC sin datos
# AZK.MC procesado
# APAM.MC procesado
# SNCE.MC sin datos
# ECR.MC procesado
# CDRE.MC sin datos
# NATR.MC sin datos
# APE.MC sin datos
# AIR.MC procesado
# PRIM.MC sin datos
# OLEO.MC sin datos
# MTS.MC procesado
# ABGEK.MC sin datos
# LBK.MC sin datos
# EBI.MC sin datos
# YENT.MC procesado
# PETR4.MC sin datos
# AMXL.MC sin datos
# BRPO.MC sin datos
# BRPP.MC sin datos
# BRKM3.MC sin datos
# CPLE6.MC sin datos
# ELTO.MC sin datos
# ELTB.MC sin datos
# PETR3.MC sin datos
# USIO.MC sin datos
# USIM5.MC sin datos
# VALO.MC sin datos
# ALFAA.MC sin datos
# ELEKTRA.MC sin datos
# XNOR.MC procesado
# TVAZ.MC sin datos
# BBAR.MC sin datos
# CMIG4.MC sin datos
# BBDC.MC sin datos
# GGBR4.MC sin datos
# VOLB.MC sin datos
# IKM.MC sin datos
# ABBO.MC sin datos
# ALC.MC procesado
# ADLB.MC sin datos
# CATN.MC sin datos
# EESP.MC sin datos
# EUWT.MC sin datos
# GRIE.MC sin datos
# MASM.MC sin datos
# IMGI.MC sin datos
# MEDC.MC sin datos
# NEUB.MC sin datos
# SECU.MC sin datos
# EDRE.MC sin datos
# LRES.MC sin datos
# APPS.MC sin datos
# MRL.MC procesado
# FACE.MC procesado
# LOG.MC procesado
# CRBHO.MC sin datos
# HMR.MC sin datos
# AENA.MC procesado
# YURO.MC sin datos
# NBIB.MC sin datos
# NTH.MC procesado
# CLNX.MC procesado
# TLGO.MC procesado
# EKTL.MC sin datos
# YFID.MC procesado
# GREG.MC sin datos
# INC.MC sin datos
# YTRA.MC procesado
# LLN.MC procesado
# YARE.MC sin datos
# YOSO.MC sin datos
# PHMR.MC sin datos
# GIGAH.MC sin datos
# NEOL.MC sin datos
# AGIL.MC procesado
# YZBL.MC procesado
# ORY.MC procesado
# TQT.MC sin datos
# CLRE.MC sin datos
# YPR3.MC sin datos
# DOMI.MC sin datos
# PQR.MC sin datos
# YABA.MC procesado
# YSCI.MC sin datos
# CCEP.MC procesado
# YAST.MC sin datos
# YVIT.MC procesado
# YISC.MC procesado
# YQUO.MC procesado
# ATRY.MC procesado
# VOZ.MC sin datos
# YGMP.MC procesado
# YORS.MC sin datos
# CMM.MC procesado
# ECG.MC sin datos
# CLE.MC sin datos
# MONIB.MC sin datos
# PANGO.MC sin datos
# YVBA.MC sin datos
# YORE.MC procesado
# CASHP.MC sin datos
# HOME.MC procesado
# GEST.MC procesado
# YOVA.MC sin datos
# ELZZ.MC sin datos
# UNI.MC procesado
# YGGC.MC sin datos
# YNUM.MC procesado
# BAINS.MC sin datos
# YAML.MC procesado
# YGOP.MC procesado
# YDOM.MC sin datos
# AEDAS.MC procesado
# NTX.MC sin datos
# GRN.MC sin datos
# YPSNA.MC sin datos
# YSPS.MC sin datos
# YHAB.MC sin datos
# RBT.MC procesado
# YTEM.MC procesado
# YSRR.MC procesado
# YAP67.MC procesado
# TR1.MC sin datos
# YTOR.MC sin datos
# YQPQ.MC procesado
# YEXR.MC procesado
# YCPS.MC procesado
# YTST.MC procesado
# BKY.MC procesado
# ALQ.MC procesado
# YGOB.MC sin datos
# ARM.MC procesado
# EATP.MC sin datos
# YATO.MC procesado
# SPK.MC sin datos
# YARP.MC procesado
# YVIV.MC procesado
# YAC1.MC sin datos
# YPARK.MC procesado
# YEPS.MC sin datos
# PROE.MC sin datos
# YMRE.MC procesado
# IFFE.MC sin datos
# CEV.MC procesado
# YMHRE.MC procesado
# TLIT.MI sin datos
# FCHA.MI sin datos
# GASI.MI sin datos
# SRG.MI procesado
# PIRC.MI procesado
# UBI.MI sin datos
# IOL.MI sin datos
# PRY.MI procesado
# ISP.MI procesado
# CRDI.MI sin datos
# BMED.MI procesado
# LDOF.MI sin datos
# ENEI.MI sin datos
# TENR.MI sin datos
# ENI.MI procesado
# UNPI.MI sin datos
# BMPS.MI procesado
# BZU.MI procesado
# A2.MI sin datos
# ATL.MI sin datos
# SALI.MI sin datos
# TRN.MI procesado
# US.MI sin datos
# MDBI.MI sin datos
# AGL.MI sin datos
# BAMI.MI procesado
# MS.MI procesado
# SPMI.MI sin datos
# GEDI.MI sin datos
# MOED.MI sin datos
# TIS.MI sin datos
# AZMT.MI sin datos
# GEO.MI procesado
# EXOR.MI sin datos
# CIRX.MI sin datos
# CPRI.MI sin datos
# CARRA.MI sin datos
# SRS.MI sin datos
# EMII.MI sin datos
# DIAS.MI sin datos
# SFER.MI procesado
# TOD.MI sin datos
# ACE.MI procesado
# REST.MI sin datos
# AMPF.MI sin datos
# ASCI.MI sin datos
# ASR.MI sin datos
# AST.MI sin datos
# ATMI.MI sin datos
# BGN.MI procesado
# BPSI.MI sin datos
# BRBI.MI sin datos
# COFI.MI sin datos
# CRGI.MI sin datos
# DAL.MI procesado
# DANI.MI sin datos
# DEA.MI procesado
# DLG.MI procesado
# EEMS.MI procesado
# ERG.MI procesado
# AA4.MI sin datos
# HRA.MI sin datos
# IGD.MI procesado
# IMAI.MI sin datos
# ITPG.MI sin datos
# IREE.MI sin datos
# IKG.MI sin datos
# LR.MI sin datos
# MTCM.MI sin datos
# PIA.MI procesado
# PRO.MI procesado
# RCSM.MI sin datos
# RECI.MI sin datos
# SFLG.MI sin datos
# SIS.MI sin datos
# SGFI.MI sin datos
# TFI.MI sin datos
# STM.MI sin datos
# SAF.MI procesado
# AIRP.MI sin datos
# INGA.MI sin datos
# AEGN.MI sin datos
# PHIA.MI sin datos
# BASF.MI sin datos
# BAYG.MI sin datos
# ALV.MI sin datos
# SIE.MI sin datos
# DBK.MI sin datos
# DAI.MI sin datos
# AXA.MI sin datos
# DNN.MI procesado
# ENGIE.MI sin datos
# BNPP.MI sin datos
# LVMH.MI sin datos
# OR.MI procesado
# CRR.MI procesado
# CAGR.MI sin datos
# ORAN.MI sin datos
# GLE.MI sin datos
# SANF.MI sin datos
# VIV.MI sin datos
# TOT.MI procesado
# RENA.MI sin datos
# TEF.MI sin datos
# NOKIA.MI sin datos
# BMW.MI sin datos
# DTE.MI sin datos
# MUV2.MI sin datos
# SAP.MI sin datos
# PRTP.MI sin datos
# RWE.MI sin datos
# UNA.MI sin datos
# AD.MI sin datos
# EOA.MI sin datos
# AGES.MI sin datos
# BIO.MI sin datos
# 37B.MI sin datos
# ACAG.MI sin datos
# ACO.MI sin datos
# AEF.MI procesado
# AMBA.MI sin datos
# ARN.MI procesado
# AUMI.MI sin datos
# B7C.MI sin datos
# BCNT.MI sin datos
# BCU.MI sin datos
# BE.MI sin datos
# BET.MI sin datos
# BFE.MI sin datos
# BIA.MI procesado
# BIAN.MI sin datos
# BIE.MI sin datos
# BIM.MI sin datos
# BRGI.MI sin datos
# BRGIN.MI sin datos
# BRUI.MI sin datos
# BSS.MI procesado
# BTGI.MI sin datos
# BZUN.MI sin datos
# CAI.MI procesado
# CALI.MI sin datos
# CASS.MI sin datos
# CDRU.MI sin datos
# CED.MI procesado
# CEMB.MI sin datos
# CEMI.MI sin datos
# CHL.MI sin datos
# CIAZ.MI sin datos
# CLED.MI sin datos
# CLFF.MI sin datos
# CLII.MI sin datos
# COPR.MI sin datos
# CRGIN.MI sin datos
# CSP.MI procesado
# DANIN.MI sin datos
# DESI.MI sin datos
# DESIN.MI sin datos
# DIB.MI procesado
# NTW.MI procesado
# E5T.MI sin datos
# EDII.MI sin datos
# EDNN.MI sin datos
# ELC.MI procesado
# ELEN.MI sin datos
# EM.MI procesado
# EMBI.MI sin datos
# ENVT.MI sin datos
# EUKE.MI sin datos
# FDA.MI procesado
# FDE.MI sin datos
# FICP.MI sin datos
# FIMI.MI sin datos
# FNMI.MI sin datos
# FTL.MI sin datos
# FUL.MI sin datos
# GABI.MI sin datos
# GFRN.MI sin datos
# GSP.MI procesado
# GEQ.MI sin datos
# IF.MI procesado
# IGS.MI sin datos
# IGV.MI procesado
# PLC.MI procesado
# IMSI.MI sin datos
# SALIN.MI sin datos
# IRC.MI procesado
# ITMI.MI sin datos
# ITWY.MI sin datos
# JUVE.MI procesado
# SERK.MI sin datos
# WIGG.MI sin datos
# IKGN.MI sin datos
# LAZI.MI sin datos
# LDO.MI procesado
# LVEN.MI sin datos
# LIT.MI sin datos
# MARR.MI procesado
# CBI.MI sin datos
# SES.MI procesado
# MLMD.MI sin datos
# MOL.MI procesado
# MTTI.MI sin datos
# MTV.MI procesado
# NR.MI procesado
# NRST.MI procesado
# OLI.MI procesado
# PAGR.MI sin datos
# PCVI.MI sin datos
# IOLN.MI sin datos
# VE.MI procesado
# PNNI.MI sin datos
# POLI.MI sin datos
# POPR.MI procesado
# PQ.MI procesado
# PRII.MI sin datos
# PRL.MI sin datos
# PRT.MI procesado
# PSF.MI sin datos
# RATI.MI sin datos
# RDM.MI sin datos
# REY.MI procesado
# RN.MI procesado
# ROSS.MI sin datos
# S24.MI procesado
# SABF.MI sin datos
# ATH.MI sin datos
# SAEI.MI sin datos
# SAEIN.MI sin datos
# SARIN.MI sin datos
# TYA.MI procesado
# SERIT.MI sin datos
# TTT.MI sin datos
# SOLS.MI sin datos
# SPMIR.MI sin datos
# STEP.MI sin datos
# STEPN.MI sin datos
# TAS.MI sin datos
# TES.MI procesado
# TIP.MI procesado
# TLITN.MI sin datos
# TRNI.MI sin datos
# TXTS.MI sin datos
# VALS.MI sin datos
# VINI.MI sin datos
# XPR.MI sin datos
# ZUCI.MI sin datos
# ZUCIN.MI sin datos
# ZV.MI procesado
# MACA.MI sin datos
# IVS.MI sin datos
# CNHI.MI sin datos
# MONC.MI procesado
# CERV.MI sin datos
# FBK.MI procesado
# FCT.MI procesado
# ANIM.MI procesado
# ON.MI sin datos
# RWAY.MI procesado
# MOLDC.MI sin datos
# ENER.MI sin datos
# EXSY.MI sin datos
# IINT.MI sin datos
# CDGI.MI sin datos
# INCI.MI sin datos
# KI.MI sin datos
# MAIL.MI sin datos
# NPI.MI procesado
# TRWL.MI sin datos
# FILA.MI procesado
# AGAT.MI sin datos
# YIV.MI sin datos
# YSFT.MI sin datos
# GO.MI sin datos
# DMG.MI sin datos
# MTFR.MI sin datos
# TB.MI procesado
# TNXT.MI procesado
# AXEL.MI sin datos
# FDOP.MI sin datos
# ITWB.MI sin datos
# EPRC.MI sin datos
# OVS.MI procesado
# CALG.MI sin datos
# DGT.MI procesado
# ECKS.MI sin datos
# ELAB.MI sin datos
# GGPW.MI sin datos
# IB.MI procesado
# LCMG.MI sin datos
# LFG.MI procesado
# CLAB.MI sin datos
# MSU.MI sin datos
# ELIN.MI sin datos
# COV.MI sin datos
# BIO2.MI sin datos
# MZB.MI sin datos
# INWT.MI sin datos
# BSTA.MI sin datos
# MASIA.MI sin datos
# ADB.MI procesado
# ASSI.MI sin datos
# GGTV.MI sin datos
# PITE.MI sin datos
# AVI.MI sin datos
# PST.MI procesado
# GAMB.MI procesado
# ORSO.MI sin datos
# HFARM.MI sin datos
# BBLUE.MI sin datos
# OJM.MI sin datos
# RACE.MI procesado
# EMCC.MI sin datos
# ABIT.MI sin datos
# SITI.MI sin datos
# TGYM.MI procesado
# CRES.MI sin datos
# CBKG.MI sin datos
# LHAG.MI sin datos
# SGEF.MI sin datos
# PRSM.MI sin datos
# ADSGN.MI sin datos
# AIR.MI sin datos
# CONG.MI sin datos
# DPWGN.MI sin datos
# ENAV.MI procesado
# IFXGN.MI sin datos
# MRCG.MI sin datos
# VOWG_P.MI sin datos
# 4AIM.MI sin datos
# BEIG.MI sin datos
# DHH.MI procesado
# FREG.MI sin datos
# HEIG.MI sin datos
# SCM.MI procesado
# SDFGN.MI sin datos
# VTY.MI sin datos
# SCHN.MI sin datos
# ABI.MI sin datos
# DB1GN.MI sin datos
# FMEG.MI sin datos
# PSMGN.MI sin datos
# SGOB.MI sin datos
# ASML.MI sin datos
# ESSI.MI sin datos
# HNKG_P.MI sin datos
# TKAG.MI sin datos
# UN01.MI sin datos
# VNAN.MI sin datos
# URW.MI sin datos
# EVKN.MI sin datos
# FF.MI procesado
# IG.MI procesado
# FOPE.MI sin datos
# GPI.MI procesado
# WMC.MI sin datos
# HIA.MI sin datos
# TLSA.MI sin datos
# CELL.MI procesado
# LUVE.MI procesado
# TPSG.MI sin datos
# UNIR.MI sin datos
# BFF.MI procesado
# ECNL.MI procesado
# INDB.MI procesado
# WIIT.MI procesado
# FNL.MI sin datos
# BFG.MI procesado
# DIGT.MI sin datos
# DOVA.MI sin datos
# CULT.MI procesado
# CFTS.MI sin datos
# SICT.MI sin datos
# SITT.MI sin datos
# ABTG.MI procesado
# ICFG.MI sin datos
# PHNU.MI sin datos
# CFP2.MI sin datos
# IGS_P.MI sin datos
# NDT.MI procesado
# SPTV.MI sin datos
# GIMA.MI sin datos
# IN3.MI sin datos
# PSAR.MI sin datos
# EQUI.MI procesado
# AMZN.MI sin datos
# GAME.MI sin datos
# ALKE.MI sin datos
# IDEAM.MI sin datos
# DBA.MI procesado
# GELE.MI sin datos
# GCL.MI sin datos
# ILLA.MI procesado
# VEI1.MI sin datos
# LCC.MI sin datos
# KIP.MI sin datos
# FVIR.MI sin datos
# GVALU.MI sin datos
# NBAA.MI sin datos
# SOME.MI sin datos
# GRALA.MI sin datos
# CRLI.MI sin datos
# TTSLA.MI sin datos
# LON.MI procesado
# ESAU.MI procesado
# EVAS.MI sin datos
# MONNA.MI sin datos
# PORTO.MI sin datos
# INTD.MI sin datos
# EPS2.MI sin datos
# SGCO.MI sin datos
# SOTR.MI sin datos
# VIMI.MI sin datos
# TSPA.MI sin datos
# SCK.MI procesado
# RENER.MI sin datos
# AAPLE.MI sin datos
# PVNA.MI sin datos
# CIRC.MI procesado
# DGV.MI procesado
# GHC.MI procesado
# EDAC.MI procesado
# PWS.MI procesado
# TEDGE.MI sin datos
# AED.MI sin datos
# NESN.MI sin datos
# IBE.MI sin datos
# REP.MI sin datos
# NNVDA.MI sin datos
# CVO.MI sin datos
# AAMD.MI sin datos
# AF.MI sin datos
# FFB.MI sin datos
# GOOG.MI sin datos
# NETI.MI sin datos
# IINTC.MI sin datos
# MMSFT.MI sin datos
# MMU.MI sin datos
# NNFLX.MI sin datos
# NOVN.MI sin datos
# SSBUX.MI sin datos
# ILP.MI procesado
# NSP.MI procesado
# ILTY.MI procesado
# MAPS.MI procesado
# COME.MI sin datos
# SEIFT.MI sin datos
# CFM.MI procesado
# NEXII.MI sin datos
# ANV.MI sin datos
# AAMM.MI sin datos
# ALCC.MI sin datos
# SIOO.MI sin datos
# IEG.MI procesado
# ELES.MI procesado
# GBUSS.MI sin datos
# OS.MI procesado
# RLT.MI sin datos
# PTRN.MI sin datos
# SHE.MI sin datos
# CLNBB.MI sin datos
# FCM.MI sin datos
# RADIC.MI sin datos
# FARMA.MI sin datos
# CFVT.MI sin datos
# IE.MI sin datos
# COPE.MI sin datos
# WEBO.MI sin datos
# CYB.MI procesado
# NWLF.MI sin datos
# ABIS.MI sin datos
# MFTC.MI sin datos
# ------------------------------------------------------------
# Proceso terminado. Procesados: 1501 | Sin cashflow/errores: 3837
# Archivos generados: cashflow.csv, sin_cashflow.csv
